# %% [markdown]
# # Preprocess PercePiano Data
#
# Run the ORIGINAL PercePiano preprocessing to create train/valid/test splits
# with their exact 78-dimension features.
#
# This creates data compatible with their original training script.

# %% [markdown]
# ## Step 1: Setup Environment

# %%
# Run this notebook with the project venv:
# cd /Users/jdhiman/Documents/crescendai/model
# source .venv/bin/activate
# jupyter notebook notebooks/preprocess_percepiano_data.ipynb

import sys
import os
from pathlib import Path

# Ensure we're using the right Python
print(f"Python: {sys.executable}")
print(f"Version: {sys.version}")

# Check if we're in the venv
if '.venv' not in sys.executable:
    print("\nWARNING: Not running in project venv!")
    print("Please activate: source .venv/bin/activate")

# Paths
PERCEPIANO_ROOT = Path('/Users/jdhiman/Documents/crescendai/model/data/raw/PercePiano')
VIRTUOSO_PATH = PERCEPIANO_ROOT / 'virtuoso' / 'virtuoso'
PYSCOREPARSER_PATH = VIRTUOSO_PATH / 'pyScoreParser'
DATA_PATH = PERCEPIANO_ROOT / 'virtuoso' / 'data'
LABELS_PATH = PERCEPIANO_ROOT / 'labels'

# Label files (they exist in both locations)
LABEL_FILE = PERCEPIANO_ROOT / 'label_2round_mean_reg_19_with0_rm_highstd0.json'
LABEL_STD_FILE = PERCEPIANO_ROOT / 'label_2round_std_reg_19_with0_rm_highstd0.json'

# Output path
OUTPUT_PATH = Path('/Users/jdhiman/Documents/crescendai/model/data/preprocessed/percepiano_original')
OUTPUT_PATH.mkdir(parents=True, exist_ok=True)

print(f"\nPercePiano root: {PERCEPIANO_ROOT}")
print(f"Data path: {DATA_PATH}")
print(f"Output path: {OUTPUT_PATH}")
print(f"Label file exists: {LABEL_FILE.exists()}")
print(f"Label std file exists: {LABEL_STD_FILE.exists()}")
# Out:
# Python: /Users/jdhiman/Documents/crescendai/model/.venv/bin/python
# Version: 3.11.14 (main, Oct 14 2025, 21:33:50) [Clang 20.1.4 ]
#
# PercePiano root: /Users/jdhiman/Documents/crescendai/model/data/raw/PercePiano
# Data path: /Users/jdhiman/Documents/crescendai/model/data/raw/PercePiano/virtuoso/data
# Output path: /Users/jdhiman/Documents/crescendai/model/data/preprocessed/percepiano_original
# Label file exists: True
# Label std file exists: True

# %%
# Install dependencies
# !uv pip install pandas pretty_midi mido music21 scipy tqdm
# Out:
# Using Python 3.11.14 environment at: /Users/jdhiman/Documents/crescendai/model/.venv
# Resolved 30 packages in 400ms
# ⠙ Preparing packages... (0/4)
# ⠙ Preparing packages... (0/4)--------------     0 B/68.03 KiB
# ⠙ Preparing packages... (0/4)--------------     0 B/68.03 KiB
# more-itertools       ------------------------------     0 B/68.03 KiB
# ⠙ Preparing packages... (0/4)--------------     0 B/194.71 KiB
# more-itertools       ------------------------------ 16.00 KiB/68.03 KiB
# ⠙ Preparing packages... (0/4)--------------     0 B/194.71 KiB
# more-itertools       ------------------------------ 16.00 KiB/68.03 KiB
# ⠙ Preparing packages... (0/4)-------------- 14.92 KiB/194.71 KiB
# more-itertools       ------------------------------ 32.00 KiB/68.03 KiB
# ⠙ Preparing packages... (0/4)-------------- 14.92 KiB/194.71 KiB
# more-itertools       ------------------------------ 48.00 KiB/68.03 KiB
# ⠙ Preparing packages... (0/4)-------------- 14.92 KiB/194.71 KiB
# more-itertools       ------------------------------ 64.00 KiB/68.03 KiB
# ⠙ Preparing packages... (0/4)-------------- 14.92 KiB/194.71 KiB
# more-itertools       ------------------------------ 64.00 KiB/68.03 KiB
# ⠙ Preparing packages... (0/4)-------------- 14.92 KiB/194.71 KiB
# more-itertools       ------------------------------ 64.00 KiB/68.03 KiB
# ⠙ Preparing packages... (0/4)-------------- 14.92 KiB/194.71 KiB
# jsonpickle           ------------------------------     0 B/46.02 KiB
# more-itertools       ------------------------------ 64.00 KiB/68.03 KiB
# ⠙ Preparing packages... (0/4)-------------- 14.92 KiB/194.71 KiB
# jsonpickle           ------------------------------     0 B/46.02 KiB
# more-itertools       ------------------------------ 64.00 KiB/68.03 KiB
# ⠙ Preparing packages... (0/4)-------------- 30.92 KiB/194.71 KiB
# jsonpickle           ------------------------------     0 B/46.02 KiB
# more-itertools       ------------------------------ 68.03 KiB/68.03 KiB
# ⠙ Preparing packages... (0/4)-------------- 30.92 KiB/194.71 KiB
# jsonpickle           ------------------------------     0 B/46.02 KiB
# more-itertools       ------------------------------ 68.03 KiB/68.03 KiB
# ⠙ Preparing packages... (0/4)-------------- 30.92 KiB/194.71 KiB
# jsonpickle           ------------------------------     0 B/46.02 KiB
# ⠙ Preparing packages... (0/4)-------------- 30.92 KiB/194.71 KiB
# jsonpickle           ------------------------------     0 B/46.02 KiB
# ⠙ Preparing packages... (0/4)-------------- 46.92 KiB/194.71 KiB
# jsonpickle           ------------------------------     0 B/46.02 KiB
# ⠙ Preparing packages... (0/4)-------------- 46.92 KiB/194.71 KiB
# jsonpickle           ------------------------------     0 B/46.02 KiB
# ⠙ Preparing packages... (0/4)-------------- 46.92 KiB/194.71 KiB
# jsonpickle           ------------------------------     0 B/46.02 KiB
# chardet              ------------------------------ 46.92 KiB/194.71 KiB
# ⠙ Preparing packages... (0/4)--------------     0 B/19.17 MiB
# chardet              ------------------------------ 139.39 KiB/194.71 KiB
# ⠙ Preparing packages... (0/4)-------------- 14.91 KiB/19.17 MiB
# ⠙ Preparing packages... (0/4)-------------- 94.91 KiB/19.17 MiB
# ⠙ Preparing packages... (0/4)-------------- 622.91 KiB/19.17 MiB
# ⠹ Preparing packages... (3/4)-------------- 1.37 MiB/19.17 MiB
# ⠹ Preparing packages... (3/4)-------------- 2.97 MiB/19.17 MiB
# ⠹ Preparing packages... (3/4)-------------- 3.02 MiB/19.17 MiB
# ⠹ Preparing packages... (3/4)-------------- 3.03 MiB/19.17 MiB
# ⠸ Preparing packages... (3/4)-------------- 4.02 MiB/19.17 MiB
# ⠸ Preparing packages... (3/4)-------------- 4.95 MiB/19.17 MiB
# ⠸ Preparing packages... (3/4)-------------- 7.16 MiB/19.17 MiB
# ⠸ Preparing packages... (3/4)-------------- 8.02 MiB/19.17 MiB
# ⠸ Preparing packages... (3/4)-------------- 9.17 MiB/19.17 MiB
# ⠼ Preparing packages... (3/4)m------------- 10.48 MiB/19.17 MiB
# ⠼ Preparing packages... (3/4)2m------------ 11.42 MiB/19.17 MiB
# ⠼ Preparing packages... (3/4)---------- 12.70 MiB/19.17 MiB
# ⠼ Preparing packages... (3/4)---------- 13.23 MiB/19.17 MiB
# ⠴ Preparing packages... (3/4)---------- 14.18 MiB/19.17 MiB
# ⠴ Preparing packages... (3/4)---------- 16.69 MiB/19.17 MiB
# ⠴ Preparing packages... (3/4)---------- 17.17 MiB/19.17 MiB
# ⠴ Preparing packages... (3/4)---------- 17.36 MiB/19.17 MiB
# ⠦ Preparing packages... (3/4)---------- 17.53 MiB/19.17 MiB
# ⠦ Preparing packages... (3/4)---------- 17.59 MiB/19.17 MiB
# Prepared 4 packages in 1.15s
# Installed 4 packages in 77ms
#  + chardet==5.2.0
#  + jsonpickle==4.1.1
#  + more-itertools==10.8.0
#  + music21==9.9.1

# %%
# Verify data exists
dat_files = list((DATA_PATH / 'all_2rounds').glob('*.dat'))
mid_files = list((DATA_PATH / 'all_2rounds').glob('*.mid'))
xml_files = list((DATA_PATH / 'score_xml').glob('*.musicxml'))
score_midis = list((DATA_PATH / 'score_midi').glob('*.mid'))

print(f"Alignment files (.dat): {len(dat_files)}")
print(f"Performance MIDIs: {len(mid_files)}")
print(f"Score XMLs: {len(xml_files)}")
print(f"Score MIDIs: {len(score_midis)}")
# Out:
# Alignment files (.dat): 1201
# Performance MIDIs: 1202
# Score XMLs: 261
# Score MIDIs: 261

# %%
# Check label file
import json

# Find label file
label_files = list(LABELS_PATH.glob('*.json')) if LABELS_PATH.exists() else []
print(f"Label files in {LABELS_PATH}: {[f.name for f in label_files]}")

# The main label file
LABEL_FILE = PERCEPIANO_ROOT / 'label_2round_mean_reg_19_with0_rm_highstd0.json'
if not LABEL_FILE.exists():
    LABEL_FILE = LABELS_PATH / 'label_2round_mean_reg_19_with0_rm_highstd0.json'

if LABEL_FILE.exists():
    with open(LABEL_FILE) as f:
        labels = json.load(f)
    print(f"\nLoaded {len(labels)} labels from {LABEL_FILE.name}")
    print(f"Sample keys: {list(labels.keys())[:3]}")
else:
    print(f"Label file not found!")
    print(f"Searched: {LABEL_FILE}")
# Out:
# Label files in /Users/jdhiman/Documents/crescendai/model/data/raw/PercePiano/labels: ['label_2round_std_reg_19_with0_rm_highstd0.json', 'label_2round_mean_reg_19_with0_rm_highstd0.json']
#
# Loaded 1202 labels from label_2round_mean_reg_19_with0_rm_highstd0.json
# Sample keys: ['Schubert_D935_no.3_4bars_1_25', 'Beethoven_WoO80_var27_8bars_1_15', 'Beethoven_WoO80_var15_8bars_Score_10']

# %% [markdown]
# ## Step 2: Patch Preprocessing Script

# %%
# Read the original preprocessing script
preprocess_script = PYSCOREPARSER_PATH / 'm2pf_dataset_compositionfold.py'
with open(preprocess_script) as f:
    original_code = f.read()

print("Hardcoded paths in original script:")
for line in original_code.split('\n'):
    if '/root/v2/muzic' in line:
        print(f"  {line.strip()}")
# Out:
# Hardcoded paths in original script:
#   perform_lists = [p for p in perform_lists if ".".join(os.path.basename(p).split(".")[:-1]) in json.load(open("/root/v2/muzic/virtuosonet/label_2round_mean_reg_19_with0_rm_highstd0.json")).keys()]
#   dataset = M2PFSet(path = "/root/v2/muzic/virtuosonet/data", split = "all_2rounds", save=False)
#   all_data = [filename for filename in os.listdir("/root/v2/muzic/virtuosonet/data/all_2rounds") if ".mid" in filename]
#   domain = json.load(open("/root/v2/muzic/virtuosonet/label_2round_mean_reg_19_with0_rm_highstd0.json")).keys()

# %%
# Create patched version of the preprocessing script
patched_code = original_code

# Replace all hardcoded paths
replacements = [
    ('/root/v2/muzic/virtuosonet/data', str(DATA_PATH)),
    ('/root/v2/muzic/virtuosonet/label_2round_mean_reg_19_with0_rm_highstd0.json', str(LABEL_FILE)),
    ('/root/v2/muzic/virtuosonet/label_2round_std_reg_19_with0_rm_highstd0.json', str(LABEL_STD_FILE)),
]

for old, new in replacements:
    patched_code = patched_code.replace(old, new)

# Change output folder to our path
# Original: f"m2pf_allround/composition{num_folds}fold/{fold}"
# Replace with absolute path
patched_code = patched_code.replace(
    'pair_data.save_features_for_virtuosoNet(f"m2pf_allround/composition{num_folds}fold/{fold}"',
    f'pair_data.save_features_for_virtuosoNet(str(Path("{OUTPUT_PATH}") / f"fold{{fold}}")'
)

# Also need to add Path import at the top if not present
if 'from pathlib import Path' not in patched_code:
    patched_code = 'from pathlib import Path\n' + patched_code

# Save patched script
patched_script = PYSCOREPARSER_PATH / 'm2pf_dataset_compositionfold_patched.py'
with open(patched_script, 'w') as f:
    f.write(patched_code)

print(f"Patched script saved to: {patched_script}")
print(f"\nReplacements made:")
for old, new in replacements:
    print(f"  {old[:50]}... -> {new[:50]}...")
# Out:
# Patched script saved to: /Users/jdhiman/Documents/crescendai/model/data/raw/PercePiano/virtuoso/virtuoso/pyScoreParser/m2pf_dataset_compositionfold_patched.py
#
# Replacements made:
#   /root/v2/muzic/virtuosonet/data... -> /Users/jdhiman/Documents/crescendai/model/data/raw...
#   /root/v2/muzic/virtuosonet/label_2round_mean_reg_1... -> /Users/jdhiman/Documents/crescendai/model/data/raw...
#   /root/v2/muzic/virtuosonet/label_2round_std_reg_19... -> /Users/jdhiman/Documents/crescendai/model/data/raw...

# %% [markdown]
# ## Step 3: Run Preprocessing

# %%
# Add paths to Python
sys.path.insert(0, str(VIRTUOSO_PATH))
sys.path.insert(0, str(PYSCOREPARSER_PATH))

print(f"Added to path:")
print(f"  {VIRTUOSO_PATH}")
print(f"  {PYSCOREPARSER_PATH}")
# Out:
# Added to path:
#   /Users/jdhiman/Documents/crescendai/model/data/raw/PercePiano/virtuoso/virtuoso
#   /Users/jdhiman/Documents/crescendai/model/data/raw/PercePiano/virtuoso/virtuoso/pyScoreParser

# %%
# Also patch dataset.py (it has hardcoded paths too)
dataset_script = VIRTUOSO_PATH / 'dataset.py'
with open(dataset_script) as f:
    dataset_code = f.read()

# Patch the label_stds path
dataset_code_patched = dataset_code.replace(
    '/root/v2/muzic/virtuosonet/label_2round_std_reg_19_with0_rm_highstd0.json',
    str(LABEL_STD_FILE)
)

# Save patched dataset.py
dataset_script_backup = VIRTUOSO_PATH / 'dataset_original.py'
if not dataset_script_backup.exists():
    with open(dataset_script_backup, 'w') as f:
        f.write(dataset_code)
    print(f"Original dataset.py backed up to: {dataset_script_backup}")

with open(dataset_script, 'w') as f:
    f.write(dataset_code_patched)
print(f"Patched dataset.py")
# Out:
# Original dataset.py backed up to: /Users/jdhiman/Documents/crescendai/model/data/raw/PercePiano/virtuoso/virtuoso/dataset_original.py
# Patched dataset.py

# %%
# Run the patched preprocessing script
# This will take a while as it extracts features from all performances
import subprocess
import os

env = os.environ.copy()
env['PYTHONPATH'] = f"{VIRTUOSO_PATH}:{PYSCOREPARSER_PATH}"

print("Running preprocessing (this may take 10-30 minutes)...")
print(f"Script: {patched_script}")
print(f"Working dir: {PYSCOREPARSER_PATH}")
print("="*60)

result = subprocess.run(
    [sys.executable, str(patched_script)],
    cwd=str(PYSCOREPARSER_PATH),
    env=env,
    capture_output=True,
    text=True
)

print("STDOUT:")
print(result.stdout[-5000:] if len(result.stdout) > 5000 else result.stdout)

if result.returncode != 0:
    print("\nSTDERR:")
    print(result.stderr[-3000:] if len(result.stderr) > 3000 else result.stderr)
    print(f"\nReturn code: {result.returncode}")
else:
    print("\nPreprocessing completed successfully!")
# Out:
# Running preprocessing (this may take 10-30 minutes)...
# Script: /Users/jdhiman/Documents/crescendai/model/data/raw/PercePiano/virtuoso/virtuoso/pyScoreParser/m2pf_dataset_compositionfold_patched.py
# Working dir: /Users/jdhiman/Documents/crescendai/model/data/raw/PercePiano/virtuoso/virtuoso/pyScoreParser
# ============================================================
# STDOUT:
# perform list length 1201
# list index out of range
# /Users/jdhiman/Documents/crescendai/model/data/raw/PercePiano/virtuoso/data/all_2rounds/Schubert_D935_no.3_4bars_1_50.mid
# list index out of range
# /Users/jdhiman/Documents/crescendai/model/data/raw/PercePiano/virtuoso/data/all_2rounds/Schubert_D935_no.3_4bars_13_50.mid
# list index out of range
# /Users/jdhiman/Documents/crescendai/model/data/raw/PercePiano/virtuoso/data/all_2rounds/Schubert_D935_no.3_4bars_3_50.mid
# list index out of range
# /Users/jdhiman/Documents/crescendai/model/data/raw/PercePiano/virtuoso/data/all_2rounds/Schubert_D935_no.3_4bars_9_50.mid
# list index out of range
# /Users/jdhiman/Documents/crescendai/model/data/raw/PercePiano/virtuoso/data/all_2rounds/Schubert_D935_no.3_4bars_Score2_50.mid
# list index out of range
# /Users/jdhiman/Documents/crescendai/model/data/raw/PercePiano/virtuoso/data/all_2rounds/Schubert_D935_no.3_4bars_Score_50.mid
# list index out of range
# /Users/jdhiman/Documents/crescendai/model/data/raw/PercePiano/virtuoso/data/all_2rounds/Schubert_D935_no.3_4bars_2_50.mid
# list index out of range
# /Users/jdhiman/Documents/crescendai/model/data/raw/PercePiano/virtuoso/data/all_2rounds/Schubert_D935_no.3_4bars_12_50.mid
# list index out of range
# /Users/jdhiman/Documents/crescendai/model/data/raw/PercePiano/virtuoso/data/all_2rounds/Schubert_D935_no.3_4bars_6_50.mid
# all_data 1201
# test_list 187
# count 15
# save features for virtuosoNet /Users/jdhiman/Documents/crescendai/model/data/preprocessed/percepiano_original/fold0
# train, valid, test :  739 266 187
# save features for virtuosoNet m2pf_allround/composition4fold_perffeatonly/0
# train, valid, test :  739 266 187
# save features for virtuosoNet /Users/jdhiman/Documents/crescendai/model/data/preprocessed/percepiano_original/fold1
# train, valid, test :  770 235 187
# save features for virtuosoNet m2pf_allround/composition4fold_perffeatonly/1
# train, valid, test :  770 235 187
# save features for virtuosoNet /Users/jdhiman/Documents/crescendai/model/data/preprocessed/percepiano_original/fold2
# train, valid, test :  759 246 187
# save features for virtuosoNet m2pf_allround/composition4fold_perffeatonly/2
# train, valid, test :  759 246 187
# save features for virtuosoNet /Users/jdhiman/Documents/crescendai/model/data/preprocessed/percepiano_original/fold3
# train, valid, test :  747 258 187
# save features for virtuosoNet m2pf_allround/composition4fold_perffeatonly/3
# train, valid, test :  747 258 187
#
#
# Preprocessing completed successfully!

# %% [markdown]
# ## Step 4: Verify Output

# %%
# Check output
import pickle

for fold in range(4):
    fold_path = OUTPUT_PATH / f'fold{fold}'
    if fold_path.exists():
        print(f"\nFold {fold}:")
        for split in ['train', 'valid', 'test']:
            split_path = fold_path / split
            if split_path.exists():
                pkl_files = list(split_path.glob('*.pkl'))
                print(f"  {split}: {len(pkl_files)} files")
                
                # Check stat.pkl
                stat_file = split_path / 'stat.pkl'
                if stat_file.exists():
                    with open(stat_file, 'rb') as f:
                        stats = pickle.load(f)
                    print(f"    stat.pkl keys: {list(stats.keys())}")
                    if 'key_to_dim' in stats:
                        print(f"    key_to_dim has {len(stats['key_to_dim'])} entries")
# Out:
# Fold 0:
#   train: 740 files
#     stat.pkl keys: ['stats', 'input_keys', 'output_keys', 'measure_keys', 'key_to_dim']
#     key_to_dim has 4 entries
#   valid: 267 files
#     stat.pkl keys: ['stats', 'input_keys', 'output_keys', 'measure_keys', 'key_to_dim']
#     key_to_dim has 4 entries
#   test: 188 files
#     stat.pkl keys: ['stats', 'input_keys', 'output_keys', 'measure_keys', 'key_to_dim']
#     key_to_dim has 4 entries
#
# Fold 1:
#   train: 771 files
#     stat.pkl keys: ['stats', 'input_keys', 'output_keys', 'measure_keys', 'key_to_dim']
#     key_to_dim has 4 entries
#   valid: 236 files
#     stat.pkl keys: ['stats', 'input_keys', 'output_keys', 'measure_keys', 'key_to_dim']
#     key_to_dim has 4 entries
#   test: 188 files
#     stat.pkl keys: ['stats', 'input_keys', 'output_keys', 'measure_keys', 'key_to_dim']
#     key_to_dim has 4 entries
#
# Fold 2:
#   train: 760 files
#     stat.pkl keys: ['stats', 'input_keys', 'output_keys', 'measure_keys', 'key_to_dim']
#     key_to_dim has 4 entries
#   valid: 247 files
#     stat.pkl keys: ['stats', 'input_keys', 'output_keys', 'measure_keys', 'key_to_dim']
#     key_to_dim has 4 entries
#   test: 188 files
#     stat.pkl keys: ['stats', 'input_keys', 'output_keys', 'measure_keys', 'key_to_dim']
#     key_to_dim has 4 entries
#
# Fold 3:
#   train: 748 files
#     stat.pkl keys: ['stats', 'input_keys', 'output_keys', 'measure_keys', 'key_to_dim']
#     key_to_dim has 4 entries
#   valid: 259 files
#     stat.pkl keys: ['stats', 'input_keys', 'output_keys', 'measure_keys', 'key_to_dim']
#     key_to_dim has 4 entries
#   test: 188 files
#     stat.pkl keys: ['stats', 'input_keys', 'output_keys', 'measure_keys', 'key_to_dim']
#     key_to_dim has 4 entries

# %%
# Check a sample file
import numpy as np

fold0_train = OUTPUT_PATH / 'fold0' / 'train'
if fold0_train.exists():
    sample_files = [f for f in fold0_train.glob('*.pkl') if f.name != 'stat.pkl']
    if sample_files:
        with open(sample_files[0], 'rb') as f:
            sample = pickle.load(f)
        
        print(f"Sample file: {sample_files[0].name}")
        print(f"Keys: {list(sample.keys())}")
        
        if 'input' in sample:
            inp = np.array(sample['input'])
            print(f"Input shape: {inp.shape}")
        
        if 'note_location' in sample:
            print(f"note_location keys: {list(sample['note_location'].keys())}")
# Out:
# Sample file: all_2rounds_Schubert_D960_mv2_8bars_2_13.mid.pkl
# Keys: ['input', 'output', 'beat', 'meas', 'note_location', 'align_matched', 'articulation_loss_weight', 'graph', 'score_path', 'perform_path']
# Input shape: (143, 101)
# note_location keys: ['beat', 'measure', 'voice', 'section']

# %% [markdown]
# ## Step 5: Upload to Google Drive

# %%
# Upload to GDrive for Thunder Compute
import subprocess

GDRIVE_PATH = 'gdrive:crescendai_data/percepiano_original'

print(f"Uploading {OUTPUT_PATH} to {GDRIVE_PATH}...")
result = subprocess.run(
    ['rclone', 'copy', str(OUTPUT_PATH), GDRIVE_PATH, '--progress'],
    capture_output=False
)

print("\nUpload complete!")
# Out:
# Uploading /Users/jdhiman/Documents/crescendai/model/data/preprocessed/percepiano_original to gdrive:crescendai_data/percepiano_original...
# Transferred:   	          0 B / 789.159 MiB, 0%, 0 B/s, ETA -
# Checks:                 0 / 0, -, Listed 4796
# Transferred:            0 / 4780, 0%
# Elapsed time:         0.4s
# Transferring:
#  * fold2/test/all_2rounds…15_8bars_11_10.mid.pkl:  0% /205.401Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_14_10.mid.pkl:  0% /207.770Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_18_10.mid.pkl:  0% /205.127Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_19_10.mid.pkl:  0% /208.243Ki, 0/s, -Transferred:   	          0 B / 789.159 MiB, 0%, 0 B/s, ETA -
# Checks:                 0 / 0, -, Listed 4796
# Transferred:            0 / 4780, 0%
# Elapsed time:         0.9s
# Transferring:
#  * fold2/test/all_2rounds…15_8bars_11_10.mid.pkl:  0% /205.401Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_14_10.mid.pkl:  0% /207.770Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_18_10.mid.pkl:  0% /205.127Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_19_10.mid.pkl:  0% /208.243Ki, 0/s, -Transferred:   	          0 B / 789.159 MiB, 0%, 0 B/s, ETA -
# Checks:                 0 / 0, -, Listed 4796
# Transferred:            0 / 4780, 0%
# Elapsed time:         1.4s
# Transferring:
#  * fold2/test/all_2rounds…15_8bars_11_10.mid.pkl:  0% /205.401Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_14_10.mid.pkl:  0% /207.770Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_18_10.mid.pkl:  0% /205.127Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_19_10.mid.pkl:  0% /208.243Ki, 0/s, -Transferred:   	          0 B / 789.159 MiB, 0%, 0 B/s, ETA -
# Checks:                 0 / 0, -, Listed 4796
# Transferred:            0 / 4780, 0%
# Elapsed time:         1.9s
# Transferring:
#  * fold2/test/all_2rounds…15_8bars_11_10.mid.pkl:  0% /205.401Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_14_10.mid.pkl:  0% /207.770Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_18_10.mid.pkl:  0% /205.127Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_19_10.mid.pkl:  0% /208.243Ki, 0/s, -Transferred:   	          0 B / 789.159 MiB, 0%, 0 B/s, ETA -
# Checks:                 0 / 0, -, Listed 4796
# Transferred:            0 / 4780, 0%
# Elapsed time:         2.4s
# Transferring:
#  * fold2/test/all_2rounds…15_8bars_11_10.mid.pkl:  0% /205.401Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_14_10.mid.pkl:  0% /207.770Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_18_10.mid.pkl:  0% /205.127Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_19_10.mid.pkl:  0% /208.243Ki, 0/s, -Transferred:   	  207.770 KiB / 789.159 MiB, 0%, 0 B/s, ETA -
# Checks:                 0 / 0, -, Listed 4796
# Transferred:            0 / 4780, 0%
# Elapsed time:         2.9s
# Transferring:
#  * fold2/test/all_2rounds…15_8bars_11_10.mid.pkl:  0% /205.401Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_14_10.mid.pkl:100% /207.770Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_18_10.mid.pkl:  0% /205.127Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_19_10.mid.pkl:  0% /208.243Ki, 0/s, -Transferred:   	  826.541 KiB / 789.159 MiB, 0%, 69.256 KiB/s, ETA 3h14m16s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:            0 / 4780, 0%
# Elapsed time:         3.4s
# Transferring:
#  * fold2/test/all_2rounds…15_8bars_11_10.mid.pkl:100% /205.401Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_14_10.mid.pkl:100% /207.770Ki, 69.255Ki/s,
#  * fold2/test/all_2rounds…15_8bars_18_10.mid.pkl:100% /205.127Ki, 68.374Ki/s,
#  * fold2/test/all_2rounds…15_8bars_19_10.mid.pkl:100% /208.243Ki, 69.413Ki/s, Transferred:   	  826.541 KiB / 789.159 MiB, 0%, 69.256 KiB/s, ETA 3h14m16s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:            0 / 4780, 0%
# Elapsed time:         3.9s
# Transferring:
#  * fold2/test/all_2rounds…15_8bars_11_10.mid.pkl:100% /205.401Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_14_10.mid.pkl:100% /207.770Ki, 69.255Ki/s,
#  * fold2/test/all_2rounds…15_8bars_18_10.mid.pkl:100% /205.127Ki, 68.374Ki/s,
#  * fold2/test/all_2rounds…15_8bars_19_10.mid.pkl:100% /208.243Ki, 69.413Ki/s, Transferred:   	  826.541 KiB / 789.159 MiB, 0%, 206.635 KiB/s, ETA 1h5m6s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:            4 / 4780, 0%
# Elapsed time:         4.4s
# Transferring:
#  * fold2/test/all_2rounds…r15_8bars_1_10.mid.pkl:  0% /205.845Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_22_10.mid.pkl:  0% /203.699Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_24_10.mid.pkl:  0% /204.599Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_26_10.mid.pkl:  0% /203.041Ki, 0/s, -Transferred:   	    1.605 MiB / 789.159 MiB, 0%, 206.635 KiB/s, ETA 1h5m2s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:            4 / 4780, 0%
# Elapsed time:         4.9s
# Transferring:
#  * fold2/test/all_2rounds…r15_8bars_1_10.mid.pkl:100% /205.845Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_22_10.mid.pkl:100% /203.699Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_24_10.mid.pkl:100% /204.599Ki, 0/s, -
#  * fold2/test/all_2rounds…15_8bars_26_10.mid.pkl:100% /203.041Ki, 0/s, -Transferred:   	    1.605 MiB / 789.159 MiB, 0%, 328.746 KiB/s, ETA 40m53s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:            4 / 4780, 0%
# Elapsed time:         5.4s
# Transferring:
#  * fold2/test/all_2rounds…r15_8bars_1_10.mid.pkl:100% /205.845Ki, 205.839Ki/s,
#  * fold2/test/all_2rounds…15_8bars_22_10.mid.pkl:100% /203.699Ki, 203.689Ki/s,
#  * fold2/test/all_2rounds…15_8bars_24_10.mid.pkl:100% /204.599Ki, 204.587Ki/s,
#  * fold2/test/all_2rounds…15_8bars_26_10.mid.pkl:100% /203.041Ki, 203.036Ki/s,Transferred:   	    2.413 MiB / 789.159 MiB, 0%, 328.746 KiB/s, ETA 40m50s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:            8 / 4780, 0%
# Elapsed time:         5.9s
# Transferring:
#  * fold2/test/all_2rounds…r15_8bars_2_10.mid.pkl:100% /203.893Ki, 0/s, -
#  * fold2/test/all_2rounds…r15_8bars_3_10.mid.pkl:100% /211.416Ki, 0/s, -
#  * fold2/test/all_2rounds…r15_8bars_4_10.mid.pkl:100% /202.642Ki, 0/s, -
#  * fold2/test/all_2rounds…r15_8bars_7_10.mid.pkl:100% /209.042Ki, 0/s, -Transferred:   	    2.413 MiB / 789.159 MiB, 0%, 411.784 KiB/s, ETA 32m36s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:            8 / 4780, 0%
# Elapsed time:         6.4s
# Transferring:
#  * fold2/test/all_2rounds…r15_8bars_2_10.mid.pkl:100% /203.893Ki, 0/s, -
#  * fold2/test/all_2rounds…r15_8bars_3_10.mid.pkl:100% /211.416Ki, 0/s, -
#  * fold2/test/all_2rounds…r15_8bars_4_10.mid.pkl:100% /202.642Ki, 0/s, -
#  * fold2/test/all_2rounds…r15_8bars_7_10.mid.pkl:100% /209.042Ki, 0/s, -Transferred:   	    2.413 MiB / 789.159 MiB, 0%, 411.784 KiB/s, ETA 32m36s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           10 / 4780, 0%
# Elapsed time:         6.9s
# Transferring:
#  * fold2/test/all_2rounds…r15_8bars_4_10.mid.pkl:100% /202.642Ki, 202.632Ki/s,
#  * fold2/test/all_2rounds…r15_8bars_7_10.mid.pkl:100% /209.042Ki, 209.031Ki/s,
#  * fold2/test/all_2rounds…bars_Score2_10.mid.pkl:  0% /207.353Ki, 0/s, -
#  * fold2/test/all_2rounds…8bars_Score_10.mid.pkl:  0% /205.164Ki, 0/s, -Transferred:   	    3.345 MiB / 789.159 MiB, 0%, 352.958 KiB/s, ETA 37m59s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           12 / 4780, 0%
# Elapsed time:         7.4s
# Transferring:
#  * fold2/test/all_2rounds…bars_Score2_10.mid.pkl:100% /207.353Ki, 0/s, -
#  * fold2/test/all_2rounds…8bars_Score_10.mid.pkl:100% /205.164Ki, 0/s, -
#  * fold2/test/all_2rounds…23_8bars_11_13.mid.pkl:100% /270.628Ki, 0/s, -
#  * fold2/test/all_2rounds…23_8bars_14_13.mid.pkl:100% /271.606Ki, 0/s, -Transferred:   	    3.345 MiB / 789.159 MiB, 0%, 352.958 KiB/s, ETA 37m59s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           12 / 4780, 0%
# Elapsed time:         7.9s
# Transferring:
#  * fold2/test/all_2rounds…bars_Score2_10.mid.pkl:100% /207.353Ki, 207.337Ki/s,
#  * fold2/test/all_2rounds…8bars_Score_10.mid.pkl:100% /205.164Ki, 205.150Ki/s,
#  * fold2/test/all_2rounds…23_8bars_11_13.mid.pkl:100% /270.628Ki, 0/s, -
#  * fold2/test/all_2rounds…23_8bars_14_13.mid.pkl:100% /271.606Ki, 0/s, -Transferred:   	    3.883 MiB / 789.159 MiB, 0%, 428.182 KiB/s, ETA 31m17s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           14 / 4780, 0%
# Elapsed time:         8.4s
# Transferring:
#  * fold2/test/all_2rounds…23_8bars_11_13.mid.pkl:100% /270.628Ki, 270.610Ki/s,
#  * fold2/test/all_2rounds…23_8bars_14_13.mid.pkl:100% /271.606Ki, 271.594Ki/s,
#  * fold2/test/all_2rounds…23_8bars_18_13.mid.pkl:100% /272.769Ki, 0/s, -
#  * fold2/test/all_2rounds…23_8bars_19_13.mid.pkl:100% /277.569Ki, 0/s, -Transferred:   	    4.418 MiB / 789.159 MiB, 1%, 428.182 KiB/s, ETA 31m16s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           16 / 4780, 0%
# Elapsed time:         8.9s
# Transferring:
#  * fold2/test/all_2rounds…23_8bars_18_13.mid.pkl:100% /272.769Ki, 0/s, -
#  * fold2/test/all_2rounds…23_8bars_19_13.mid.pkl:100% /277.569Ki, 0/s, -
#  * fold2/test/all_2rounds…r23_8bars_1_13.mid.pkl:100% /275.976Ki, 0/s, -
#  * fold2/test/all_2rounds…23_8bars_22_13.mid.pkl:100% /271.909Ki, 0/s, -Transferred:   	    4.418 MiB / 789.159 MiB, 1%, 502.634 KiB/s, ETA 26m38s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           18 / 4780, 0%
# Elapsed time:         9.4s
# Transferring:
#  * fold2/test/all_2rounds…r23_8bars_1_13.mid.pkl:100% /275.976Ki, 0/s, -
#  * fold2/test/all_2rounds…23_8bars_22_13.mid.pkl:100% /271.909Ki, 0/s, -
#  * fold2/test/all_2rounds…23_8bars_24_13.mid.pkl:  0% /272.568Ki, 0/s, -
#  * fold2/test/all_2rounds…23_8bars_26_13.mid.pkl:  0% /271.451Ki, 0/s, -Transferred:   	    4.949 MiB / 789.159 MiB, 1%, 502.634 KiB/s, ETA 26m37s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           19 / 4780, 0%
# Elapsed time:         9.9s
# Transferring:
#  * fold2/test/all_2rounds…r23_8bars_1_13.mid.pkl:100% /275.976Ki, 275.968Ki/s,
#  * fold2/test/all_2rounds…23_8bars_24_13.mid.pkl:100% /272.568Ki, 0/s, -
#  * fold2/test/all_2rounds…23_8bars_26_13.mid.pkl:100% /271.451Ki, 0/s, -
#  * fold2/test/all_2rounds…r23_8bars_2_13.mid.pkl:  0% /276.685Ki, 0/s, -Transferred:   	    5.484 MiB / 789.159 MiB, 1%, 506.772 KiB/s, ETA 26m23s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           20 / 4780, 0%
# Elapsed time:        10.4s
# Transferring:
#  * fold2/test/all_2rounds…23_8bars_24_13.mid.pkl:100% /272.568Ki, 272.551Ki/s,
#  * fold2/test/all_2rounds…23_8bars_26_13.mid.pkl:100% /271.451Ki, 271.444Ki/s,
#  * fold2/test/all_2rounds…r23_8bars_2_13.mid.pkl:100% /276.685Ki, 0/s, -
#  * fold2/test/all_2rounds…r23_8bars_3_13.mid.pkl:100% /270.722Ki, 0/s, -Transferred:   	    6.012 MiB / 789.159 MiB, 1%, 506.772 KiB/s, ETA 26m22s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           22 / 4780, 0%
# Elapsed time:        10.9s
# Transferring:
#  * fold2/test/all_2rounds…r23_8bars_2_13.mid.pkl:100% /276.685Ki, 276.676Ki/s,
#  * fold2/test/all_2rounds…r23_8bars_3_13.mid.pkl:100% /270.722Ki, 0/s, -
#  * fold2/test/all_2rounds…r23_8bars_4_13.mid.pkl:100% /271.344Ki, 0/s, -
#  * fold2/test/all_2rounds…r23_8bars_7_13.mid.pkl:100% /270.285Ki, 0/s, -Transferred:   	    6.549 MiB / 789.159 MiB, 1%, 559.703 KiB/s, ETA 23m51s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           24 / 4780, 1%
# Elapsed time:        11.4s
# Transferring:
#  * fold2/test/all_2rounds…r23_8bars_4_13.mid.pkl:100% /271.344Ki, 0/s, -
#  * fold2/test/all_2rounds…r23_8bars_7_13.mid.pkl:100% /270.285Ki, 0/s, -
#  * fold2/test/all_2rounds…bars_Score2_13.mid.pkl:100% /274.889Ki, 0/s, -
#  * fold2/test/all_2rounds…8bars_Score_13.mid.pkl:100% /274.327Ki, 0/s, -Transferred:   	    6.549 MiB / 789.159 MiB, 1%, 559.703 KiB/s, ETA 23m51s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           25 / 4780, 1%
# Elapsed time:        11.9s
# Transferring:
#  * fold2/test/all_2rounds…r23_8bars_7_13.mid.pkl:100% /270.285Ki, 270.271Ki/s,
#  * fold2/test/all_2rounds…bars_Score2_13.mid.pkl:100% /274.889Ki, 0/s, -
#  * fold2/test/all_2rounds…8bars_Score_13.mid.pkl:100% /274.327Ki, 0/s, -
#  * fold2/test/all_2rounds…27_8bars_11_15.mid.pkl:  0% /291.620Ki, 0/s, -Transferred:   	    7.106 MiB / 789.159 MiB, 1%, 558.829 KiB/s, ETA 23m53s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           26 / 4780, 1%
# Elapsed time:        12.4s
# Transferring:
#  * fold2/test/all_2rounds…bars_Score2_13.mid.pkl:100% /274.889Ki, 274.865Ki/s,
#  * fold2/test/all_2rounds…8bars_Score_13.mid.pkl:100% /274.327Ki, 274.315Ki/s,
#  * fold2/test/all_2rounds…27_8bars_11_15.mid.pkl:100% /291.620Ki, 0/s, -
#  * fold2/test/all_2rounds…27_8bars_14_15.mid.pkl:100% /279.211Ki, 0/s, -Transferred:   	    7.654 MiB / 789.159 MiB, 1%, 558.829 KiB/s, ETA 23m52s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           28 / 4780, 1%
# Elapsed time:        12.9s
# Transferring:
#  * fold2/test/all_2rounds…27_8bars_11_15.mid.pkl:100% /291.620Ki, 291.603Ki/s,
#  * fold2/test/all_2rounds…27_8bars_14_15.mid.pkl:100% /279.211Ki, 0/s, -
#  * fold2/test/all_2rounds…27_8bars_18_15.mid.pkl:100% /279.183Ki, 0/s, -
#  * fold2/test/all_2rounds…27_8bars_19_15.mid.pkl:100% /281.500Ki, 0/s, -Transferred:   	    8.194 MiB / 789.159 MiB, 1%, 602.882 KiB/s, ETA 22m6s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           30 / 4780, 1%
# Elapsed time:        13.4s
# Transferring:
#  * fold2/test/all_2rounds…27_8bars_18_15.mid.pkl:100% /279.183Ki, 0/s, -
#  * fold2/test/all_2rounds…27_8bars_19_15.mid.pkl:100% /281.500Ki, 0/s, -
#  * fold2/test/all_2rounds…r27_8bars_1_15.mid.pkl:100% /279.347Ki, 0/s, -
#  * fold2/test/all_2rounds…27_8bars_22_15.mid.pkl:100% /273.955Ki, 0/s, -Transferred:   	    8.737 MiB / 789.159 MiB, 1%, 602.882 KiB/s, ETA 22m5s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           32 / 4780, 1%
# Elapsed time:        13.9s
# Transferring:
#  * fold2/test/all_2rounds…r27_8bars_1_15.mid.pkl:100% /279.347Ki, 0/s, -
#  * fold2/test/all_2rounds…27_8bars_22_15.mid.pkl:100% /273.955Ki, 0/s, -
#  * fold2/test/all_2rounds…27_8bars_24_15.mid.pkl:100% /281.003Ki, 0/s, -
#  * fold2/test/all_2rounds…27_8bars_26_15.mid.pkl:100% /274.913Ki, 0/s, -Transferred:   	    8.737 MiB / 789.159 MiB, 1%, 639.048 KiB/s, ETA 20m50s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           32 / 4780, 1%
# Elapsed time:        14.4s
# Transferring:
#  * fold2/test/all_2rounds…r27_8bars_1_15.mid.pkl:100% /279.347Ki, 279.334Ki/s,
#  * fold2/test/all_2rounds…27_8bars_22_15.mid.pkl:100% /273.955Ki, 273.936Ki/s,
#  * fold2/test/all_2rounds…27_8bars_24_15.mid.pkl:100% /281.003Ki, 0/s, -
#  * fold2/test/all_2rounds…27_8bars_26_15.mid.pkl:100% /274.913Ki, 0/s, -Transferred:   	    9.296 MiB / 789.159 MiB, 1%, 639.048 KiB/s, ETA 20m49s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           35 / 4780, 1%
# Elapsed time:        14.9s
# Transferring:
#  * fold2/test/all_2rounds…27_8bars_26_15.mid.pkl:100% /274.913Ki, 274.898Ki/s,
#  * fold2/test/all_2rounds…r27_8bars_2_15.mid.pkl:100% /277.787Ki, 0/s, -
#  * fold2/test/all_2rounds…r27_8bars_3_15.mid.pkl:100% /294.992Ki, 0/s, -
#  * fold2/test/all_2rounds…r27_8bars_4_15.mid.pkl:  0% /275.781Ki, 0/s, -Transferred:   	    9.835 MiB / 789.159 MiB, 1%, 634.631 KiB/s, ETA 20m57s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           36 / 4780, 1%
# Elapsed time:        15.4s
# Transferring:
#  * fold2/test/all_2rounds…r27_8bars_2_15.mid.pkl:100% /277.787Ki, 0/s, -
#  * fold2/test/all_2rounds…r27_8bars_3_15.mid.pkl:100% /294.992Ki, 0/s, -
#  * fold2/test/all_2rounds…r27_8bars_4_15.mid.pkl:100% /275.781Ki, 0/s, -
#  * fold2/test/all_2rounds…r27_8bars_7_15.mid.pkl:100% /276.255Ki, 0/s, -Transferred:   	   10.096 MiB / 789.159 MiB, 1%, 634.631 KiB/s, ETA 20m57s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           38 / 4780, 1%
# Elapsed time:        15.9s
# Transferring:
#  * fold2/test/all_2rounds…r27_8bars_4_15.mid.pkl:100% /275.781Ki, 275.767Ki/s,
#  * fold2/test/all_2rounds…r27_8bars_7_15.mid.pkl:100% /276.255Ki, 0/s, -
#  * fold2/test/all_2rounds…bars_Score2_15.mid.pkl:100% /267.116Ki, 0/s, -
#  * fold2/test/all_2rounds…8bars_Score_15.mid.pkl:  0% /269.164Ki, 0/s, -Transferred:   	   10.359 MiB / 789.159 MiB, 1%, 646.163 KiB/s, ETA 20m34s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           40 / 4780, 1%
# Elapsed time:        16.4s
# Transferring:
#  * fold2/test/all_2rounds…bars_Score2_15.mid.pkl:100% /267.116Ki, 0/s, -
#  * fold2/test/all_2rounds…8bars_Score_15.mid.pkl:100% /269.164Ki, 0/s, -
#  * fold2/test/all_2rounds…30_8bars_14_17.mid.pkl:  0% /119.847Ki, 0/s, -
#  * fold2/test/all_2rounds…30_8bars_11_17.mid.pkl:  0% /119.188Ki, 0/s, -Transferred:   	   10.593 MiB / 789.159 MiB, 1%, 646.163 KiB/s, ETA 20m33s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           41 / 4780, 1%
# Elapsed time:        16.9s
# Transferring:
#  * fold2/test/all_2rounds…8bars_Score_15.mid.pkl:100% /269.164Ki, 269.144Ki/s,
#  * fold2/test/all_2rounds…30_8bars_14_17.mid.pkl:100% /119.847Ki, 0/s, -
#  * fold2/test/all_2rounds…30_8bars_11_17.mid.pkl:100% /119.188Ki, 0/s, -
#  * fold2/test/all_2rounds…30_8bars_18_17.mid.pkl:  0% /119.997Ki, 0/s, -Transferred:   	   10.828 MiB / 789.159 MiB, 1%, 637.540 KiB/s, ETA 20m50s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           42 / 4780, 1%
# Elapsed time:        17.4s
# Transferring:
#  * fold2/test/all_2rounds…30_8bars_14_17.mid.pkl:100% /119.847Ki, 119.836Ki/s,
#  * fold2/test/all_2rounds…30_8bars_11_17.mid.pkl:100% /119.188Ki, 119.180Ki/s,
#  * fold2/test/all_2rounds…30_8bars_18_17.mid.pkl:100% /119.997Ki, 0/s, -
#  * fold2/test/all_2rounds…30_8bars_19_17.mid.pkl:100% /120.635Ki, 0/s, -Transferred:   	   10.828 MiB / 789.159 MiB, 1%, 637.540 KiB/s, ETA 20m50s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           44 / 4780, 1%
# Elapsed time:        17.9s
# Transferring:
#  * fold2/test/all_2rounds…30_8bars_18_17.mid.pkl:100% /119.997Ki, 119.990Ki/s,
#  * fold2/test/all_2rounds…30_8bars_19_17.mid.pkl:100% /120.635Ki, 0/s, -
#  * fold2/test/all_2rounds…r30_8bars_1_17.mid.pkl:  0% /122.468Ki, 0/s, -
#  * fold2/test/all_2rounds…30_8bars_22_17.mid.pkl:  0% /119.654Ki, 0/s, -Transferred:   	   11.181 MiB / 789.159 MiB, 1%, 612.733 KiB/s, ETA 21m40s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           46 / 4780, 1%
# Elapsed time:        18.4s
# Transferring:
#  * fold2/test/all_2rounds…r30_8bars_1_17.mid.pkl:100% /122.468Ki, 0/s, -
#  * fold2/test/all_2rounds…30_8bars_22_17.mid.pkl:100% /119.654Ki, 0/s, -
#  * fold2/test/all_2rounds…30_8bars_24_17.mid.pkl:100% /119.435Ki, 0/s, -
#  * fold2/test/all_2rounds…30_8bars_26_17.mid.pkl:  0% /119.479Ki, 0/s, -Transferred:   	   11.297 MiB / 789.159 MiB, 1%, 612.733 KiB/s, ETA 21m39s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           46 / 4780, 1%
# Elapsed time:        18.9s
# Transferring:
#  * fold2/test/all_2rounds…r30_8bars_1_17.mid.pkl:100% /122.468Ki, 122.461Ki/s,
#  * fold2/test/all_2rounds…30_8bars_22_17.mid.pkl:100% /119.654Ki, 119.646Ki/s,
#  * fold2/test/all_2rounds…30_8bars_24_17.mid.pkl:100% /119.435Ki, 0/s, -
#  * fold2/test/all_2rounds…30_8bars_26_17.mid.pkl:100% /119.479Ki, 0/s, -Transferred:   	   11.648 MiB / 789.159 MiB, 1%, 604.502 KiB/s, ETA 21m57s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           49 / 4780, 1%
# Elapsed time:        19.4s
# Transferring:
#  * fold2/test/all_2rounds…30_8bars_26_17.mid.pkl:100% /119.479Ki, 119.473Ki/s,
#  * fold2/test/all_2rounds…r30_8bars_2_17.mid.pkl:100% /119.502Ki, 0/s, -
#  * fold2/test/all_2rounds…r30_8bars_3_17.mid.pkl:100% /119.623Ki, 0/s, -
#  * fold2/test/all_2rounds…r30_8bars_4_17.mid.pkl:100% /119.479Ki, 0/s, -Transferred:   	   11.766 MiB / 789.159 MiB, 1%, 604.502 KiB/s, ETA 21m56s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           50 / 4780, 1%
# Elapsed time:        19.9s
# Transferring:
#  * fold2/test/all_2rounds…r30_8bars_2_17.mid.pkl:100% /119.502Ki, 0/s, -
#  * fold2/test/all_2rounds…r30_8bars_3_17.mid.pkl:100% /119.623Ki, 0/s, -
#  * fold2/test/all_2rounds…r30_8bars_4_17.mid.pkl:100% /119.479Ki, 0/s, -
#  * fold2/test/all_2rounds…r30_8bars_7_17.mid.pkl:100% /120.924Ki, 0/s, -Transferred:   	   11.766 MiB / 789.159 MiB, 1%, 596.690 KiB/s, ETA 22m14s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           52 / 4780, 1%
# Elapsed time:        20.4s
# Transferring:
#  * fold2/test/all_2rounds…r30_8bars_4_17.mid.pkl:100% /119.479Ki, 119.474Ki/s,
#  * fold2/test/all_2rounds…r30_8bars_7_17.mid.pkl:100% /120.924Ki, 0/s, -
#  * fold2/test/all_2rounds…bars_Score2_17.mid.pkl:  0% /121.731Ki, 0/s, -
#  * fold2/test/all_2rounds…8bars_Score_17.mid.pkl:  0% /121.371Ki, 0/s, -Transferred:   	   12.400 MiB / 789.159 MiB, 2%, 596.690 KiB/s, ETA 22m13s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           54 / 4780, 1%
# Elapsed time:        20.9s
# Transferring:
#  * fold2/test/all_2rounds…bars_Score2_17.mid.pkl:100% /121.731Ki, 0/s, -
#  * fold2/test/all_2rounds…8bars_Score_17.mid.pkl:100% /121.371Ki, 0/s, -
#  * fold2/test/all_2rounds….3_4bars_12_29.mid.pkl:100% /239.013Ki, 0/s, -
#  * fold2/test/all_2rounds….3_4bars_12_37.mid.pkl:100% /167.276Ki, 0/s, -Transferred:   	   12.400 MiB / 789.159 MiB, 2%, 599.984 KiB/s, ETA 22m5s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           54 / 4780, 1%
# Elapsed time:        21.4s
# Transferring:
#  * fold2/test/all_2rounds…bars_Score2_17.mid.pkl:100% /121.731Ki, 121.726Ki/s,
#  * fold2/test/all_2rounds…8bars_Score_17.mid.pkl:100% /121.371Ki, 121.366Ki/s,
#  * fold2/test/all_2rounds….3_4bars_12_29.mid.pkl:100% /239.013Ki, 0/s, -
#  * fold2/test/all_2rounds….3_4bars_12_37.mid.pkl:100% /167.276Ki, 0/s, -Transferred:   	   12.798 MiB / 789.159 MiB, 2%, 599.984 KiB/s, ETA 22m5s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           57 / 4780, 1%
# Elapsed time:        21.9s
# Transferring:
#  * fold2/test/all_2rounds….3_4bars_12_37.mid.pkl:100% /167.276Ki, 167.266Ki/s,
#  * fold2/test/all_2rounds….3_4bars_12_46.mid.pkl:100% /171.702Ki, 0/s, -
#  * fold2/test/all_2rounds….3_4bars_13_29.mid.pkl:100% /236.304Ki, 0/s, -
#  * fold2/test/all_2rounds….3_4bars_13_37.mid.pkl:  0% /158.875Ki, 0/s, -Transferred:   	   13.124 MiB / 789.159 MiB, 2%, 587.986 KiB/s, ETA 22m31s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           58 / 4780, 1%
# Elapsed time:        22.4s
# Transferring:
#  * fold2/test/all_2rounds….3_4bars_12_46.mid.pkl:100% /171.702Ki, 0/s, -
#  * fold2/test/all_2rounds….3_4bars_13_29.mid.pkl:100% /236.304Ki, 0/s, -
#  * fold2/test/all_2rounds….3_4bars_13_37.mid.pkl:100% /158.875Ki, 0/s, -
#  * fold2/test/all_2rounds….3_4bars_13_46.mid.pkl:100% /174.977Ki, 0/s, -Transferred:   	   13.124 MiB / 789.159 MiB, 2%, 587.986 KiB/s, ETA 22m31s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           59 / 4780, 1%
# Elapsed time:        22.9s
# Transferring:
#  * fold2/test/all_2rounds….3_4bars_13_29.mid.pkl:100% /236.304Ki, 236.286Ki/s,
#  * fold2/test/all_2rounds….3_4bars_13_37.mid.pkl:100% /158.875Ki, 158.865Ki/s,
#  * fold2/test/all_2rounds….3_4bars_13_46.mid.pkl:100% /174.977Ki, 0/s, -
#  * fold2/test/all_2rounds…o.3_4bars_1_29.mid.pkl:  0% /231.603Ki, 0/s, -Transferred:   	   13.673 MiB / 789.159 MiB, 2%, 572.103 KiB/s, ETA 23m8s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           61 / 4780, 1%
# Elapsed time:        23.4s
# Transferring:
#  * fold2/test/all_2rounds….3_4bars_13_46.mid.pkl:100% /174.977Ki, 174.936Ki/s,
#  * fold2/test/all_2rounds…o.3_4bars_1_29.mid.pkl:100% /231.603Ki, 0/s, -
#  * fold2/test/all_2rounds…o.3_4bars_1_37.mid.pkl:100% /154.311Ki, 0/s, -
#  * fold2/test/all_2rounds…o.3_4bars_1_46.mid.pkl:100% /176.051Ki, 0/s, -Transferred:   	   13.897 MiB / 789.159 MiB, 2%, 572.103 KiB/s, ETA 23m7s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           62 / 4780, 1%
# Elapsed time:        23.9s
# Transferring:
#  * fold2/test/all_2rounds…o.3_4bars_1_29.mid.pkl:100% /231.603Ki, 231.585Ki/s,
#  * fold2/test/all_2rounds…o.3_4bars_1_37.mid.pkl:100% /154.311Ki, 0/s, -
#  * fold2/test/all_2rounds…o.3_4bars_1_46.mid.pkl:100% /176.051Ki, 0/s, -
#  * fold2/test/all_2rounds…o.3_4bars_2_29.mid.pkl:100% /229.203Ki, 0/s, -Transferred:   	   14.049 MiB / 789.159 MiB, 2%, 585.794 KiB/s, ETA 22m34s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           64 / 4780, 1%
# Elapsed time:        24.4s
# Transferring:
#  * fold2/test/all_2rounds…o.3_4bars_1_46.mid.pkl:100% /176.051Ki, 176.040Ki/s,
#  * fold2/test/all_2rounds…o.3_4bars_2_29.mid.pkl:100% /229.203Ki, 0/s, -
#  * fold2/test/all_2rounds…o.3_4bars_2_37.mid.pkl:100% /155.973Ki, 0/s, -
#  * fold2/test/all_2rounds…o.3_4bars_2_46.mid.pkl:  0% /169.310Ki, 0/s, -Transferred:   	   14.437 MiB / 789.159 MiB, 2%, 585.794 KiB/s, ETA 22m34s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           66 / 4780, 1%
# Elapsed time:        24.9s
# Transferring:
#  * fold2/test/all_2rounds…o.3_4bars_2_37.mid.pkl:100% /155.973Ki, 0/s, -
#  * fold2/test/all_2rounds…o.3_4bars_2_46.mid.pkl:100% /169.310Ki, 0/s, -
#  * fold2/test/all_2rounds…o.3_4bars_3_29.mid.pkl:100% /228.267Ki, 0/s, -
#  * fold2/test/all_2rounds…o.3_4bars_3_37.mid.pkl:  0% /155.807Ki, 0/s, -Transferred:   	   14.590 MiB / 789.159 MiB, 2%, 587.779 KiB/s, ETA 22m29s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           66 / 4780, 1%
# Elapsed time:        25.4s
# Transferring:
#  * fold2/test/all_2rounds…o.3_4bars_2_37.mid.pkl:100% /155.973Ki, 155.968Ki/s,
#  * fold2/test/all_2rounds…o.3_4bars_2_46.mid.pkl:100% /169.310Ki, 169.297Ki/s,
#  * fold2/test/all_2rounds…o.3_4bars_3_29.mid.pkl:100% /228.267Ki, 0/s, -
#  * fold2/test/all_2rounds…o.3_4bars_3_37.mid.pkl:100% /155.807Ki, 0/s, -Transferred:   	   14.990 MiB / 789.159 MiB, 2%, 587.779 KiB/s, ETA 22m28s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           69 / 4780, 1%
# Elapsed time:        25.9s
# Transferring:
#  * fold2/test/all_2rounds…o.3_4bars_3_37.mid.pkl:100% /155.807Ki, 155.801Ki/s,
#  * fold2/test/all_2rounds…o.3_4bars_3_46.mid.pkl:100% /173.797Ki, 0/s, -
#  * fold2/test/all_2rounds…o.3_4bars_6_29.mid.pkl:100% /235.992Ki, 0/s, -
#  * fold2/test/all_2rounds…o.3_4bars_6_37.mid.pkl:  0% /156.979Ki, 0/s, -Transferred:   	   15.315 MiB / 789.159 MiB, 2%, 582.393 KiB/s, ETA 22m40s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           70 / 4780, 1%
# Elapsed time:        26.4s
# Transferring:
#  * fold2/test/all_2rounds…o.3_4bars_3_46.mid.pkl:100% /173.797Ki, 0/s, -
#  * fold2/test/all_2rounds…o.3_4bars_6_29.mid.pkl:100% /235.992Ki, 0/s, -
#  * fold2/test/all_2rounds…o.3_4bars_6_37.mid.pkl:100% /156.979Ki, 0/s, -
#  * fold2/test/all_2rounds…o.3_4bars_6_46.mid.pkl:100% /175.874Ki, 0/s, -Transferred:   	   15.315 MiB / 789.159 MiB, 2%, 582.393 KiB/s, ETA 22m40s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           72 / 4780, 2%
# Elapsed time:        26.9s
# Transferring:
#  * fold2/test/all_2rounds…o.3_4bars_6_37.mid.pkl:100% /156.979Ki, 156.969Ki/s,
#  * fold2/test/all_2rounds…o.3_4bars_6_46.mid.pkl:100% /175.874Ki, 0/s, -
#  * fold2/test/all_2rounds…o.3_4bars_9_29.mid.pkl:  0% /234.215Ki, 0/s, -
#  * fold2/test/all_2rounds…o.3_4bars_9_37.mid.pkl:  0% /154.623Ki, 0/s, -Transferred:   	   16.110 MiB / 789.159 MiB, 2%, 566.796 KiB/s, ETA 23m16s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           74 / 4780, 2%
# Elapsed time:        27.4s
# Transferring:
#  * fold2/test/all_2rounds…o.3_4bars_9_29.mid.pkl:100% /234.215Ki, 0/s, -
#  * fold2/test/all_2rounds…o.3_4bars_9_37.mid.pkl:100% /154.623Ki, 0/s, -
#  * fold2/test/all_2rounds…o.3_4bars_9_46.mid.pkl:100% /195.164Ki, 0/s, -
#  * fold2/test/all_2rounds…bars_Score2_29.mid.pkl:100% /229.949Ki, 0/s, -Transferred:   	   16.110 MiB / 789.159 MiB, 2%, 566.796 KiB/s, ETA 23m16s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           74 / 4780, 2%
# Elapsed time:        27.9s
# Transferring:
#  * fold2/test/all_2rounds…o.3_4bars_9_29.mid.pkl:100% /234.215Ki, 234.198Ki/s,
#  * fold2/test/all_2rounds…o.3_4bars_9_37.mid.pkl:100% /154.623Ki, 154.618Ki/s,
#  * fold2/test/all_2rounds…o.3_4bars_9_46.mid.pkl:100% /195.164Ki, 0/s, -
#  * fold2/test/all_2rounds…bars_Score2_29.mid.pkl:100% /229.949Ki, 0/s, -Transferred:   	   16.650 MiB / 789.159 MiB, 2%, 582.243 KiB/s, ETA 22m38s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           77 / 4780, 2%
# Elapsed time:        28.4s
# Transferring:
#  * fold2/test/all_2rounds…bars_Score2_29.mid.pkl:100% /229.949Ki, 229.937Ki/s,
#  * fold2/test/all_2rounds…bars_Score2_37.mid.pkl:100% /155.932Ki, 0/s, -
#  * fold2/test/all_2rounds…bars_Score2_46.mid.pkl:100% /170.699Ki, 0/s, -
#  * fold2/test/all_2rounds…4bars_Score_29.mid.pkl:100% /226.688Ki, 0/s, -Transferred:   	   16.801 MiB / 789.159 MiB, 2%, 582.243 KiB/s, ETA 22m38s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           78 / 4780, 2%
# Elapsed time:        28.9s
# Transferring:
#  * fold2/test/all_2rounds…bars_Score2_37.mid.pkl:100% /155.932Ki, 0/s, -
#  * fold2/test/all_2rounds…bars_Score2_46.mid.pkl:100% /170.699Ki, 0/s, -
#  * fold2/test/all_2rounds…4bars_Score_29.mid.pkl:100% /226.688Ki, 0/s, -
#  * fold2/test/all_2rounds…4bars_Score_37.mid.pkl:100% /154.645Ki, 0/s, -Transferred:   	   16.801 MiB / 789.159 MiB, 2%, 590.102 KiB/s, ETA 22m20s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           81 / 4780, 2%
# Elapsed time:        29.4s
# Transferring:
#  * fold2/test/all_2rounds…4bars_Score_37.mid.pkl:100% /154.645Ki, 0/s, -
#  * fold2/test/all_2rounds…4bars_Score_46.mid.pkl:  0% /169.896Ki, 0/s, -
#  * fold2/test/all_2rounds…mv2_8bars_0_08.mid.pkl:  0% /215.080Ki, 0/s, -
#  * fold2/test/all_2rounds…mv2_8bars_0_10.mid.pkl:  0% /296.809Ki, 0/s, -Transferred:   	   17.467 MiB / 789.159 MiB, 2%, 590.102 KiB/s, ETA 22m19s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           81 / 4780, 2%
# Elapsed time:        29.9s
# Transferring:
#  * fold2/test/all_2rounds…4bars_Score_37.mid.pkl:100% /154.645Ki, 154.641Ki/s,
#  * fold2/test/all_2rounds…4bars_Score_46.mid.pkl:100% /169.896Ki, 0/s, -
#  * fold2/test/all_2rounds…mv2_8bars_0_08.mid.pkl:100% /215.080Ki, 0/s, -
#  * fold2/test/all_2rounds…mv2_8bars_0_10.mid.pkl:100% /296.809Ki, 0/s, -Transferred:   	   17.467 MiB / 789.159 MiB, 2%, 595.831 KiB/s, ETA 22m6s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           82 / 4780, 2%
# Elapsed time:        30.4s
# Transferring:
#  * fold2/test/all_2rounds…4bars_Score_46.mid.pkl:100% /169.896Ki, 169.886Ki/s,
#  * fold2/test/all_2rounds…mv2_8bars_0_08.mid.pkl:100% /215.080Ki, 215.067Ki/s,
#  * fold2/test/all_2rounds…mv2_8bars_0_10.mid.pkl:100% /296.809Ki, 296.793Ki/s,
#  * fold2/test/all_2rounds…mv2_8bars_0_14.mid.pkl:  0% /130.229Ki, 0/s, -Transferred:   	   17.802 MiB / 789.159 MiB, 2%, 595.831 KiB/s, ETA 22m5s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           85 / 4780, 2%
# Elapsed time:        30.9s
# Transferring:
#  * fold2/test/all_2rounds…mv2_8bars_0_14.mid.pkl:100% /130.229Ki, 0/s, -
#  * fold2/test/all_2rounds…v2_8bars_10_08.mid.pkl:100% /212.982Ki, 0/s, -
#  * fold2/test/all_2rounds…v2_8bars_10_10.mid.pkl:  0% /289.825Ki, 0/s, -
#  * fold2/test/all_2rounds…v2_8bars_10_14.mid.pkl:  0% /130.832Ki, 0/s, -Transferred:   	   18.213 MiB / 789.159 MiB, 2%, 580.042 KiB/s, ETA 22m41s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           85 / 4780, 2%
# Elapsed time:        31.4s
# Transferring:
#  * fold2/test/all_2rounds…mv2_8bars_0_14.mid.pkl:100% /130.229Ki, 130.221Ki/s,
#  * fold2/test/all_2rounds…v2_8bars_10_08.mid.pkl:100% /212.982Ki, 0/s, -
#  * fold2/test/all_2rounds…v2_8bars_10_10.mid.pkl:100% /289.825Ki, 0/s, -
#  * fold2/test/all_2rounds…v2_8bars_10_14.mid.pkl:100% /130.832Ki, 0/s, -Transferred:   	   18.213 MiB / 789.159 MiB, 2%, 580.042 KiB/s, ETA 22m41s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           87 / 4780, 2%
# Elapsed time:        31.9s
# Transferring:
#  * fold2/test/all_2rounds…v2_8bars_10_10.mid.pkl:100% /289.825Ki, 289.817Ki/s,
#  * fold2/test/all_2rounds…v2_8bars_10_14.mid.pkl:100% /130.832Ki, 130.828Ki/s,
#  * fold2/test/all_2rounds…v2_8bars_12_08.mid.pkl:  0% /220.749Ki, 0/s, -
#  * fold2/test/all_2rounds…v2_8bars_12_10.mid.pkl:  0% /290.508Ki, 0/s, -Transferred:   	   18.841 MiB / 789.159 MiB, 2%, 570.080 KiB/s, ETA 23m3s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           89 / 4780, 2%
# Elapsed time:        32.4s
# Transferring:
#  * fold2/test/all_2rounds…v2_8bars_12_08.mid.pkl:100% /220.749Ki, 0/s, -
#  * fold2/test/all_2rounds…v2_8bars_12_10.mid.pkl:100% /290.508Ki, 0/s, -
#  * fold2/test/all_2rounds…v2_8bars_12_14.mid.pkl:100% /131.465Ki, 0/s, -
#  * fold2/test/all_2rounds…mv2_8bars_1_08.mid.pkl:  0% /212.921Ki, 0/s, -Transferred:   	   19.048 MiB / 789.159 MiB, 2%, 570.080 KiB/s, ETA 23m3s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           89 / 4780, 2%
# Elapsed time:        32.9s
# Transferring:
#  * fold2/test/all_2rounds…v2_8bars_12_08.mid.pkl:100% /220.749Ki, 220.743Ki/s,
#  * fold2/test/all_2rounds…v2_8bars_12_10.mid.pkl:100% /290.508Ki, 290.492Ki/s,
#  * fold2/test/all_2rounds…v2_8bars_12_14.mid.pkl:100% /131.465Ki, 0/s, -
#  * fold2/test/all_2rounds…mv2_8bars_1_08.mid.pkl:100% /212.921Ki, 0/s, -Transferred:   	   19.330 MiB / 789.159 MiB, 2%, 587.928 KiB/s, ETA 22m20s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           91 / 4780, 2%
# Elapsed time:        33.4s
# Transferring:
#  * fold2/test/all_2rounds…v2_8bars_12_10.mid.pkl:100% /290.508Ki, 290.492Ki/s,
#  * fold2/test/all_2rounds…mv2_8bars_1_08.mid.pkl:100% /212.921Ki, 212.906Ki/s,
#  * fold2/test/all_2rounds…mv2_8bars_1_10.mid.pkl:100% /287.882Ki, 0/s, -
#  * fold2/test/all_2rounds…mv2_8bars_1_14.mid.pkl:  0% /126.322Ki, 0/s, -Transferred:   	   19.968 MiB / 789.159 MiB, 3%, 587.928 KiB/s, ETA 22m19s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           93 / 4780, 2%
# Elapsed time:        33.9s
# Transferring:
#  * fold2/test/all_2rounds…mv2_8bars_1_10.mid.pkl:100% /287.882Ki, 0/s, -
#  * fold2/test/all_2rounds…mv2_8bars_1_14.mid.pkl:100% /126.322Ki, 0/s, -
#  * fold2/test/all_2rounds…mv2_8bars_2_08.mid.pkl:100% /213.892Ki, 0/s, -
#  * fold2/test/all_2rounds…mv2_8bars_2_10.mid.pkl:100% /313.932Ki, 0/s, -Transferred:   	   19.968 MiB / 789.159 MiB, 3%, 610.060 KiB/s, ETA 21m31s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           94 / 4780, 2%
# Elapsed time:        34.4s
# Transferring:
#  * fold2/test/all_2rounds…mv2_8bars_1_14.mid.pkl:100% /126.322Ki, 126.314Ki/s,
#  * fold2/test/all_2rounds…mv2_8bars_2_08.mid.pkl:100% /213.892Ki, 0/s, -
#  * fold2/test/all_2rounds…mv2_8bars_2_10.mid.pkl:100% /313.932Ki, 0/s, -
#  * fold2/test/all_2rounds…mv2_8bars_2_14.mid.pkl:  0% /132.191Ki, 0/s, -Transferred:   	   20.305 MiB / 789.159 MiB, 3%, 610.060 KiB/s, ETA 21m30s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           96 / 4780, 2%
# Elapsed time:        34.9s
# Transferring:
#  * fold2/test/all_2rounds…mv2_8bars_2_10.mid.pkl:100% /313.932Ki, 313.909Ki/s,
#  * fold2/test/all_2rounds…mv2_8bars_2_14.mid.pkl:100% /132.191Ki, 0/s, -
#  * fold2/test/all_2rounds…mv2_8bars_3_08.mid.pkl:100% /212.949Ki, 0/s, -
#  * fold2/test/all_2rounds…mv2_8bars_3_10.mid.pkl:  0% /297.406Ki, 0/s, -Transferred:   	   20.725 MiB / 789.159 MiB, 3%, 593.502 KiB/s, ETA 22m5s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           97 / 4780, 2%
# Elapsed time:        35.4s
# Transferring:
#  * fold2/test/all_2rounds…mv2_8bars_2_14.mid.pkl:100% /132.191Ki, 132.185Ki/s,
#  * fold2/test/all_2rounds…mv2_8bars_3_08.mid.pkl:100% /212.949Ki, 0/s, -
#  * fold2/test/all_2rounds…mv2_8bars_3_10.mid.pkl:100% /297.406Ki, 0/s, -
#  * fold2/test/all_2rounds…mv2_8bars_3_14.mid.pkl:100% /132.021Ki, 0/s, -Transferred:   	   20.937 MiB / 789.159 MiB, 3%, 593.502 KiB/s, ETA 22m5s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:           98 / 4780, 2%
# Elapsed time:        35.9s
# Transferring:
#  * fold2/test/all_2rounds…mv2_8bars_3_08.mid.pkl:100% /212.949Ki, 212.939Ki/s,
#  * fold2/test/all_2rounds…mv2_8bars_3_10.mid.pkl:100% /297.406Ki, 297.397Ki/s,
#  * fold2/test/all_2rounds…mv2_8bars_3_14.mid.pkl:100% /132.021Ki, 0/s, -
#  * fold2/test/all_2rounds…mv2_8bars_4_08.mid.pkl:100% /216.930Ki, 0/s, -Transferred:   	   20.937 MiB / 789.159 MiB, 3%, 596.806 KiB/s, ETA 21m58s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          101 / 4780, 2%
# Elapsed time:        36.4s
# Transferring:
#  * fold2/test/all_2rounds…mv2_8bars_4_08.mid.pkl:100% /216.930Ki, 0/s, -
#  * fold3/test/all_2rounds…15_8bars_11_10.mid.pkl:  0% /205.401Ki, 0/s, -
#  * fold3/test/all_2rounds…15_8bars_14_10.mid.pkl:  0% /207.770Ki, 0/s, -
#  * fold3/test/all_2rounds…15_8bars_18_10.mid.pkl:  0% /205.127Ki, 0/s, -Transferred:   	   20.937 MiB / 789.159 MiB, 3%, 596.806 KiB/s, ETA 21m58s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          101 / 4780, 2%
# Elapsed time:        36.9s
# Transferring:
#  * fold2/test/all_2rounds…mv2_8bars_4_08.mid.pkl:100% /216.930Ki, 216.914Ki/s,
#  * fold3/test/all_2rounds…15_8bars_11_10.mid.pkl:  0% /205.401Ki, 0/s, -
#  * fold3/test/all_2rounds…15_8bars_14_10.mid.pkl:  0% /207.770Ki, 0/s, -
#  * fold3/test/all_2rounds…15_8bars_18_10.mid.pkl:  0% /205.127Ki, 0/s, -Transferred:   	   21.137 MiB / 789.159 MiB, 3%, 559.505 KiB/s, ETA 23m25s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          102 / 4780, 2%
# Elapsed time:        37.4s
# Transferring:
#  * fold3/test/all_2rounds…15_8bars_11_10.mid.pkl:100% /205.401Ki, 0/s, -
#  * fold3/test/all_2rounds…15_8bars_14_10.mid.pkl:  0% /207.770Ki, 0/s, -
#  * fold3/test/all_2rounds…15_8bars_18_10.mid.pkl:  0% /205.127Ki, 0/s, -
#  * fold3/test/all_2rounds…15_8bars_19_10.mid.pkl:  0% /208.243Ki, 0/s, -Transferred:   	   21.744 MiB / 789.159 MiB, 3%, 559.505 KiB/s, ETA 23m24s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          102 / 4780, 2%
# Elapsed time:        37.9s
# Transferring:
#  * fold3/test/all_2rounds…15_8bars_11_10.mid.pkl:100% /205.401Ki, 0/s, -
#  * fold3/test/all_2rounds…15_8bars_14_10.mid.pkl:100% /207.770Ki, 0/s, -
#  * fold3/test/all_2rounds…15_8bars_18_10.mid.pkl:100% /205.127Ki, 0/s, -
#  * fold3/test/all_2rounds…15_8bars_19_10.mid.pkl:100% /208.243Ki, 0/s, -Transferred:   	   21.744 MiB / 789.159 MiB, 3%, 576.194 KiB/s, ETA 22m43s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          102 / 4780, 2%
# Elapsed time:        38.4s
# Transferring:
#  * fold3/test/all_2rounds…15_8bars_11_10.mid.pkl:100% /205.401Ki, 102.697Ki/s,
#  * fold3/test/all_2rounds…15_8bars_14_10.mid.pkl:100% /207.770Ki, 103.885Ki/s,
#  * fold3/test/all_2rounds…15_8bars_18_10.mid.pkl:100% /205.127Ki, 102.562Ki/s,
#  * fold3/test/all_2rounds…15_8bars_19_10.mid.pkl:100% /208.243Ki, 208.233Ki/s,Transferred:   	   22.144 MiB / 789.159 MiB, 3%, 576.194 KiB/s, ETA 22m43s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          106 / 4780, 2%
# Elapsed time:        38.9s
# Transferring:
#  * fold3/test/all_2rounds…r15_8bars_1_10.mid.pkl:100% /205.845Ki, 0/s, -
#  * fold3/test/all_2rounds…15_8bars_22_10.mid.pkl:100% /203.699Ki, 0/s, -
#  * fold3/test/all_2rounds…15_8bars_24_10.mid.pkl:  0% /204.599Ki, 0/s, -
#  * fold3/test/all_2rounds…15_8bars_26_10.mid.pkl:  0% /203.041Ki, 0/s, -Transferred:   	   22.542 MiB / 789.159 MiB, 3%, 565.779 KiB/s, ETA 23m7s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          106 / 4780, 2%
# Elapsed time:        39.4s
# Transferring:
#  * fold3/test/all_2rounds…r15_8bars_1_10.mid.pkl:100% /205.845Ki, 0/s, -
#  * fold3/test/all_2rounds…15_8bars_22_10.mid.pkl:100% /203.699Ki, 0/s, -
#  * fold3/test/all_2rounds…15_8bars_24_10.mid.pkl:100% /204.599Ki, 0/s, -
#  * fold3/test/all_2rounds…15_8bars_26_10.mid.pkl:100% /203.041Ki, 0/s, -Transferred:   	   22.542 MiB / 789.159 MiB, 3%, 565.779 KiB/s, ETA 23m7s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          106 / 4780, 2%
# Elapsed time:        39.9s
# Transferring:
#  * fold3/test/all_2rounds…r15_8bars_1_10.mid.pkl:100% /205.845Ki, 205.833Ki/s,
#  * fold3/test/all_2rounds…15_8bars_22_10.mid.pkl:100% /203.699Ki, 203.689Ki/s,
#  * fold3/test/all_2rounds…15_8bars_24_10.mid.pkl:100% /204.599Ki, 204.584Ki/s,
#  * fold3/test/all_2rounds…15_8bars_26_10.mid.pkl:100% /203.041Ki, 202.890Ki/s,Transferred:   	   23.349 MiB / 789.159 MiB, 3%, 555.895 KiB/s, ETA 23m30s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          110 / 4780, 2%
# Elapsed time:        40.4s
# Transferring:
#  * fold3/test/all_2rounds…r15_8bars_2_10.mid.pkl:100% /203.893Ki, 0/s, -
#  * fold3/test/all_2rounds…r15_8bars_3_10.mid.pkl:100% /211.416Ki, 0/s, -
#  * fold3/test/all_2rounds…r15_8bars_4_10.mid.pkl:100% /202.642Ki, 0/s, -
#  * fold3/test/all_2rounds…r15_8bars_7_10.mid.pkl:100% /209.042Ki, 0/s, -Transferred:   	   23.349 MiB / 789.159 MiB, 3%, 555.895 KiB/s, ETA 23m30s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          110 / 4780, 2%
# Elapsed time:        40.9s
# Transferring:
#  * fold3/test/all_2rounds…r15_8bars_2_10.mid.pkl:100% /203.893Ki, 0/s, -
#  * fold3/test/all_2rounds…r15_8bars_3_10.mid.pkl:100% /211.416Ki, 0/s, -
#  * fold3/test/all_2rounds…r15_8bars_4_10.mid.pkl:100% /202.642Ki, 0/s, -
#  * fold3/test/all_2rounds…r15_8bars_7_10.mid.pkl:100% /209.042Ki, 0/s, -Transferred:   	   23.349 MiB / 789.159 MiB, 3%, 572.838 KiB/s, ETA 22m48s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          111 / 4780, 2%
# Elapsed time:        41.4s
# Transferring:
#  * fold3/test/all_2rounds…r15_8bars_2_10.mid.pkl:100% /203.893Ki, 203.876Ki/s,
#  * fold3/test/all_2rounds…r15_8bars_4_10.mid.pkl:100% /202.642Ki, 202.630Ki/s,
#  * fold3/test/all_2rounds…r15_8bars_7_10.mid.pkl:100% /209.042Ki, 209.030Ki/s,
#  * fold3/test/all_2rounds…bars_Score2_10.mid.pkl:  0% /207.353Ki, 0/s, -Transferred:   	   24.282 MiB / 789.159 MiB, 3%, 572.838 KiB/s, ETA 22m47s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          114 / 4780, 2%
# Elapsed time:        41.9s
# Transferring:
#  * fold3/test/all_2rounds…bars_Score2_10.mid.pkl:100% /207.353Ki, 0/s, -
#  * fold3/test/all_2rounds…8bars_Score_10.mid.pkl:100% /205.164Ki, 0/s, -
#  * fold3/test/all_2rounds…23_8bars_11_13.mid.pkl:100% /270.628Ki, 0/s, -
#  * fold3/test/all_2rounds…23_8bars_14_13.mid.pkl:100% /271.606Ki, 0/s, -Transferred:   	   24.282 MiB / 789.159 MiB, 3%, 596.709 KiB/s, ETA 21m52s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          114 / 4780, 2%
# Elapsed time:        42.4s
# Transferring:
#  * fold3/test/all_2rounds…bars_Score2_10.mid.pkl:100% /207.353Ki, 207.337Ki/s,
#  * fold3/test/all_2rounds…8bars_Score_10.mid.pkl:100% /205.164Ki, 0/s, -
#  * fold3/test/all_2rounds…23_8bars_11_13.mid.pkl:100% /270.628Ki, 0/s, -
#  * fold3/test/all_2rounds…23_8bars_14_13.mid.pkl:100% /271.606Ki, 0/s, -Transferred:   	   25.089 MiB / 789.159 MiB, 3%, 596.709 KiB/s, ETA 21m51s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          118 / 4780, 2%
# Elapsed time:        42.9s
# Transferring:
#  * fold3/test/all_2rounds…23_8bars_18_13.mid.pkl:100% /272.769Ki, 0/s, -
#  * fold3/test/all_2rounds…23_8bars_19_13.mid.pkl:100% /277.569Ki, 0/s, -
#  * fold3/test/all_2rounds…r23_8bars_1_13.mid.pkl:100% /275.976Ki, 0/s, -
#  * fold3/test/all_2rounds…23_8bars_22_13.mid.pkl:  0% /271.909Ki, 0/s, -Transferred:   	   25.354 MiB / 789.159 MiB, 3%, 611.059 KiB/s, ETA 21m19s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          118 / 4780, 2%
# Elapsed time:        43.4s
# Transferring:
#  * fold3/test/all_2rounds…23_8bars_18_13.mid.pkl:100% /272.769Ki, 0/s, -
#  * fold3/test/all_2rounds…23_8bars_19_13.mid.pkl:100% /277.569Ki, 0/s, -
#  * fold3/test/all_2rounds…r23_8bars_1_13.mid.pkl:100% /275.976Ki, 0/s, -
#  * fold3/test/all_2rounds…23_8bars_22_13.mid.pkl:100% /271.909Ki, 0/s, -Transferred:   	   25.354 MiB / 789.159 MiB, 3%, 611.059 KiB/s, ETA 21m19s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          118 / 4780, 2%
# Elapsed time:        43.9s
# Transferring:
#  * fold3/test/all_2rounds…23_8bars_18_13.mid.pkl:100% /272.769Ki, 272.740Ki/s,
#  * fold3/test/all_2rounds…23_8bars_19_13.mid.pkl:100% /277.569Ki, 277.553Ki/s,
#  * fold3/test/all_2rounds…r23_8bars_1_13.mid.pkl:100% /275.976Ki, 275.957Ki/s,
#  * fold3/test/all_2rounds…23_8bars_22_13.mid.pkl:100% /271.909Ki, 271.884Ki/s,Transferred:   	   25.886 MiB / 789.159 MiB, 3%, 589.861 KiB/s, ETA 22m5s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          121 / 4780, 3%
# Elapsed time:        44.4s
# Transferring:
#  * fold3/test/all_2rounds…23_8bars_22_13.mid.pkl:100% /271.909Ki, 271.884Ki/s,
#  * fold3/test/all_2rounds…23_8bars_24_13.mid.pkl:100% /272.568Ki, 0/s, -
#  * fold3/test/all_2rounds…23_8bars_26_13.mid.pkl:100% /271.451Ki, 0/s, -
#  * fold3/test/all_2rounds…r23_8bars_2_13.mid.pkl:  0% /276.685Ki, 0/s, -Transferred:   	   26.420 MiB / 789.159 MiB, 3%, 589.861 KiB/s, ETA 22m4s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          122 / 4780, 3%
# Elapsed time:        44.9s
# Transferring:
#  * fold3/test/all_2rounds…23_8bars_24_13.mid.pkl:100% /272.568Ki, 0/s, -
#  * fold3/test/all_2rounds…23_8bars_26_13.mid.pkl:100% /271.451Ki, 0/s, -
#  * fold3/test/all_2rounds…r23_8bars_2_13.mid.pkl:100% /276.685Ki, 0/s, -
#  * fold3/test/all_2rounds…r23_8bars_3_13.mid.pkl:100% /270.722Ki, 0/s, -Transferred:   	   26.420 MiB / 789.159 MiB, 3%, 621.209 KiB/s, ETA 20m57s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          123 / 4780, 3%
# Elapsed time:        45.4s
# Transferring:
#  * fold3/test/all_2rounds…23_8bars_26_13.mid.pkl:100% /271.451Ki, 271.434Ki/s,
#  * fold3/test/all_2rounds…r23_8bars_2_13.mid.pkl:100% /276.685Ki, 276.668Ki/s,
#  * fold3/test/all_2rounds…r23_8bars_3_13.mid.pkl:100% /270.722Ki, 0/s, -
#  * fold3/test/all_2rounds…r23_8bars_4_13.mid.pkl:  0% /271.344Ki, 0/s, -Transferred:   	   26.949 MiB / 789.159 MiB, 3%, 621.209 KiB/s, ETA 20m56s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          125 / 4780, 3%
# Elapsed time:        45.9s
# Transferring:
#  * fold3/test/all_2rounds…r23_8bars_3_13.mid.pkl:100% /270.722Ki, 270.710Ki/s,
#  * fold3/test/all_2rounds…r23_8bars_4_13.mid.pkl:100% /271.344Ki, 0/s, -
#  * fold3/test/all_2rounds…r23_8bars_7_13.mid.pkl:100% /270.285Ki, 0/s, -
#  * fold3/test/all_2rounds…bars_Score2_13.mid.pkl:  0% /274.889Ki, 0/s, -Transferred:   	   27.485 MiB / 789.159 MiB, 3%, 616.235 KiB/s, ETA 21m5s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          126 / 4780, 3%
# Elapsed time:        46.4s
# Transferring:
#  * fold3/test/all_2rounds…r23_8bars_4_13.mid.pkl:100% /271.344Ki, 271.323Ki/s,
#  * fold3/test/all_2rounds…r23_8bars_7_13.mid.pkl:100% /270.285Ki, 0/s, -
#  * fold3/test/all_2rounds…bars_Score2_13.mid.pkl:100% /274.889Ki, 0/s, -
#  * fold3/test/all_2rounds…8bars_Score_13.mid.pkl:100% /274.327Ki, 0/s, -Transferred:   	   27.770 MiB / 789.159 MiB, 4%, 616.235 KiB/s, ETA 21m5s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          128 / 4780, 3%
# Elapsed time:        46.9s
# Transferring:
#  * fold3/test/all_2rounds…bars_Score2_13.mid.pkl:100% /274.889Ki, 274.867Ki/s,
#  * fold3/test/all_2rounds…8bars_Score_13.mid.pkl:100% /274.327Ki, 0/s, -
#  * fold3/test/all_2rounds…27_8bars_11_15.mid.pkl:100% /291.620Ki, 0/s, -
#  * fold3/test/all_2rounds…27_8bars_14_15.mid.pkl:  0% /279.211Ki, 0/s, -Transferred:   	   28.316 MiB / 789.159 MiB, 4%, 630.272 KiB/s, ETA 20m36s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          130 / 4780, 3%
# Elapsed time:        47.4s
# Transferring:
#  * fold3/test/all_2rounds…27_8bars_11_15.mid.pkl:100% /291.620Ki, 0/s, -
#  * fold3/test/all_2rounds…27_8bars_14_15.mid.pkl:100% /279.211Ki, 0/s, -
#  * fold3/test/all_2rounds…27_8bars_18_15.mid.pkl:100% /279.183Ki, 0/s, -
#  * fold3/test/all_2rounds…27_8bars_19_15.mid.pkl:  0% /281.500Ki, 0/s, -Transferred:   	   28.590 MiB / 789.159 MiB, 4%, 630.272 KiB/s, ETA 20m35s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          130 / 4780, 3%
# Elapsed time:        47.9s
# Transferring:
#  * fold3/test/all_2rounds…27_8bars_11_15.mid.pkl:100% /291.620Ki, 291.602Ki/s,
#  * fold3/test/all_2rounds…27_8bars_14_15.mid.pkl:100% /279.211Ki, 279.192Ki/s,
#  * fold3/test/all_2rounds…27_8bars_18_15.mid.pkl:100% /279.183Ki, 0/s, -
#  * fold3/test/all_2rounds…27_8bars_19_15.mid.pkl:100% /281.500Ki, 0/s, -Transferred:   	   29.131 MiB / 789.159 MiB, 4%, 643.374 KiB/s, ETA 20m9s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:          133 / 4780, 3%
# Elapsed time:        48.4s
# Transferring:
#  * fold3/test/all_2rounds…27_8bars_19_15.mid.pkl:100% /281.500Ki, 281.481Ki/s,
#  * fold3/test/all_2rounds…r27_8bars_1_15.mid.pkl:100% /279.347Ki, 0/s, -
# ...
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4731 / 4780, 99%
# Elapsed time:     26m10.0s
# Transferring:
#  * fold1/train/all_2round…mv3_8bars_9_06.mid.pkl:100% /78.715Ki, 78.709Ki/s, 0
#  * fold1/train/all_2round…mv3_8bars_9_07.mid.pkl:100% /83.160Ki, 83.154Ki/s, 0
#  * fold1/train/all_2round…mv3_8bars_9_08.mid.pkl:100% /64.895Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_09.mid.pkl:100% /109.439Ki, 0/s, -Transferred:   	  784.951 MiB / 789.159 MiB, 99%, 325.203 KiB/s, ETA 13s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4735 / 4780, 99%
# Elapsed time:     26m10.4s
# Transferring:
#  * fold1/train/all_2round…mv3_8bars_9_10.mid.pkl:100% /123.097Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_11.mid.pkl:100% /152.061Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_12.mid.pkl:  0% /125.491Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_13.mid.pkl:  0% /131.955Ki, 0/s, -Transferred:   	  785.202 MiB / 789.159 MiB, 99%, 322.075 KiB/s, ETA 12s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4735 / 4780, 99%
# Elapsed time:     26m11.0s
# Transferring:
#  * fold1/train/all_2round…mv3_8bars_9_10.mid.pkl:100% /123.097Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_11.mid.pkl:100% /152.061Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_12.mid.pkl:100% /125.491Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_13.mid.pkl:100% /131.955Ki, 0/s, -Transferred:   	  785.202 MiB / 789.159 MiB, 99%, 322.075 KiB/s, ETA 12s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4735 / 4780, 99%
# Elapsed time:     26m11.5s
# Transferring:
#  * fold1/train/all_2round…mv3_8bars_9_10.mid.pkl:100% /123.097Ki, 123.093Ki/s,
#  * fold1/train/all_2round…mv3_8bars_9_11.mid.pkl:100% /152.061Ki, 152.056Ki/s,
#  * fold1/train/all_2round…mv3_8bars_9_12.mid.pkl:100% /125.491Ki, 125.486Ki/s,
#  * fold1/train/all_2round…mv3_8bars_9_13.mid.pkl:100% /131.955Ki, 131.946Ki/s,Transferred:   	  785.522 MiB / 789.159 MiB, 100%, 318.036 KiB/s, ETA 11s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4739 / 4780, 99%
# Elapsed time:     26m12.0s
# Transferring:
#  * fold1/train/all_2round…mv3_8bars_9_15.mid.pkl:100% /78.769Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_17.mid.pkl:100% /64.512Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_18.mid.pkl:100% /107.031Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_21.mid.pkl:100% /77.070Ki, 0/s, -Transferred:   	  785.522 MiB / 789.159 MiB, 100%, 318.036 KiB/s, ETA 11s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4739 / 4780, 99%
# Elapsed time:     26m12.5s
# Transferring:
#  * fold1/train/all_2round…mv3_8bars_9_15.mid.pkl:100% /78.769Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_17.mid.pkl:100% /64.512Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_18.mid.pkl:100% /107.031Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_21.mid.pkl:100% /77.070Ki, 0/s, -Transferred:   	  785.672 MiB / 789.159 MiB, 100%, 318.621 KiB/s, ETA 11s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4742 / 4780, 99%
# Elapsed time:     26m12.9s
# Transferring:
#  * fold1/train/all_2round…mv3_8bars_9_18.mid.pkl:100% /107.031Ki, 107.012Ki/s,
#  * fold1/train/all_2round…mv3_8bars_9_24.mid.pkl:100% /77.890Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_25.mid.pkl:  0% /78.258Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_26.mid.pkl:100% /75.638Ki, 0/s, -Transferred:   	  785.874 MiB / 789.159 MiB, 100%, 318.621 KiB/s, ETA 10s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4743 / 4780, 99%
# Elapsed time:     26m13.5s
# Transferring:
#  * fold1/train/all_2round…mv3_8bars_9_24.mid.pkl:100% /77.890Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_25.mid.pkl:100% /78.258Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_26.mid.pkl:100% /75.638Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_29.mid.pkl:100% /128.829Ki, 0/s, -Transferred:   	  785.874 MiB / 789.159 MiB, 100%, 321.245 KiB/s, ETA 10s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4743 / 4780, 99%
# Elapsed time:     26m14.0s
# Transferring:
#  * fold1/train/all_2round…mv3_8bars_9_24.mid.pkl:100% /77.890Ki, 77.887Ki/s, 0
#  * fold1/train/all_2round…mv3_8bars_9_25.mid.pkl:100% /78.258Ki, 78.255Ki/s, 0
#  * fold1/train/all_2round…mv3_8bars_9_26.mid.pkl:100% /75.638Ki, 75.636Ki/s, 0
#  * fold1/train/all_2round…mv3_8bars_9_29.mid.pkl:100% /128.829Ki, 0/s, -Transferred:   	  786.149 MiB / 789.159 MiB, 100%, 321.245 KiB/s, ETA 9s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4747 / 4780, 99%
# Elapsed time:     26m14.5s
# Transferring:
#  * fold1/train/all_2round…mv3_8bars_9_30.mid.pkl:100% /129.555Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_31.mid.pkl:100% /87.377Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_34.mid.pkl:100% /64.631Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_35.mid.pkl:  0% /107.221Ki, 0/s, -Transferred:   	  786.253 MiB / 789.159 MiB, 100%, 325.466 KiB/s, ETA 9s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4747 / 4780, 99%
# Elapsed time:     26m14.9s
# Transferring:
#  * fold1/train/all_2round…mv3_8bars_9_30.mid.pkl:100% /129.555Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_31.mid.pkl:100% /87.377Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_34.mid.pkl:100% /64.631Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_35.mid.pkl:100% /107.221Ki, 0/s, -Transferred:   	  786.253 MiB / 789.159 MiB, 100%, 325.466 KiB/s, ETA 9s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4750 / 4780, 99%
# Elapsed time:     26m15.5s
# Transferring:
#  * fold1/train/all_2round…mv3_8bars_9_35.mid.pkl:100% /107.221Ki, 107.214Ki/s,
#  * fold1/train/all_2round…mv3_8bars_9_36.mid.pkl:  0% /122.012Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_37.mid.pkl:  0% /165.513Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_01.mid.pkl:  0% /124.655Ki, 0/s, -Transferred:   	  786.776 MiB / 789.159 MiB, 100%, 320.541 KiB/s, ETA 7s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4751 / 4780, 99%
# Elapsed time:     26m16.0s
# Transferring:
#  * fold1/train/all_2round…mv3_8bars_9_36.mid.pkl:100% /122.012Ki, 0/s, -
#  * fold1/train/all_2round…mv3_8bars_9_37.mid.pkl:100% /165.513Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_01.mid.pkl:100% /124.655Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_02.mid.pkl:100% /122.794Ki, 0/s, -Transferred:   	  786.776 MiB / 789.159 MiB, 100%, 320.541 KiB/s, ETA 7s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4751 / 4780, 99%
# Elapsed time:     26m16.5s
# Transferring:
#  * fold1/train/all_2round…mv3_8bars_9_36.mid.pkl:100% /122.012Ki, 122.005Ki/s,
#  * fold1/train/all_2round…mv3_8bars_9_37.mid.pkl:100% /165.513Ki, 165.508Ki/s,
#  * fold1/train/all_2round…8bars_Score_01.mid.pkl:100% /124.655Ki, 124.653Ki/s,
#  * fold1/train/all_2round…8bars_Score_02.mid.pkl:100% /122.794Ki, 0/s, -Transferred:   	  786.904 MiB / 789.159 MiB, 100%, 318.526 KiB/s, ETA 7s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4754 / 4780, 99%
# Elapsed time:     26m17.0s
# Transferring:
#  * fold1/train/all_2round…8bars_Score_02.mid.pkl:100% /122.794Ki, 122.787Ki/s,
#  * fold1/train/all_2round…8bars_Score_04.mid.pkl:100% /131.411Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_05.mid.pkl:  0% /84.512Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_06.mid.pkl:  0% /77.192Ki, 0/s, -Transferred:   	  787.144 MiB / 789.159 MiB, 100%, 318.526 KiB/s, ETA 6s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4755 / 4780, 99%
# Elapsed time:     26m17.5s
# Transferring:
#  * fold1/train/all_2round…8bars_Score_04.mid.pkl:100% /131.411Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_05.mid.pkl:100% /84.512Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_06.mid.pkl:100% /77.192Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_07.mid.pkl:100% /83.523Ki, 0/s, -Transferred:   	  787.144 MiB / 789.159 MiB, 100%, 322.158 KiB/s, ETA 6s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4755 / 4780, 99%
# Elapsed time:     26m18.0s
# Transferring:
#  * fold1/train/all_2round…8bars_Score_04.mid.pkl:100% /131.411Ki, 131.398Ki/s,
#  * fold1/train/all_2round…8bars_Score_05.mid.pkl:100% /84.512Ki, 84.507Ki/s, 0
#  * fold1/train/all_2round…8bars_Score_06.mid.pkl:100% /77.192Ki, 77.188Ki/s, 0
#  * fold1/train/all_2round…8bars_Score_07.mid.pkl:100% /83.523Ki, 0/s, -Transferred:   	  787.581 MiB / 789.159 MiB, 100%, 322.158 KiB/s, ETA 5s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4759 / 4780, 100%
# Elapsed time:     26m18.5s
# Transferring:
#  * fold1/train/all_2round…8bars_Score_08.mid.pkl:100% /65.312Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_09.mid.pkl:100% /107.336Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_10.mid.pkl:100% /123.105Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_11.mid.pkl:100% /152.455Ki, 0/s, -Transferred:   	  787.581 MiB / 789.159 MiB, 100%, 330.036 KiB/s, ETA 4s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4759 / 4780, 100%
# Elapsed time:     26m19.0s
# Transferring:
#  * fold1/train/all_2round…8bars_Score_08.mid.pkl:100% /65.312Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_09.mid.pkl:100% /107.336Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_10.mid.pkl:100% /123.105Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_11.mid.pkl:100% /152.455Ki, 0/s, -Transferred:   	  787.909 MiB / 789.159 MiB, 100%, 330.036 KiB/s, ETA 3s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4762 / 4780, 100%
# Elapsed time:     26m19.4s
# Transferring:
#  * fold1/train/all_2round…8bars_Score_11.mid.pkl:100% /152.455Ki, 152.448Ki/s,
#  * fold1/train/all_2round…8bars_Score_12.mid.pkl:100% /126.576Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_13.mid.pkl:100% /131.411Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_15.mid.pkl:100% /77.192Ki, 0/s, -Transferred:   	  787.973 MiB / 789.159 MiB, 100%, 330.358 KiB/s, ETA 3s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4763 / 4780, 100%
# Elapsed time:     26m20.0s
# Transferring:
#  * fold1/train/all_2round…8bars_Score_12.mid.pkl:100% /126.576Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_13.mid.pkl:100% /131.411Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_15.mid.pkl:100% /77.192Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_17.mid.pkl:100% /65.312Ki, 0/s, -Transferred:   	  787.973 MiB / 789.159 MiB, 100%, 330.358 KiB/s, ETA 3s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4765 / 4780, 100%
# Elapsed time:     26m20.5s
# Transferring:
#  * fold1/train/all_2round…8bars_Score_13.mid.pkl:100% /131.411Ki, 131.406Ki/s,
#  * fold1/train/all_2round…8bars_Score_17.mid.pkl:100% /65.312Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_18.mid.pkl:  0% /107.336Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_21.mid.pkl:  0% /76.402Ki, 0/s, -Transferred:   	  788.302 MiB / 789.159 MiB, 100%, 313.793 KiB/s, ETA 2s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4767 / 4780, 100%
# Elapsed time:     26m21.0s
# Transferring:
#  * fold1/train/all_2round…8bars_Score_18.mid.pkl:100% /107.336Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_21.mid.pkl:100% /76.402Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_24.mid.pkl:100% /78.550Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_25.mid.pkl:100% /75.327Ki, 0/s, -Transferred:   	  788.302 MiB / 789.159 MiB, 100%, 313.793 KiB/s, ETA 2s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4767 / 4780, 100%
# Elapsed time:     26m21.5s
# Transferring:
#  * fold1/train/all_2round…8bars_Score_18.mid.pkl:100% /107.336Ki, 107.332Ki/s,
#  * fold1/train/all_2round…8bars_Score_21.mid.pkl:100% /76.402Ki, 76.399Ki/s, 0
#  * fold1/train/all_2round…8bars_Score_24.mid.pkl:100% /78.550Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_25.mid.pkl:100% /75.327Ki, 0/s, -Transferred:   	  788.711 MiB / 789.159 MiB, 100%, 315.281 KiB/s, ETA 1s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4771 / 4780, 100%
# Elapsed time:     26m21.9s
# Transferring:
#  * fold1/train/all_2round…8bars_Score_26.mid.pkl:100% /76.294Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_29.mid.pkl:100% /126.576Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_30.mid.pkl:100% /131.411Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_31.mid.pkl:100% /84.512Ki, 0/s, -Transferred:   	  788.711 MiB / 789.159 MiB, 100%, 315.281 KiB/s, ETA 1s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4771 / 4780, 100%
# Elapsed time:     26m22.5s
# Transferring:
#  * fold1/train/all_2round…8bars_Score_26.mid.pkl:100% /76.294Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_29.mid.pkl:100% /126.576Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_30.mid.pkl:100% /131.411Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_31.mid.pkl:100% /84.512Ki, 0/s, -Transferred:   	  788.711 MiB / 789.159 MiB, 100%, 321.751 KiB/s, ETA 1s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4772 / 4780, 100%
# Elapsed time:     26m23.0s
# Transferring:
#  * fold1/train/all_2round…8bars_Score_26.mid.pkl:100% /76.294Ki, 76.289Ki/s, 0
#  * fold1/train/all_2round…8bars_Score_30.mid.pkl:100% /131.411Ki, 131.407Ki/s,
#  * fold1/train/all_2round…8bars_Score_31.mid.pkl:100% /84.512Ki, 84.506Ki/s, 0
#  * fold1/train/all_2round…8bars_Score_34.mid.pkl:  0% /65.312Ki, 0/s, -Transferred:   	  789.156 MiB / 789.159 MiB, 100%, 321.751 KiB/s, ETA 0s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4775 / 4780, 100%
# Elapsed time:     26m23.5s
# Transferring:
#  * fold1/train/all_2round…8bars_Score_34.mid.pkl:100% /65.312Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_35.mid.pkl:100% /107.336Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_36.mid.pkl:100% /123.105Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_37.mid.pkl:100% /160.199Ki, 0/s, -Transferred:   	  789.156 MiB / 789.159 MiB, 100%, 330.139 KiB/s, ETA 0s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4775 / 4780, 100%
# Elapsed time:     26m24.0s
# Transferring:
#  * fold1/train/all_2round…8bars_Score_34.mid.pkl:100% /65.312Ki, 65.309Ki/s, 0
#  * fold1/train/all_2round…8bars_Score_35.mid.pkl:100% /107.336Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_36.mid.pkl:100% /123.105Ki, 0/s, -
#  * fold1/train/all_2round…8bars_Score_37.mid.pkl:100% /160.199Ki, 0/s, -Transferred:   	  789.159 MiB / 789.159 MiB, 100%, 330.139 KiB/s, ETA 0s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4779 / 4780, 100%
# Elapsed time:     26m24.5s
# Transferring:
#  *                          fold1/train/stat.pkl:100% /2.577Ki, 0/s, -Transferred:   	  789.159 MiB / 789.159 MiB, 100%, 309.666 KiB/s, ETA 0s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4779 / 4780, 100%
# Elapsed time:     26m25.0s
# Transferring:
#  *                          fold1/train/stat.pkl:100% /2.577Ki, 0/s, -Transferred:   	  789.159 MiB / 789.159 MiB, 100%, 309.666 KiB/s, ETA 0s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4780 / 4780, 100%
# Elapsed time:     26m25.5sTransferred:   	  789.159 MiB / 789.159 MiB, 100%, 309.666 KiB/s, ETA 0s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4780 / 4780, 100%
# Elapsed time:     26m25.9sTransferred:   	  789.159 MiB / 789.159 MiB, 100%, 309.666 KiB/s, ETA 0s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4780 / 4780, 100%
# Elapsed time:     26m26.5sTransferred:   	  789.159 MiB / 789.159 MiB, 100%, 309.666 KiB/s, ETA 0s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4780 / 4780, 100%
# Elapsed time:     26m27.0sTransferred:   	  789.159 MiB / 789.159 MiB, 100%, 309.666 KiB/s, ETA 0s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4780 / 4780, 100%
# Elapsed time:     26m27.4sTransferred:   	  789.159 MiB / 789.159 MiB, 100%, 309.666 KiB/s, ETA 0s
# Checks:                 0 / 0, -, Listed 4796
# Transferred:         4780 / 4780, 100%
# Elapsed time:     26m27.6s
#
# Upload complete!

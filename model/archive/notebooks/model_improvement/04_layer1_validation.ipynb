# %% [markdown]
# # Layer 1 Validation Experiments
#
# Validates four assumptions before investing in Layer 2 model improvements.
# See `docs/plans/2026-03-09-layer1-validation-design.md` for the full design.
#
# ## Setup

# %%
import sys
from pathlib import Path

# Navigate to model/ root so all relative paths work consistently
_nb_dir = Path.cwd()
_model_dir = _nb_dir
while _model_dir.name != 'model' and _model_dir != _model_dir.parent:
    _model_dir = _model_dir.parent
if _model_dir.name == 'model':
    get_ipython().run_line_magic('cd', str(_model_dir))

sys.path.insert(0, 'src') if 'src' not in sys.path else None

import json
import logging

import jsonlines
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import torch
import pytorch_lightning as pl

pl.seed_everything(42, workers=True)
torch.set_float32_matmul_precision("medium")
logging.basicConfig(level=logging.INFO)

from model_improvement.audio_encoders import MuQLoRAModel
from model_improvement.taxonomy import DIMENSIONS, load_composite_labels
from model_improvement.layer1_validation import (
    score_competition_segments,
    competition_correlation,
    dynamic_range_analysis,
)

DATA_DIR = Path("data")
CHECKPOINT_DIR = DATA_DIR / "checkpoints/model_improvement"
COMPETITION_DIR = DATA_DIR / "competition_cache/chopin2021"
PERCEPIANO_DIR = DATA_DIR / "percepiano_cache"

print(f"DATA_DIR: {DATA_DIR.resolve()}")
print(f"CHECKPOINT_DIR: {CHECKPOINT_DIR.resolve()}")
# Out:
# /Users/jdhiman/Documents/crescendai/model
# Seed set to 42
# DATA_DIR: /Users/jdhiman/Documents/crescendai/model/data
# CHECKPOINT_DIR: /Users/jdhiman/Documents/crescendai/model/data/checkpoints/model_improvement
# /Users/jdhiman/Documents/crescendai/model/.venv/lib/python3.12/site-packages/torch/__init__.py:1617: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/Context.cpp:85.)
#   _C._set_float32_matmul_precision(precision)

# %% [markdown]
# ## Experiment 1: Competition Correlation
#
# **Question:** Does A1's quality signal predict expert competition placement?
#
# **Data:** 2,293 segments from Chopin 2021 (already on GDrive, synced locally).
#
# **Decision gate:** rho > 0.3 on at least one aggregation = model signal is real.

# %%
# Load A1 fold 3 checkpoint
a1_ckpt = sorted(CHECKPOINT_DIR.glob("A1/fold_3/*.ckpt"))[0]
print(f"Loading A1 from {a1_ckpt.name}")

a1_model = MuQLoRAModel.load_from_checkpoint(
    str(a1_ckpt),
    use_pretrained_muq=False,
)
a1_model.eval()
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
a1_model = a1_model.to(device)

# Competition embeddings loaded lazily (one at a time) by score_competition_segments
emb_dir = COMPETITION_DIR / "muq_embeddings"
print(f"Embedding directory: {emb_dir} ({len(list(emb_dir.glob('*.pt')))} files)")

# Load metadata
with jsonlines.open(COMPETITION_DIR / "metadata.jsonl") as reader:
    metadata = list(reader)
print(f"Loaded {len(metadata)} metadata records")
print(f"Performers: {len(set(m['performer'] for m in metadata))}")
print(f"Rounds: {sorted(set(m['round'] for m in metadata))}")
# Out:
# Loading A1 from epoch=5-val_loss=0.5450.ckpt
# Embedding directory: data/competition_cache/chopin2021/muq_embeddings (2293 files)
# Loaded 2293 metadata records
# Performers: 11
# Rounds: ['final', 'stage2', 'stage3']

# %%
# Score all segments (lazy loading from directory -- ~1.4MB peak per iteration)
segment_scores = score_competition_segments(a1_model, emb_dir)
print(f"Scored {len(segment_scores)} segments")

# Compute correlations
corr_results = competition_correlation(segment_scores, metadata)

# Display results
print("\n=== Competition Correlation Results ===\n")
for agg_name, corr in corr_results.items():
    gate = "PASS" if abs(corr["rho"]) > 0.3 else "INVESTIGATE" if abs(corr["rho"]) > 0.2 else "FAIL"
    print(f"{agg_name:>8s}: rho={corr['rho']:+.3f}  p={corr['p_value']:.4f}  n={corr['n_performers']}  [{gate}]")
    for dim_name, dim_corr in corr["per_dimension"].items():
        print(f"           {dim_name:>14s}: rho={dim_corr['rho']:+.3f}  p={dim_corr['p_value']:.4f}")
    print()
# Out:
# INFO:model_improvement.layer1_validation:Scored 500 segments so far
# INFO:model_improvement.layer1_validation:Scored 1000 segments so far
# INFO:model_improvement.layer1_validation:Scored 1500 segments so far
# INFO:model_improvement.layer1_validation:Scored 2000 segments so far
# INFO:model_improvement.layer1_validation:Scored 2293 segments total
# Scored 2293 segments
#
# === Competition Correlation Results ===
#
#     mean: rho=+0.704  p=0.0156  n=11  [PASS]
#                  dynamics: rho=-0.917  p=0.0001
#                    timing: rho=-0.590  p=0.0561
#                  pedaling: rho=+0.887  p=0.0003
#              articulation: rho=+0.292  p=0.3828
#                  phrasing: rho=+0.803  p=0.0029
#            interpretation: rho=+0.169  p=0.6204
#
#   median: rho=+0.248  p=0.4625  n=11  [INVESTIGATE]
#                  dynamics: rho=-0.615  p=0.0442
#                    timing: rho=-0.788  p=0.0040
#                  pedaling: rho=+0.853  p=0.0009
#              articulation: rho=+0.258  p=0.4441
#                  phrasing: rho=+0.758  p=0.0068
#            interpretation: rho=-0.183  p=0.5893
#
#      min: rho=+0.654  p=0.0289  n=11  [PASS]
#                  dynamics: rho=+0.773  p=0.0052
#                    timing: rho=+0.431  p=0.1854
#                  pedaling: rho=+0.644  p=0.0323
#              articulation: rho=+0.520  p=0.1007
#                  phrasing: rho=+0.887  p=0.0003
#            interpretation: rho=+0.689  p=0.0190

# %%
# Scatter plots: per-aggregation, overall score vs placement
from collections import defaultdict

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

for ax, agg_name in zip(axes, ["mean", "median", "min"]):
    perf_segs = defaultdict(list)
    perf_place = {}
    for m in metadata:
        if m["segment_id"] in segment_scores:
            perf_segs[m["performer"]].append(segment_scores[m["segment_id"]])
            perf_place[m["performer"]] = m["placement"]

    agg_fn = {"mean": np.mean, "median": np.median, "min": np.min}[agg_name]
    performers = sorted(perf_segs.keys())
    agg_overall = [agg_fn(perf_segs[p], axis=0).mean() for p in performers]
    placements = [perf_place[p] for p in performers]

    ax.scatter(placements, agg_overall, alpha=0.7)
    ax.set_xlabel("Competition Placement (lower = better)")
    ax.set_ylabel(f"A1 Score ({agg_name})")
    ax.set_title(f"{agg_name}: rho={corr_results[agg_name]['rho']:+.3f}")
    ax.invert_xaxis()

plt.tight_layout()
plt.savefig(COMPETITION_DIR / "correlation_scatter.png", dpi=150)
plt.show()

# %%
# Per-dimension correlation heatmap
fig, ax = plt.subplots(figsize=(10, 4))
data = []
for agg_name in ["mean", "median", "min"]:
    row = [corr_results[agg_name]["per_dimension"][d]["rho"] for d in DIMENSIONS]
    data.append(row)

sns.heatmap(
    np.array(data), annot=True, fmt=".2f", cmap="RdYlGn",
    xticklabels=DIMENSIONS, yticklabels=["mean", "median", "min"],
    ax=ax, center=0, vmin=-0.6, vmax=0.6,
)
ax.set_title("Per-Dimension Spearman rho vs Competition Placement")
plt.tight_layout()
plt.savefig(COMPETITION_DIR / "correlation_heatmap.png", dpi=150)
plt.show()

# %% [markdown]
# ## Experiment 3: Dynamic Range at Intermediate Level
#
# **Question:** Does A1 produce meaningful score variance on intermediate-level recordings?
#
# **Data:** YouTube recordings of intermediate pianists.
# Must be collected first using yt-dlp (manual search for student recitals).
#
# **No hard gate.** Diagnostic only -- informs Layer 3 data priorities.

# %%
# Intermediate recordings: search, download, and embed.
# Step 1: Run the curation script to find candidates:
#   python scripts/curate_intermediate_recordings.py
# Step 2: Review candidates.jsonl, add "approved": true to selected entries
# Step 3: Download and embed approved recordings:
#   python scripts/curate_intermediate_recordings.py --download
#
# This cell checks for existing embeddings and reports status.

INTERMEDIATE_DIR = DATA_DIR / "intermediate_cache"
INTERMEDIATE_DIR.mkdir(parents=True, exist_ok=True)
INTERMEDIATE_EMB = INTERMEDIATE_DIR / "muq_embeddings"
INTERMEDIATE_EMB.mkdir(parents=True, exist_ok=True)

n_emb = len(list(INTERMEDIATE_EMB.glob("*.pt")))
candidates_path = INTERMEDIATE_DIR / "candidates.jsonl"

if n_emb > 0:
    print(f"Intermediate embeddings: {n_emb} files (ready for scoring)")
elif candidates_path.exists():
    import jsonlines as _jl
    with _jl.open(candidates_path) as reader:
        candidates = list(reader)
    n_approved = sum(1 for c in candidates if c.get("approved"))
    print(f"Candidates found: {len(candidates)} total, {n_approved} approved")
    if n_approved == 0:
        print("Edit candidates.jsonl to approve recordings, then run:")
        print("  python scripts/curate_intermediate_recordings.py --download")
    else:
        print("Run: python scripts/curate_intermediate_recordings.py --download")
else:
    print("No intermediate data yet. Run:")
    print("  python scripts/curate_intermediate_recordings.py")
    print("Then review candidates.jsonl and approve entries.")
# Out:
# Intermediate embeddings: 629 files (ready for scoring)

# %%
# Score intermediate segments with A1 (lazy loading from directory)
if list(INTERMEDIATE_EMB.glob("*.pt")):
    int_scores = score_competition_segments(a1_model, INTERMEDIATE_EMB)
else:
    int_scores = {}
    print("No intermediate data yet. Populate INTERMEDIATE_URLS and re-run the download cell.")

# Load PercePiano scores for comparison (advanced reference)
labels = load_composite_labels(DATA_DIR / "composite_labels/composite_labels.json")
percepiano_scores = {k: np.array(v[:6]) for k, v in labels.items()}

# Compare distributions
if int_scores:
    groups = {
        "intermediate": int_scores,
        "advanced (PercePiano)": percepiano_scores,
    }
    groups["professional (Chopin 2021)"] = segment_scores

    range_results = dynamic_range_analysis(groups)

    print("\n=== Dynamic Range Analysis ===")
    for group, stats in range_results["group_stats"].items():
        print(f"{group}: mean={stats['overall_mean']:.3f}, std={stats['overall_std']:.3f}, n={stats['n_segments']}")
    print()
    for key, sep in range_results["separation"].items():
        if isinstance(sep, dict):
            print(f"  {key}: diff={sep['mean_diff']:+.3f}, Cohen's d={sep['cohens_d']:.2f}")
# Out:
# INFO:model_improvement.layer1_validation:Scored 500 segments so far
# INFO:model_improvement.layer1_validation:Scored 629 segments total
# === Dynamic Range Analysis ===
# intermediate: mean=0.565, std=0.062, n=629
# advanced (PercePiano): mean=0.552, std=0.110, n=1202
# professional (Chopin 2021): mean=0.595, std=0.064, n=2293
#
#   advanced (PercePiano)_vs_intermediate: diff=+0.013, Cohen's d=0.15
#   advanced (PercePiano)_vs_professional (Chopin 2021): diff=+0.043, Cohen's d=0.47
#   intermediate_vs_professional (Chopin 2021): diff=+0.030, Cohen's d=0.47

# %%
if int_scores:
    import pandas as pd

    fig, axes = plt.subplots(2, 3, figsize=(15, 10))
    axes = axes.flatten()

    for d, (ax, dim_name) in enumerate(zip(axes, DIMENSIONS)):
        plot_data = []
        group_labels = []
        for group_name, scores_dict in groups.items():
            vals = [s[d] for s in scores_dict.values()]
            plot_data.extend(vals)
            group_labels.extend([group_name] * len(vals))

        df = pd.DataFrame({"Score": plot_data, "Group": group_labels})
        sns.boxplot(data=df, x="Group", y="Score", ax=ax)
        ax.set_title(dim_name)
        ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right")

    plt.suptitle("Per-Dimension Score Distributions by Skill Level")
    plt.tight_layout()
    plt.savefig(INTERMEDIATE_DIR / "dynamic_range_boxplots.png", dpi=150)
    plt.show()
else:
    print("Skipping box plots -- no intermediate data available yet.")
# Out:
# /var/folders/nz/pb29np9d7r366n0szm32d14w0000gn/T/ipykernel_71043/341611695.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right")
# /var/folders/nz/pb29np9d7r366n0szm32d14w0000gn/T/ipykernel_71043/341611695.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right")
# /var/folders/nz/pb29np9d7r366n0szm32d14w0000gn/T/ipykernel_71043/341611695.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right")
# /var/folders/nz/pb29np9d7r366n0szm32d14w0000gn/T/ipykernel_71043/341611695.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right")
# /var/folders/nz/pb29np9d7r366n0szm32d14w0000gn/T/ipykernel_71043/341611695.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right")
# /var/folders/nz/pb29np9d7r366n0szm32d14w0000gn/T/ipykernel_71043/341611695.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right")

# %% [markdown]
# ## Experiment 4: MIDI-as-Context Feedback Test
#
# **Question:** Does providing structured MIDI comparison data to the teacher LLM produce
# more specific, actionable feedback than A1 scores alone?
#
# **Data:** 20 Schubert D960 mv3 segments (5 top, 10 middle, 5 bottom by quality).
#
# **Method:** Two conditions compared via randomized LLM judge:
# - **Condition A:** A1 dimension scores + student context only
# - **Condition B:** A1 dimension scores + student context + structured MIDI comparison
#   (velocity MAE/correlation, onset timing deviations, note accuracy F1)
#
# **Decision gate:** Condition B wins > 65% = BUILD score comparison pipeline.

# %%
# Load Experiment 4 results (generated by run_feedback_assessment.py)
import json
from collections import Counter

exp4_path = DATA_DIR / "experiment4_results" / "feedback_assessment_results.json"
with open(exp4_path) as f:
    exp4_results = json.load(f)

# Summary
winners = [r["judgment"]["winner"] for r in exp4_results]
winner_counts = Counter(winners)
wins_b = winner_counts.get("B", 0)
wins_a = winner_counts.get("A", 0)
total = wins_a + wins_b
win_rate_b = wins_b / total * 100 if total > 0 else 0

gate = "BUILD" if win_rate_b > 65 else "SKIP" if win_rate_b < 55 else "BORDERLINE"

print(f"=== Experiment 4: MIDI-as-Context Feedback Test ===\n")
print(f"Condition B (MIDI context) wins: {wins_b}/{total} ({win_rate_b:.0f}%)")
print(f"Condition A (scores only) wins:  {wins_a}/{total} ({100 - win_rate_b:.0f}%)")
print(f"Decision: [{gate}]\n")

# Confidence breakdown
confidence = Counter(r["judgment"].get("confidence", "unknown") for r in exp4_results)
print(f"Judge confidence: {dict(confidence)}")
for conf in ["high", "medium", "low"]:
    subset = [r for r in exp4_results if r["judgment"].get("confidence") == conf]
    if subset:
        b_wins = sum(1 for r in subset if r["judgment"]["winner"] == "B")
        print(f"  {conf}: B wins {b_wins}/{len(subset)}")

# %% [markdown]
# ## Experiment 2: AMT Degradation Test
#
# **Question:** How much does S2's pairwise accuracy drop with transcribed MIDI vs ground-truth?
#
# **Data:** 50 MAESTRO recordings with ground-truth MIDI. Transcribed with YourMT3+ (ceiling) and ByteDance (floor).
#
# **Decision gate:** Per-dimension pairwise drop < 10% = symbolic path viable.
#
# **Note:** This experiment requires installing YourMT3+ and ByteDance Piano Transcription.
# AMT transcription takes ~4-8 hours on M4. Run the transcription cells once,
# then the assessment cells reuse cached transcriptions.

# %%
with open(DATA_DIR / "maestro_cache/contrastive_mapping.json") as f:
    contrastive_mapping = json.load(f)

from model_improvement.layer1_validation import select_maestro_subset
selected_keys = select_maestro_subset(contrastive_mapping, n_recordings=50)
print(f"Selected {len(selected_keys)} unique recordings from {len(contrastive_mapping)} pieces")
print(f"Sample keys: {selected_keys[:3]}")
# Out:
# Selected 50 unique recordings from 204 pieces
# Sample keys: ['maestro_2008_MIDI-Unprocessed_02_R3_2008_01-03_ORIG_MID--AUDIO_02_R3_2008_wav--1_wav', 'maestro_2008_MIDI-Unprocessed_03_R3_2008_01-03_ORIG_MID--AUDIO_03_R3_2008_wav--1_wav', 'maestro_2008_MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--1_wav']

# %%
# AMT transcription -- run once, results are cached.
# Prerequisites:
#   1. Download MAESTRO audio: python scripts/download_maestro_subset.py
#   2. Install ByteDance: uv pip install piano-transcription-inference
#   3. Install YourMT3+: uv pip install git+https://github.com/mimbres/YourMT3.git
#
# This cell is expensive (~4-8 hours on M4). Skip if transcriptions already exist.

import soundfile as sf
from model_improvement.maestro import parse_maestro_audio_metadata
from model_improvement.audio_utils import load_audio

AMT_DIR = DATA_DIR / "amt_cache"
AMT_DIR.mkdir(parents=True, exist_ok=True)
YOURMT3_DIR = AMT_DIR / "yourmt3"
YOURMT3_DIR.mkdir(parents=True, exist_ok=True)
BYTEDANCE_DIR = AMT_DIR / "bytedance"
BYTEDANCE_DIR.mkdir(parents=True, exist_ok=True)

MAESTRO_DIR = DATA_DIR / "maestro_cache"

# Map selected segment IDs back to unique audio filenames
maestro_records = parse_maestro_audio_metadata(MAESTRO_DIR)

def _segment_id_to_audio_filename(seg_id, records):
    body = seg_id
    if body.startswith("maestro_"):
        body = body[len("maestro_"):]
    seg_idx = body.rfind("_seg")
    if seg_idx >= 0:
        body = body[:seg_idx]
    for rec in records:
        normalized = rec["audio_filename"].replace("/", "_").replace(".", "_")
        if normalized == body:
            return rec
    return None

selected_audio = {}
for seg_id in selected_keys:
    rec = _segment_id_to_audio_filename(seg_id, maestro_records)
    if rec:
        selected_audio[rec["audio_filename"]] = rec

audio_files = sorted(selected_audio.keys())
print(f"Selected {len(audio_files)} unique audio files for AMT")

# Check which audio files exist
existing = [af for af in audio_files if (MAESTRO_DIR / af).exists()]
missing = [af for af in audio_files if not (MAESTRO_DIR / af).exists()]
print(f"Audio files on disk: {len(existing)} / {len(audio_files)}")

if missing:
    print(f"\nMissing {len(missing)} audio files. Download with:")
    print("  python scripts/download_maestro_subset.py")
elif existing:
    # ByteDance transcription (expects numpy array at 16kHz)
    n_bytedance_existing = len(list(BYTEDANCE_DIR.glob("*.mid")))
    if n_bytedance_existing >= len(existing):
        print(f"\nByteDance transcriptions: {n_bytedance_existing} (cached)")
    else:
        print(f"\nRunning ByteDance transcription ({len(existing)} files)...")
        from piano_transcription_inference import PianoTranscription
        transcriptor = PianoTranscription(device="cpu")
        for i, af in enumerate(existing):
            recording_id = af.replace("/", "_").replace(".wav", "")
            out_path = BYTEDANCE_DIR / f"{recording_id}.mid"
            if out_path.exists():
                continue
            print(f"  [{i+1}/{len(existing)}] {af}")
            # Load audio as numpy array (ByteDance expects 16kHz mono)
            audio, sr = load_audio(MAESTRO_DIR / af, target_sr=16000)
            transcriptor.transcribe(audio, str(out_path))
        del transcriptor
        print(f"  ByteDance done: {len(list(BYTEDANCE_DIR.glob('*.mid')))} files")

    # YourMT3+ transcription
    n_yourmt3_existing = len(list(YOURMT3_DIR.glob("*.mid")))
    if n_yourmt3_existing >= len(existing):
        print(f"YourMT3+ transcriptions: {n_yourmt3_existing} (cached)")
    else:
        try:
            from yourmt3.transcribe import transcribe_audio
            print(f"\nRunning YourMT3+ transcription ({len(existing)} files)...")
            for i, af in enumerate(existing):
                recording_id = af.replace("/", "_").replace(".wav", "")
                out_path = YOURMT3_DIR / f"{recording_id}.mid"
                if out_path.exists():
                    continue
                audio_path = str(MAESTRO_DIR / af)
                print(f"  [{i+1}/{len(existing)}] {af}")
                transcribe_audio(audio_path, str(out_path))
            print(f"  YourMT3+ done: {len(list(YOURMT3_DIR.glob('*.mid')))} files")
        except ImportError:
            print("\nYourMT3+ not installed. Install with:")
            print("  uv pip install git+https://github.com/mimbres/YourMT3.git")
            print("Continuing with ByteDance only.")
# Out:
# INFO:model_improvement.maestro:Parsed 1276 MAESTRO audio records
# Selected 50 unique audio files for AMT
# Audio files on disk: 50 / 50
#
# Running ByteDance transcription (50 files)...
# Checkpoint path: /Users/jdhiman/piano_transcription_inference_data/note_F1=0.9677_pedal_F1=0.9186.pth
# Using cpu for inference.
# Using CPU.
#   [1/50] 2004/MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_01_Track01_wav.wav
# Segment 0 / 139
# Segment 1 / 139
# Segment 2 / 139
# Segment 3 / 139
# Segment 4 / 139
# Segment 5 / 139
# Segment 6 / 139
# Segment 7 / 139
# Segment 8 / 139
# Segment 9 / 139
# Segment 10 / 139
# Segment 11 / 139
# Segment 12 / 139
# Segment 13 / 139
# Segment 14 / 139
# Segment 15 / 139
# Segment 16 / 139
# Segment 17 / 139
# Segment 18 / 139
# Segment 19 / 139
# Segment 20 / 139
# Segment 21 / 139
# Segment 22 / 139
# Segment 23 / 139
# Segment 24 / 139
# Segment 25 / 139
# Segment 26 / 139
# Segment 27 / 139
# Segment 28 / 139
# Segment 29 / 139
# Segment 30 / 139
# Segment 31 / 139
# Segment 32 / 139
# Segment 33 / 139
# Segment 34 / 139
# Segment 35 / 139
# Segment 36 / 139
# Segment 37 / 139
# Segment 38 / 139
# Segment 39 / 139
# Segment 40 / 139
# Segment 41 / 139
# Segment 42 / 139
# Segment 43 / 139
# Segment 44 / 139
# Segment 45 / 139
# Segment 46 / 139
# Segment 47 / 139
# Segment 48 / 139
# Segment 49 / 139
# Segment 50 / 139
# Segment 51 / 139
# Segment 52 / 139
# Segment 53 / 139
# Segment 54 / 139
# Segment 55 / 139
# Segment 56 / 139
# Segment 57 / 139
# Segment 58 / 139
# Segment 59 / 139
# Segment 60 / 139
# Segment 61 / 139
# Segment 62 / 139
# Segment 63 / 139
# Segment 64 / 139
# Segment 65 / 139
# Segment 66 / 139
# Segment 67 / 139
# Segment 68 / 139
# Segment 69 / 139
# Segment 70 / 139
# Segment 71 / 139
# Segment 72 / 139
# Segment 73 / 139
# Segment 74 / 139
# Segment 75 / 139
# Segment 76 / 139
# Segment 77 / 139
# Segment 78 / 139
# Segment 79 / 139
# Segment 80 / 139
# Segment 81 / 139
# Segment 82 / 139
# Segment 83 / 139
# Segment 84 / 139
# Segment 85 / 139
# Segment 86 / 139
# Segment 87 / 139
# Segment 88 / 139
# Segment 89 / 139
# Segment 90 / 139
# Segment 91 / 139
# Segment 92 / 139
# Segment 93 / 139
# Segment 94 / 139
# Segment 95 / 139
# Segment 96 / 139
# Segment 97 / 139
# Segment 98 / 139
# Segment 99 / 139
# Segment 100 / 139
# Segment 101 / 139
# Segment 102 / 139
# Segment 103 / 139
# Segment 104 / 139
# Segment 105 / 139
# Segment 106 / 139
# Segment 107 / 139
# Segment 108 / 139
# Segment 109 / 139
# Segment 110 / 139
# Segment 111 / 139
# Segment 112 / 139
# Segment 113 / 139
# Segment 114 / 139
# Segment 115 / 139
# Segment 116 / 139
# Segment 117 / 139
# Segment 118 / 139
# Segment 119 / 139
# Segment 120 / 139
# Segment 121 / 139
# Segment 122 / 139
# Segment 123 / 139
# Segment 124 / 139
# Segment 125 / 139
# Segment 126 / 139
# Segment 127 / 139
# Segment 128 / 139
# Segment 129 / 139
# Segment 130 / 139
# Segment 131 / 139
# Segment 132 / 139
# Segment 133 / 139
# Segment 134 / 139
# Segment 135 / 139
# Segment 136 / 139
# Segment 137 / 139
# Segment 138 / 139
# Segment 139 / 139
# Write out to data/amt_cache/bytedance/2004_MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_01_Track01_wav.mid
#   [2/50] 2004/MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_02_Track02_wav.wav
# Segment 0 / 105
# Segment 1 / 105
# Segment 2 / 105
# Segment 3 / 105
# Segment 4 / 105
# Segment 5 / 105
# Segment 6 / 105
# Segment 7 / 105
# Segment 8 / 105
# Segment 9 / 105
# Segment 10 / 105
# Segment 11 / 105
# Segment 12 / 105
# Segment 13 / 105
# Segment 14 / 105
# Segment 15 / 105
# Segment 16 / 105
# Segment 17 / 105
# Segment 18 / 105
# Segment 19 / 105
# Segment 20 / 105
# Segment 21 / 105
# Segment 22 / 105
# Segment 23 / 105
# Segment 24 / 105
# Segment 25 / 105
# Segment 26 / 105
# Segment 27 / 105
# Segment 28 / 105
# Segment 29 / 105
# Segment 30 / 105
# Segment 31 / 105
# Segment 32 / 105
# Segment 33 / 105
# Segment 34 / 105
# Segment 35 / 105
# Segment 36 / 105
# Segment 37 / 105
# Segment 38 / 105
# Segment 39 / 105
# Segment 40 / 105
# Segment 41 / 105
# Segment 42 / 105
# Segment 43 / 105
# Segment 44 / 105
# Segment 45 / 105
# Segment 46 / 105
# Segment 47 / 105
# Segment 48 / 105
# Segment 49 / 105
# Segment 50 / 105
# Segment 51 / 105
# Segment 52 / 105
# Segment 53 / 105
# Segment 54 / 105
# Segment 55 / 105
# Segment 56 / 105
# Segment 57 / 105
# Segment 58 / 105
# Segment 59 / 105
# Segment 60 / 105
# Segment 61 / 105
# Segment 62 / 105
# Segment 63 / 105
# Segment 64 / 105
# Segment 65 / 105
# Segment 66 / 105
# Segment 67 / 105
# Segment 68 / 105
# Segment 69 / 105
# Segment 70 / 105
# Segment 71 / 105
# Segment 72 / 105
# Segment 73 / 105
# Segment 74 / 105
# Segment 75 / 105
# Segment 76 / 105
# Segment 77 / 105
# Segment 78 / 105
# Segment 79 / 105
# Segment 80 / 105
# Segment 81 / 105
# Segment 82 / 105
# Segment 83 / 105
# Segment 84 / 105
# Segment 85 / 105
# Segment 86 / 105
# Segment 87 / 105
# Segment 88 / 105
# Segment 89 / 105
# Segment 90 / 105
# Segment 91 / 105
# Segment 92 / 105
# Segment 93 / 105
# Segment 94 / 105
# Segment 95 / 105
# Segment 96 / 105
# Segment 97 / 105
# Segment 98 / 105
# Segment 99 / 105
# Segment 100 / 105
# Segment 101 / 105
# Segment 102 / 105
# Segment 103 / 105
# Segment 104 / 105
# Segment 105 / 105
# Write out to data/amt_cache/bytedance/2004_MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_02_Track02_wav.mid
#   [3/50] 2004/MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_03_Track03_wav.wav
# Segment 0 / 149
# Segment 1 / 149
# Segment 2 / 149
# Segment 3 / 149
# Segment 4 / 149
# Segment 5 / 149
# Segment 6 / 149
# Segment 7 / 149
# Segment 8 / 149
# Segment 9 / 149
# Segment 10 / 149
# Segment 11 / 149
# Segment 12 / 149
# Segment 13 / 149
# Segment 14 / 149
# Segment 15 / 149
# Segment 16 / 149
# Segment 17 / 149
# Segment 18 / 149
# Segment 19 / 149
# Segment 20 / 149
# Segment 21 / 149
# Segment 22 / 149
# Segment 23 / 149
# Segment 24 / 149
# Segment 25 / 149
# Segment 26 / 149
# Segment 27 / 149
# Segment 28 / 149
# Segment 29 / 149
# Segment 30 / 149
# Segment 31 / 149
# Segment 32 / 149
# Segment 33 / 149
# Segment 34 / 149
# Segment 35 / 149
# Segment 36 / 149
# Segment 37 / 149
# Segment 38 / 149
# Segment 39 / 149
# Segment 40 / 149
# Segment 41 / 149
# Segment 42 / 149
# Segment 43 / 149
# Segment 44 / 149
# Segment 45 / 149
# Segment 46 / 149
# Segment 47 / 149
# Segment 48 / 149
# Segment 49 / 149
# Segment 50 / 149
# Segment 51 / 149
# Segment 52 / 149
# Segment 53 / 149
# Segment 54 / 149
# Segment 55 / 149
# Segment 56 / 149
# Segment 57 / 149
# Segment 58 / 149
# Segment 59 / 149
# Segment 60 / 149
# Segment 61 / 149
# Segment 62 / 149
# Segment 63 / 149
# Segment 64 / 149
# Segment 65 / 149
# Segment 66 / 149
# Segment 67 / 149
# Segment 68 / 149
# Segment 69 / 149
# Segment 70 / 149
# Segment 71 / 149
# Segment 72 / 149
# Segment 73 / 149
# Segment 74 / 149
# Segment 75 / 149
# Segment 76 / 149
# Segment 77 / 149
# Segment 78 / 149
# Segment 79 / 149
# Segment 80 / 149
# Segment 81 / 149
# Segment 82 / 149
# Segment 83 / 149
# Segment 84 / 149
# Segment 85 / 149
# Segment 86 / 149
# Segment 87 / 149
# Segment 88 / 149
# Segment 89 / 149
# Segment 90 / 149
# Segment 91 / 149
# Segment 92 / 149
# Segment 93 / 149
# Segment 94 / 149
# Segment 95 / 149
# Segment 96 / 149
# Segment 97 / 149
# Segment 98 / 149
# Segment 99 / 149
# Segment 100 / 149
# Segment 101 / 149
# Segment 102 / 149
# Segment 103 / 149
# Segment 104 / 149
# Segment 105 / 149
# Segment 106 / 149
# Segment 107 / 149
# Segment 108 / 149
# Segment 109 / 149
# Segment 110 / 149
# Segment 111 / 149
# Segment 112 / 149
# Segment 113 / 149
# Segment 114 / 149
# Segment 115 / 149
# Segment 116 / 149
# Segment 117 / 149
# Segment 118 / 149
# Segment 119 / 149
# Segment 120 / 149
# Segment 121 / 149
# Segment 122 / 149
# Segment 123 / 149
# Segment 124 / 149
# Segment 125 / 149
# Segment 126 / 149
# Segment 127 / 149
# Segment 128 / 149
# Segment 129 / 149
# Segment 130 / 149
# Segment 131 / 149
# Segment 132 / 149
# Segment 133 / 149
# Segment 134 / 149
# Segment 135 / 149
# Segment 136 / 149
# Segment 137 / 149
# Segment 138 / 149
# Segment 139 / 149
# Segment 140 / 149
# Segment 141 / 149
# Segment 142 / 149
# Segment 143 / 149
# Segment 144 / 149
# Segment 145 / 149
# Segment 146 / 149
# Segment 147 / 149
# Segment 148 / 149
# Segment 149 / 149
# Write out to data/amt_cache/bytedance/2004_MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_03_Track03_wav.mid
#   [4/50] 2004/MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_01_Track01_wav.wav
# Segment 0 / 181
# Segment 1 / 181
# Segment 2 / 181
# Segment 3 / 181
# Segment 4 / 181
# Segment 5 / 181
# Segment 6 / 181
# Segment 7 / 181
# Segment 8 / 181
# Segment 9 / 181
# Segment 10 / 181
# Segment 11 / 181
# Segment 12 / 181
# Segment 13 / 181
# Segment 14 / 181
# Segment 15 / 181
# Segment 16 / 181
# Segment 17 / 181
# Segment 18 / 181
# Segment 19 / 181
# Segment 20 / 181
# Segment 21 / 181
# Segment 22 / 181
# Segment 23 / 181
# Segment 24 / 181
# Segment 25 / 181
# Segment 26 / 181
# Segment 27 / 181
# Segment 28 / 181
# Segment 29 / 181
# Segment 30 / 181
# Segment 31 / 181
# Segment 32 / 181
# Segment 33 / 181
# Segment 34 / 181
# Segment 35 / 181
# Segment 36 / 181
# Segment 37 / 181
# Segment 38 / 181
# Segment 39 / 181
# Segment 40 / 181
# Segment 41 / 181
# Segment 42 / 181
# Segment 43 / 181
# Segment 44 / 181
# Segment 45 / 181
# Segment 46 / 181
# Segment 47 / 181
# Segment 48 / 181
# Segment 49 / 181
# Segment 50 / 181
# Segment 51 / 181
# Segment 52 / 181
# Segment 53 / 181
# Segment 54 / 181
# Segment 55 / 181
# Segment 56 / 181
# Segment 57 / 181
# Segment 58 / 181
# Segment 59 / 181
# Segment 60 / 181
# Segment 61 / 181
# Segment 62 / 181
# Segment 63 / 181
# Segment 64 / 181
# Segment 65 / 181
# Segment 66 / 181
# Segment 67 / 181
# Segment 68 / 181
# Segment 69 / 181
# Segment 70 / 181
# Segment 71 / 181
# Segment 72 / 181
# Segment 73 / 181
# Segment 74 / 181
# Segment 75 / 181
# Segment 76 / 181
# Segment 77 / 181
# Segment 78 / 181
# Segment 79 / 181
# Segment 80 / 181
# Segment 81 / 181
# Segment 82 / 181
# Segment 83 / 181
# Segment 84 / 181
# Segment 85 / 181
# Segment 86 / 181
# Segment 87 / 181
# Segment 88 / 181
# Segment 89 / 181
# Segment 90 / 181
# Segment 91 / 181
# Segment 92 / 181
# Segment 93 / 181
# Segment 94 / 181
# Segment 95 / 181
# Segment 96 / 181
# Segment 97 / 181
# Segment 98 / 181
# Segment 99 / 181
# Segment 100 / 181
# Segment 101 / 181
# Segment 102 / 181
# Segment 103 / 181
# Segment 104 / 181
# Segment 105 / 181
# Segment 106 / 181
# Segment 107 / 181
# Segment 108 / 181
# Segment 109 / 181
# Segment 110 / 181
# Segment 111 / 181
# Segment 112 / 181
# Segment 113 / 181
# Segment 114 / 181
# Segment 115 / 181
# Segment 116 / 181
# Segment 117 / 181
# Segment 118 / 181
# Segment 119 / 181
# Segment 120 / 181
# Segment 121 / 181
# Segment 122 / 181
# Segment 123 / 181
# Segment 124 / 181
# Segment 125 / 181
# Segment 126 / 181
# Segment 127 / 181
# Segment 128 / 181
# Segment 129 / 181
# Segment 130 / 181
# Segment 131 / 181
# Segment 132 / 181
# Segment 133 / 181
# Segment 134 / 181
# Segment 135 / 181
# Segment 136 / 181
# Segment 137 / 181
# Segment 138 / 181
# Segment 139 / 181
# Segment 140 / 181
# Segment 141 / 181
# Segment 142 / 181
# Segment 143 / 181
# Segment 144 / 181
# Segment 145 / 181
# Segment 146 / 181
# Segment 147 / 181
# Segment 148 / 181
# Segment 149 / 181
# Segment 150 / 181
# Segment 151 / 181
# Segment 152 / 181
# Segment 153 / 181
# Segment 154 / 181
# Segment 155 / 181
# Segment 156 / 181
# Segment 157 / 181
# Segment 158 / 181
# Segment 159 / 181
# Segment 160 / 181
# Segment 161 / 181
# Segment 162 / 181
# Segment 163 / 181
# Segment 164 / 181
# Segment 165 / 181
# Segment 166 / 181
# Segment 167 / 181
# Segment 168 / 181
# Segment 169 / 181
# Segment 170 / 181
# Segment 171 / 181
# Segment 172 / 181
# Segment 173 / 181
# Segment 174 / 181
# Segment 175 / 181
# Segment 176 / 181
# Segment 177 / 181
# Segment 178 / 181
# Segment 179 / 181
# Segment 180 / 181
# Segment 181 / 181
# Write out to data/amt_cache/bytedance/2004_MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_01_Track01_wav.mid
#   [5/50] 2004/MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_02_Track02_wav.wav
# Segment 0 / 119
# Segment 1 / 119
# Segment 2 / 119
# Segment 3 / 119
# Segment 4 / 119
# Segment 5 / 119
# Segment 6 / 119
# Segment 7 / 119
# Segment 8 / 119
# Segment 9 / 119
# Segment 10 / 119
# Segment 11 / 119
# Segment 12 / 119
# Segment 13 / 119
# Segment 14 / 119
# Segment 15 / 119
# Segment 16 / 119
# Segment 17 / 119
# Segment 18 / 119
# Segment 19 / 119
# Segment 20 / 119
# Segment 21 / 119
# Segment 22 / 119
# Segment 23 / 119
# Segment 24 / 119
# Segment 25 / 119
# Segment 26 / 119
# Segment 27 / 119
# Segment 28 / 119
# Segment 29 / 119
# Segment 30 / 119
# Segment 31 / 119
# Segment 32 / 119
# Segment 33 / 119
# Segment 34 / 119
# Segment 35 / 119
# Segment 36 / 119
# Segment 37 / 119
# Segment 38 / 119
# Segment 39 / 119
# Segment 40 / 119
# Segment 41 / 119
# Segment 42 / 119
# Segment 43 / 119
# Segment 44 / 119
# Segment 45 / 119
# Segment 46 / 119
# Segment 47 / 119
# Segment 48 / 119
# Segment 49 / 119
# Segment 50 / 119
# Segment 51 / 119
# Segment 52 / 119
# Segment 53 / 119
# Segment 54 / 119
# Segment 55 / 119
# Segment 56 / 119
# Segment 57 / 119
# Segment 58 / 119
# Segment 59 / 119
# Segment 60 / 119
# Segment 61 / 119
# Segment 62 / 119
# Segment 63 / 119
# Segment 64 / 119
# Segment 65 / 119
# Segment 66 / 119
# Segment 67 / 119
# Segment 68 / 119
# Segment 69 / 119
# Segment 70 / 119
# Segment 71 / 119
# Segment 72 / 119
# Segment 73 / 119
# Segment 74 / 119
# Segment 75 / 119
# Segment 76 / 119
# Segment 77 / 119
# Segment 78 / 119
# Segment 79 / 119
# Segment 80 / 119
# Segment 81 / 119
# Segment 82 / 119
# Segment 83 / 119
# Segment 84 / 119
# Segment 85 / 119
# Segment 86 / 119
# Segment 87 / 119
# Segment 88 / 119
# Segment 89 / 119
# Segment 90 / 119
# Segment 91 / 119
# Segment 92 / 119
# Segment 93 / 119
# Segment 94 / 119
# Segment 95 / 119
# Segment 96 / 119
# Segment 97 / 119
# Segment 98 / 119
# Segment 99 / 119
# Segment 100 / 119
# Segment 101 / 119
# Segment 102 / 119
# Segment 103 / 119
# Segment 104 / 119
# Segment 105 / 119
# Segment 106 / 119
# Segment 107 / 119
# Segment 108 / 119
# Segment 109 / 119
# Segment 110 / 119
# Segment 111 / 119
# Segment 112 / 119
# Segment 113 / 119
# Segment 114 / 119
# Segment 115 / 119
# Segment 116 / 119
# Segment 117 / 119
# Segment 118 / 119
# Segment 119 / 119
# Write out to data/amt_cache/bytedance/2004_MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_02_Track02_wav.mid
#   [6/50] 2004/MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_03_Track03_wav.wav
# Segment 0 / 45
# Segment 1 / 45
# Segment 2 / 45
# Segment 3 / 45
# Segment 4 / 45
# Segment 5 / 45
# Segment 6 / 45
# Segment 7 / 45
# Segment 8 / 45
# Segment 9 / 45
# Segment 10 / 45
# Segment 11 / 45
# Segment 12 / 45
# Segment 13 / 45
# Segment 14 / 45
# Segment 15 / 45
# Segment 16 / 45
# Segment 17 / 45
# Segment 18 / 45
# Segment 19 / 45
# Segment 20 / 45
# Segment 21 / 45
# Segment 22 / 45
# Segment 23 / 45
# Segment 24 / 45
# Segment 25 / 45
# Segment 26 / 45
# Segment 27 / 45
# Segment 28 / 45
# Segment 29 / 45
# Segment 30 / 45
# Segment 31 / 45
# Segment 32 / 45
# Segment 33 / 45
# Segment 34 / 45
# Segment 35 / 45
# Segment 36 / 45
# Segment 37 / 45
# Segment 38 / 45
# Segment 39 / 45
# Segment 40 / 45
# Segment 41 / 45
# Segment 42 / 45
# Segment 43 / 45
# Segment 44 / 45
# Segment 45 / 45
# Write out to data/amt_cache/bytedance/2004_MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_03_Track03_wav.mid
#   [7/50] 2004/MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_04_Track04_wav.wav
# Segment 0 / 91
# Segment 1 / 91
# Segment 2 / 91
# Segment 3 / 91
# Segment 4 / 91
# Segment 5 / 91
# Segment 6 / 91
# Segment 7 / 91
# Segment 8 / 91
# Segment 9 / 91
# Segment 10 / 91
# Segment 11 / 91
# Segment 12 / 91
# Segment 13 / 91
# Segment 14 / 91
# Segment 15 / 91
# Segment 16 / 91
# Segment 17 / 91
# Segment 18 / 91
# Segment 19 / 91
# Segment 20 / 91
# Segment 21 / 91
# Segment 22 / 91
# Segment 23 / 91
# Segment 24 / 91
# Segment 25 / 91
# Segment 26 / 91
# Segment 27 / 91
# Segment 28 / 91
# Segment 29 / 91
# Segment 30 / 91
# Segment 31 / 91
# Segment 32 / 91
# Segment 33 / 91
# Segment 34 / 91
# Segment 35 / 91
# Segment 36 / 91
# Segment 37 / 91
# Segment 38 / 91
# Segment 39 / 91
# Segment 40 / 91
# Segment 41 / 91
# Segment 42 / 91
# Segment 43 / 91
# Segment 44 / 91
# Segment 45 / 91
# Segment 46 / 91
# Segment 47 / 91
# Segment 48 / 91
# Segment 49 / 91
# Segment 50 / 91
# Segment 51 / 91
# Segment 52 / 91
# Segment 53 / 91
# Segment 54 / 91
# Segment 55 / 91
# Segment 56 / 91
# Segment 57 / 91
# Segment 58 / 91
# Segment 59 / 91
# Segment 60 / 91
# Segment 61 / 91
# Segment 62 / 91
# Segment 63 / 91
# Segment 64 / 91
# Segment 65 / 91
# Segment 66 / 91
# Segment 67 / 91
# Segment 68 / 91
# Segment 69 / 91
# Segment 70 / 91
# Segment 71 / 91
# Segment 72 / 91
# Segment 73 / 91
# Segment 74 / 91
# Segment 75 / 91
# Segment 76 / 91
# Segment 77 / 91
# Segment 78 / 91
# Segment 79 / 91
# Segment 80 / 91
# Segment 81 / 91
# Segment 82 / 91
# Segment 83 / 91
# Segment 84 / 91
# Segment 85 / 91
# Segment 86 / 91
# Segment 87 / 91
# Segment 88 / 91
# Segment 89 / 91
# Segment 90 / 91
# Segment 91 / 91
# Write out to data/amt_cache/bytedance/2004_MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_04_Track04_wav.mid
#   [8/50] 2004/MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_01_Track01_wav.wav
# Segment 0 / 91
# Segment 1 / 91
# Segment 2 / 91
# Segment 3 / 91
# Segment 4 / 91
# Segment 5 / 91
# Segment 6 / 91
# Segment 7 / 91
# Segment 8 / 91
# Segment 9 / 91
# Segment 10 / 91
# Segment 11 / 91
# Segment 12 / 91
# Segment 13 / 91
# Segment 14 / 91
# Segment 15 / 91
# Segment 16 / 91
# Segment 17 / 91
# Segment 18 / 91
# Segment 19 / 91
# Segment 20 / 91
# Segment 21 / 91
# Segment 22 / 91
# Segment 23 / 91
# Segment 24 / 91
# Segment 25 / 91
# Segment 26 / 91
# Segment 27 / 91
# Segment 28 / 91
# Segment 29 / 91
# Segment 30 / 91
# Segment 31 / 91
# Segment 32 / 91
# Segment 33 / 91
# Segment 34 / 91
# Segment 35 / 91
# Segment 36 / 91
# Segment 37 / 91
# Segment 38 / 91
# Segment 39 / 91
# Segment 40 / 91
# Segment 41 / 91
# Segment 42 / 91
# Segment 43 / 91
# Segment 44 / 91
# Segment 45 / 91
# Segment 46 / 91
# Segment 47 / 91
# Segment 48 / 91
# Segment 49 / 91
# Segment 50 / 91
# Segment 51 / 91
# Segment 52 / 91
# Segment 53 / 91
# Segment 54 / 91
# Segment 55 / 91
# Segment 56 / 91
# Segment 57 / 91
# Segment 58 / 91
# Segment 59 / 91
# Segment 60 / 91
# Segment 61 / 91
# Segment 62 / 91
# Segment 63 / 91
# Segment 64 / 91
# Segment 65 / 91
# Segment 66 / 91
# Segment 67 / 91
# Segment 68 / 91
# Segment 69 / 91
# Segment 70 / 91
# Segment 71 / 91
# Segment 72 / 91
# Segment 73 / 91
# Segment 74 / 91
# Segment 75 / 91
# Segment 76 / 91
# Segment 77 / 91
# Segment 78 / 91
# Segment 79 / 91
# Segment 80 / 91
# Segment 81 / 91
# Segment 82 / 91
# Segment 83 / 91
# Segment 84 / 91
# Segment 85 / 91
# Segment 86 / 91
# Segment 87 / 91
# Segment 88 / 91
# Segment 89 / 91
# Segment 90 / 91
# Segment 91 / 91
# Write out to data/amt_cache/bytedance/2004_MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_01_Track01_wav.mid
#   [9/50] 2004/MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_02_Track02_wav.wav
# Segment 0 / 93
# Segment 1 / 93
# Segment 2 / 93
# Segment 3 / 93
# Segment 4 / 93
# Segment 5 / 93
# Segment 6 / 93
# Segment 7 / 93
# Segment 8 / 93
# Segment 9 / 93
# Segment 10 / 93
# Segment 11 / 93
# Segment 12 / 93
# Segment 13 / 93
# Segment 14 / 93
# Segment 15 / 93
# Segment 16 / 93
# Segment 17 / 93
# Segment 18 / 93
# Segment 19 / 93
# Segment 20 / 93
# Segment 21 / 93
# Segment 22 / 93
# Segment 23 / 93
# Segment 24 / 93
# Segment 25 / 93
# Segment 26 / 93
# Segment 27 / 93
# Segment 28 / 93
# Segment 29 / 93
# Segment 30 / 93
# Segment 31 / 93
# Segment 32 / 93
# Segment 33 / 93
# Segment 34 / 93
# Segment 35 / 93
# Segment 36 / 93
# Segment 37 / 93
# Segment 38 / 93
# Segment 39 / 93
# Segment 40 / 93
# Segment 41 / 93
# Segment 42 / 93
# Segment 43 / 93
# Segment 44 / 93
# Segment 45 / 93
# Segment 46 / 93
# Segment 47 / 93
# Segment 48 / 93
# Segment 49 / 93
# Segment 50 / 93
# Segment 51 / 93
# Segment 52 / 93
# Segment 53 / 93
# Segment 54 / 93
# Segment 55 / 93
# Segment 56 / 93
# Segment 57 / 93
# Segment 58 / 93
# Segment 59 / 93
# Segment 60 / 93
# Segment 61 / 93
# Segment 62 / 93
# Segment 63 / 93
# Segment 64 / 93
# Segment 65 / 93
# Segment 66 / 93
# Segment 67 / 93
# Segment 68 / 93
# Segment 69 / 93
# Segment 70 / 93
# Segment 71 / 93
# Segment 72 / 93
# Segment 73 / 93
# Segment 74 / 93
# Segment 75 / 93
# Segment 76 / 93
# Segment 77 / 93
# Segment 78 / 93
# Segment 79 / 93
# Segment 80 / 93
# Segment 81 / 93
# Segment 82 / 93
# Segment 83 / 93
# Segment 84 / 93
# Segment 85 / 93
# Segment 86 / 93
# Segment 87 / 93
# Segment 88 / 93
# Segment 89 / 93
# Segment 90 / 93
# Segment 91 / 93
# Segment 92 / 93
# Segment 93 / 93
# Write out to data/amt_cache/bytedance/2004_MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_02_Track02_wav.mid
#   [10/50] 2004/MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_03_Track03_wav.wav
# Segment 0 / 141
# Segment 1 / 141
# Segment 2 / 141
# Segment 3 / 141
# Segment 4 / 141
# Segment 5 / 141
# Segment 6 / 141
# Segment 7 / 141
# Segment 8 / 141
# Segment 9 / 141
# Segment 10 / 141
# Segment 11 / 141
# Segment 12 / 141
# Segment 13 / 141
# Segment 14 / 141
# Segment 15 / 141
# Segment 16 / 141
# Segment 17 / 141
# Segment 18 / 141
# Segment 19 / 141
# Segment 20 / 141
# Segment 21 / 141
# Segment 22 / 141
# Segment 23 / 141
# Segment 24 / 141
# Segment 25 / 141
# Segment 26 / 141
# Segment 27 / 141
# Segment 28 / 141
# Segment 29 / 141
# Segment 30 / 141
# Segment 31 / 141
# Segment 32 / 141
# Segment 33 / 141
# Segment 34 / 141
# Segment 35 / 141
# Segment 36 / 141
# Segment 37 / 141
# Segment 38 / 141
# Segment 39 / 141
# Segment 40 / 141
# Segment 41 / 141
# Segment 42 / 141
# Segment 43 / 141
# Segment 44 / 141
# Segment 45 / 141
# Segment 46 / 141
# Segment 47 / 141
# Segment 48 / 141
# Segment 49 / 141
# Segment 50 / 141
# Segment 51 / 141
# Segment 52 / 141
# Segment 53 / 141
# Segment 54 / 141
# Segment 55 / 141
# Segment 56 / 141
# Segment 57 / 141
# Segment 58 / 141
# Segment 59 / 141
# Segment 60 / 141
# Segment 61 / 141
# Segment 62 / 141
# Segment 63 / 141
# Segment 64 / 141
# Segment 65 / 141
# Segment 66 / 141
# Segment 67 / 141
# Segment 68 / 141
# Segment 69 / 141
# Segment 70 / 141
# Segment 71 / 141
# Segment 72 / 141
# Segment 73 / 141
# Segment 74 / 141
# Segment 75 / 141
# Segment 76 / 141
# Segment 77 / 141
# Segment 78 / 141
# Segment 79 / 141
# Segment 80 / 141
# Segment 81 / 141
# Segment 82 / 141
# Segment 83 / 141
# Segment 84 / 141
# Segment 85 / 141
# Segment 86 / 141
# Segment 87 / 141
# Segment 88 / 141
# Segment 89 / 141
# Segment 90 / 141
# Segment 91 / 141
# Segment 92 / 141
# Segment 93 / 141
# Segment 94 / 141
# Segment 95 / 141
# Segment 96 / 141
# Segment 97 / 141
# Segment 98 / 141
# Segment 99 / 141
# Segment 100 / 141
# Segment 101 / 141
# Segment 102 / 141
# Segment 103 / 141
# Segment 104 / 141
# Segment 105 / 141
# Segment 106 / 141
# Segment 107 / 141
# Segment 108 / 141
# Segment 109 / 141
# Segment 110 / 141
# Segment 111 / 141
# Segment 112 / 141
# Segment 113 / 141
# Segment 114 / 141
# Segment 115 / 141
# Segment 116 / 141
# Segment 117 / 141
# Segment 118 / 141
# Segment 119 / 141
# Segment 120 / 141
# Segment 121 / 141
# Segment 122 / 141
# Segment 123 / 141
# Segment 124 / 141
# Segment 125 / 141
# Segment 126 / 141
# Segment 127 / 141
# Segment 128 / 141
# Segment 129 / 141
# Segment 130 / 141
# Segment 131 / 141
# Segment 132 / 141
# Segment 133 / 141
# Segment 134 / 141
# Segment 135 / 141
# Segment 136 / 141
# Segment 137 / 141
# Segment 138 / 141
# Segment 139 / 141
# Segment 140 / 141
# Segment 141 / 141
# Write out to data/amt_cache/bytedance/2004_MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_03_Track03_wav.mid
#   [11/50] 2004/MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_01_Track01_wav.wav
# Segment 0 / 93
# Segment 1 / 93
# Segment 2 / 93
# Segment 3 / 93
# Segment 4 / 93
# Segment 5 / 93
# Segment 6 / 93
# Segment 7 / 93
# Segment 8 / 93
# Segment 9 / 93
# Segment 10 / 93
# Segment 11 / 93
# Segment 12 / 93
# Segment 13 / 93
# Segment 14 / 93
# Segment 15 / 93
# Segment 16 / 93
# Segment 17 / 93
# Segment 18 / 93
# Segment 19 / 93
# Segment 20 / 93
# Segment 21 / 93
# Segment 22 / 93
# Segment 23 / 93
# Segment 24 / 93
# Segment 25 / 93
# Segment 26 / 93
# Segment 27 / 93
# Segment 28 / 93
# Segment 29 / 93
# Segment 30 / 93
# Segment 31 / 93
# Segment 32 / 93
# Segment 33 / 93
# Segment 34 / 93
# Segment 35 / 93
# Segment 36 / 93
# Segment 37 / 93
# Segment 38 / 93
# Segment 39 / 93
# Segment 40 / 93
# Segment 41 / 93
# Segment 42 / 93
# Segment 43 / 93
# Segment 44 / 93
# Segment 45 / 93
# Segment 46 / 93
# Segment 47 / 93
# Segment 48 / 93
# Segment 49 / 93
# Segment 50 / 93
# Segment 51 / 93
# Segment 52 / 93
# Segment 53 / 93
# Segment 54 / 93
# Segment 55 / 93
# Segment 56 / 93
# Segment 57 / 93
# Segment 58 / 93
# Segment 59 / 93
# Segment 60 / 93
# Segment 61 / 93
# Segment 62 / 93
# Segment 63 / 93
# Segment 64 / 93
# Segment 65 / 93
# Segment 66 / 93
# Segment 67 / 93
# Segment 68 / 93
# Segment 69 / 93
# Segment 70 / 93
# Segment 71 / 93
# Segment 72 / 93
# Segment 73 / 93
# Segment 74 / 93
# Segment 75 / 93
# Segment 76 / 93
# Segment 77 / 93
# Segment 78 / 93
# Segment 79 / 93
# Segment 80 / 93
# Segment 81 / 93
# Segment 82 / 93
# Segment 83 / 93
# Segment 84 / 93
# Segment 85 / 93
# Segment 86 / 93
# Segment 87 / 93
# Segment 88 / 93
# Segment 89 / 93
# Segment 90 / 93
# Segment 91 / 93
# Segment 92 / 93
# Segment 93 / 93
# Write out to data/amt_cache/bytedance/2004_MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_01_Track01_wav.mid
#   [12/50] 2004/MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_02_Track02_wav.wav
# Segment 0 / 93
# Segment 1 / 93
# Segment 2 / 93
# Segment 3 / 93
# Segment 4 / 93
# Segment 5 / 93
# Segment 6 / 93
# Segment 7 / 93
# Segment 8 / 93
# Segment 9 / 93
# Segment 10 / 93
# Segment 11 / 93
# Segment 12 / 93
# Segment 13 / 93
# Segment 14 / 93
# Segment 15 / 93
# Segment 16 / 93
# Segment 17 / 93
# Segment 18 / 93
# Segment 19 / 93
# Segment 20 / 93
# Segment 21 / 93
# Segment 22 / 93
# Segment 23 / 93
# Segment 24 / 93
# Segment 25 / 93
# Segment 26 / 93
# Segment 27 / 93
# Segment 28 / 93
# Segment 29 / 93
# Segment 30 / 93
# Segment 31 / 93
# Segment 32 / 93
# Segment 33 / 93
# Segment 34 / 93
# Segment 35 / 93
# Segment 36 / 93
# Segment 37 / 93
# Segment 38 / 93
# Segment 39 / 93
# Segment 40 / 93
# Segment 41 / 93
# Segment 42 / 93
# Segment 43 / 93
# Segment 44 / 93
# Segment 45 / 93
# Segment 46 / 93
# Segment 47 / 93
# Segment 48 / 93
# Segment 49 / 93
# Segment 50 / 93
# Segment 51 / 93
# Segment 52 / 93
# Segment 53 / 93
# Segment 54 / 93
# Segment 55 / 93
# Segment 56 / 93
# Segment 57 / 93
# Segment 58 / 93
# Segment 59 / 93
# Segment 60 / 93
# Segment 61 / 93
# Segment 62 / 93
# Segment 63 / 93
# Segment 64 / 93
# Segment 65 / 93
# Segment 66 / 93
# Segment 67 / 93
# Segment 68 / 93
# Segment 69 / 93
# Segment 70 / 93
# Segment 71 / 93
# Segment 72 / 93
# Segment 73 / 93
# Segment 74 / 93
# Segment 75 / 93
# Segment 76 / 93
# Segment 77 / 93
# Segment 78 / 93
# Segment 79 / 93
# Segment 80 / 93
# Segment 81 / 93
# Segment 82 / 93
# Segment 83 / 93
# Segment 84 / 93
# Segment 85 / 93
# Segment 86 / 93
# Segment 87 / 93
# Segment 88 / 93
# Segment 89 / 93
# Segment 90 / 93
# Segment 91 / 93
# Segment 92 / 93
# Segment 93 / 93
# Write out to data/amt_cache/bytedance/2004_MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_02_Track02_wav.mid
#   [13/50] 2004/MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_03_Track03_wav.wav
# Segment 0 / 31
# Segment 1 / 31
# Segment 2 / 31
# Segment 3 / 31
# Segment 4 / 31
# Segment 5 / 31
# Segment 6 / 31
# Segment 7 / 31
# Segment 8 / 31
# Segment 9 / 31
# Segment 10 / 31
# Segment 11 / 31
# Segment 12 / 31
# Segment 13 / 31
# Segment 14 / 31
# Segment 15 / 31
# Segment 16 / 31
# Segment 17 / 31
# Segment 18 / 31
# Segment 19 / 31
# Segment 20 / 31
# Segment 21 / 31
# Segment 22 / 31
# Segment 23 / 31
# Segment 24 / 31
# Segment 25 / 31
# Segment 26 / 31
# Segment 27 / 31
# Segment 28 / 31
# Segment 29 / 31
# Segment 30 / 31
# Segment 31 / 31
# Write out to data/amt_cache/bytedance/2004_MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_03_Track03_wav.mid
#   [14/50] 2004/MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_04_Track04_wav.wav
# Segment 0 / 109
# Segment 1 / 109
# Segment 2 / 109
# Segment 3 / 109
# Segment 4 / 109
# Segment 5 / 109
# Segment 6 / 109
# Segment 7 / 109
# Segment 8 / 109
# Segment 9 / 109
# Segment 10 / 109
# Segment 11 / 109
# Segment 12 / 109
# Segment 13 / 109
# Segment 14 / 109
# Segment 15 / 109
# Segment 16 / 109
# Segment 17 / 109
# Segment 18 / 109
# Segment 19 / 109
# Segment 20 / 109
# Segment 21 / 109
# Segment 22 / 109
# Segment 23 / 109
# Segment 24 / 109
# Segment 25 / 109
# Segment 26 / 109
# Segment 27 / 109
# Segment 28 / 109
# Segment 29 / 109
# Segment 30 / 109
# Segment 31 / 109
# Segment 32 / 109
# Segment 33 / 109
# Segment 34 / 109
# Segment 35 / 109
# Segment 36 / 109
# Segment 37 / 109
# Segment 38 / 109
# Segment 39 / 109
# Segment 40 / 109
# Segment 41 / 109
# Segment 42 / 109
# Segment 43 / 109
# Segment 44 / 109
# Segment 45 / 109
# Segment 46 / 109
# Segment 47 / 109
# Segment 48 / 109
# Segment 49 / 109
# Segment 50 / 109
# Segment 51 / 109
# Segment 52 / 109
# Segment 53 / 109
# Segment 54 / 109
# Segment 55 / 109
# Segment 56 / 109
# Segment 57 / 109
# Segment 58 / 109
# Segment 59 / 109
# Segment 60 / 109
# Segment 61 / 109
# Segment 62 / 109
# Segment 63 / 109
# Segment 64 / 109
# Segment 65 / 109
# Segment 66 / 109
# Segment 67 / 109
# Segment 68 / 109
# Segment 69 / 109
# Segment 70 / 109
# Segment 71 / 109
# Segment 72 / 109
# Segment 73 / 109
# Segment 74 / 109
# Segment 75 / 109
# Segment 76 / 109
# Segment 77 / 109
# Segment 78 / 109
# Segment 79 / 109
# Segment 80 / 109
# Segment 81 / 109
# Segment 82 / 109
# Segment 83 / 109
# Segment 84 / 109
# Segment 85 / 109
# Segment 86 / 109
# Segment 87 / 109
# Segment 88 / 109
# Segment 89 / 109
# Segment 90 / 109
# Segment 91 / 109
# Segment 92 / 109
# Segment 93 / 109
# Segment 94 / 109
# Segment 95 / 109
# Segment 96 / 109
# Segment 97 / 109
# Segment 98 / 109
# Segment 99 / 109
# Segment 100 / 109
# Segment 101 / 109
# Segment 102 / 109
# Segment 103 / 109
# Segment 104 / 109
# Segment 105 / 109
# Segment 106 / 109
# Segment 107 / 109
# Segment 108 / 109
# Segment 109 / 109
# Write out to data/amt_cache/bytedance/2004_MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_04_Track04_wav.mid
#   [15/50] 2008/MIDI-Unprocessed_02_R3_2008_01-03_ORIG_MID--AUDIO_02_R3_2008_wav--1.wav
# Segment 0 / 109
# Segment 1 / 109
# Segment 2 / 109
# Segment 3 / 109
# Segment 4 / 109
# Segment 5 / 109
# Segment 6 / 109
# Segment 7 / 109
# Segment 8 / 109
# Segment 9 / 109
# Segment 10 / 109
# Segment 11 / 109
# Segment 12 / 109
# Segment 13 / 109
# Segment 14 / 109
# Segment 15 / 109
# Segment 16 / 109
# Segment 17 / 109
# Segment 18 / 109
# Segment 19 / 109
# Segment 20 / 109
# Segment 21 / 109
# Segment 22 / 109
# Segment 23 / 109
# Segment 24 / 109
# Segment 25 / 109
# Segment 26 / 109
# Segment 27 / 109
# Segment 28 / 109
# Segment 29 / 109
# Segment 30 / 109
# Segment 31 / 109
# Segment 32 / 109
# Segment 33 / 109
# Segment 34 / 109
# Segment 35 / 109
# Segment 36 / 109
# Segment 37 / 109
# Segment 38 / 109
# Segment 39 / 109
# Segment 40 / 109
# Segment 41 / 109
# Segment 42 / 109
# Segment 43 / 109
# Segment 44 / 109
# Segment 45 / 109
# Segment 46 / 109
# Segment 47 / 109
# Segment 48 / 109
# Segment 49 / 109
# Segment 50 / 109
# Segment 51 / 109
# Segment 52 / 109
# Segment 53 / 109
# Segment 54 / 109
# Segment 55 / 109
# Segment 56 / 109
# Segment 57 / 109
# Segment 58 / 109
# Segment 59 / 109
# Segment 60 / 109
# Segment 61 / 109
# Segment 62 / 109
# Segment 63 / 109
# Segment 64 / 109
# Segment 65 / 109
# Segment 66 / 109
# Segment 67 / 109
# Segment 68 / 109
# Segment 69 / 109
# Segment 70 / 109
# Segment 71 / 109
# Segment 72 / 109
# Segment 73 / 109
# Segment 74 / 109
# Segment 75 / 109
# Segment 76 / 109
# Segment 77 / 109
# Segment 78 / 109
# Segment 79 / 109
# Segment 80 / 109
# Segment 81 / 109
# Segment 82 / 109
# Segment 83 / 109
# Segment 84 / 109
# Segment 85 / 109
# Segment 86 / 109
# Segment 87 / 109
# Segment 88 / 109
# Segment 89 / 109
# Segment 90 / 109
# Segment 91 / 109
# Segment 92 / 109
# Segment 93 / 109
# Segment 94 / 109
# Segment 95 / 109
# Segment 96 / 109
# Segment 97 / 109
# Segment 98 / 109
# Segment 99 / 109
# Segment 100 / 109
# Segment 101 / 109
# Segment 102 / 109
# Segment 103 / 109
# Segment 104 / 109
# Segment 105 / 109
# Segment 106 / 109
# Segment 107 / 109
# Segment 108 / 109
# Segment 109 / 109
# Write out to data/amt_cache/bytedance/2008_MIDI-Unprocessed_02_R3_2008_01-03_ORIG_MID--AUDIO_02_R3_2008_wav--1.mid
#   [16/50] 2008/MIDI-Unprocessed_03_R3_2008_01-03_ORIG_MID--AUDIO_03_R3_2008_wav--1.wav
# Segment 0 / 127
# Segment 1 / 127
# Segment 2 / 127
# Segment 3 / 127
# Segment 4 / 127
# Segment 5 / 127
# Segment 6 / 127
# Segment 7 / 127
# Segment 8 / 127
# Segment 9 / 127
# Segment 10 / 127
# Segment 11 / 127
# Segment 12 / 127
# Segment 13 / 127
# Segment 14 / 127
# Segment 15 / 127
# Segment 16 / 127
# Segment 17 / 127
# Segment 18 / 127
# Segment 19 / 127
# Segment 20 / 127
# Segment 21 / 127
# Segment 22 / 127
# Segment 23 / 127
# Segment 24 / 127
# Segment 25 / 127
# Segment 26 / 127
# Segment 27 / 127
# Segment 28 / 127
# Segment 29 / 127
# Segment 30 / 127
# Segment 31 / 127
# Segment 32 / 127
# Segment 33 / 127
# Segment 34 / 127
# Segment 35 / 127
# Segment 36 / 127
# Segment 37 / 127
# Segment 38 / 127
# Segment 39 / 127
# Segment 40 / 127
# Segment 41 / 127
# Segment 42 / 127
# Segment 43 / 127
# Segment 44 / 127
# Segment 45 / 127
# Segment 46 / 127
# Segment 47 / 127
# Segment 48 / 127
# Segment 49 / 127
# Segment 50 / 127
# Segment 51 / 127
# Segment 52 / 127
# Segment 53 / 127
# Segment 54 / 127
# Segment 55 / 127
# Segment 56 / 127
# Segment 57 / 127
# Segment 58 / 127
# Segment 59 / 127
# Segment 60 / 127
# Segment 61 / 127
# Segment 62 / 127
# Segment 63 / 127
# Segment 64 / 127
# Segment 65 / 127
# Segment 66 / 127
# Segment 67 / 127
# Segment 68 / 127
# Segment 69 / 127
# Segment 70 / 127
# Segment 71 / 127
# Segment 72 / 127
# Segment 73 / 127
# Segment 74 / 127
# Segment 75 / 127
# Segment 76 / 127
# Segment 77 / 127
# Segment 78 / 127
# Segment 79 / 127
# Segment 80 / 127
# Segment 81 / 127
# Segment 82 / 127
# Segment 83 / 127
# Segment 84 / 127
# Segment 85 / 127
# Segment 86 / 127
# Segment 87 / 127
# Segment 88 / 127
# Segment 89 / 127
# Segment 90 / 127
# Segment 91 / 127
# Segment 92 / 127
# Segment 93 / 127
# Segment 94 / 127
# Segment 95 / 127
# Segment 96 / 127
# Segment 97 / 127
# Segment 98 / 127
# Segment 99 / 127
# Segment 100 / 127
# Segment 101 / 127
# Segment 102 / 127
# Segment 103 / 127
# Segment 104 / 127
# Segment 105 / 127
# Segment 106 / 127
# Segment 107 / 127
# Segment 108 / 127
# Segment 109 / 127
# Segment 110 / 127
# Segment 111 / 127
# Segment 112 / 127
# Segment 113 / 127
# Segment 114 / 127
# Segment 115 / 127
# Segment 116 / 127
# Segment 117 / 127
# Segment 118 / 127
# Segment 119 / 127
# Segment 120 / 127
# Segment 121 / 127
# Segment 122 / 127
# Segment 123 / 127
# Segment 124 / 127
# Segment 125 / 127
# Segment 126 / 127
# Segment 127 / 127
# Write out to data/amt_cache/bytedance/2008_MIDI-Unprocessed_03_R3_2008_01-03_ORIG_MID--AUDIO_03_R3_2008_wav--1.mid
#   [17/50] 2008/MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--1.wav
# Segment 0 / 129
# Segment 1 / 129
# Segment 2 / 129
# Segment 3 / 129
# Segment 4 / 129
# Segment 5 / 129
# Segment 6 / 129
# Segment 7 / 129
# Segment 8 / 129
# Segment 9 / 129
# Segment 10 / 129
# Segment 11 / 129
# Segment 12 / 129
# Segment 13 / 129
# Segment 14 / 129
# Segment 15 / 129
# Segment 16 / 129
# Segment 17 / 129
# Segment 18 / 129
# Segment 19 / 129
# Segment 20 / 129
# Segment 21 / 129
# Segment 22 / 129
# Segment 23 / 129
# Segment 24 / 129
# Segment 25 / 129
# Segment 26 / 129
# Segment 27 / 129
# Segment 28 / 129
# Segment 29 / 129
# Segment 30 / 129
# Segment 31 / 129
# Segment 32 / 129
# Segment 33 / 129
# Segment 34 / 129
# Segment 35 / 129
# Segment 36 / 129
# Segment 37 / 129
# Segment 38 / 129
# Segment 39 / 129
# Segment 40 / 129
# Segment 41 / 129
# Segment 42 / 129
# Segment 43 / 129
# Segment 44 / 129
# Segment 45 / 129
# Segment 46 / 129
# Segment 47 / 129
# Segment 48 / 129
# Segment 49 / 129
# Segment 50 / 129
# Segment 51 / 129
# Segment 52 / 129
# Segment 53 / 129
# Segment 54 / 129
# Segment 55 / 129
# Segment 56 / 129
# Segment 57 / 129
# Segment 58 / 129
# Segment 59 / 129
# Segment 60 / 129
# Segment 61 / 129
# Segment 62 / 129
# Segment 63 / 129
# Segment 64 / 129
# Segment 65 / 129
# Segment 66 / 129
# Segment 67 / 129
# Segment 68 / 129
# Segment 69 / 129
# Segment 70 / 129
# Segment 71 / 129
# Segment 72 / 129
# Segment 73 / 129
# Segment 74 / 129
# Segment 75 / 129
# Segment 76 / 129
# Segment 77 / 129
# Segment 78 / 129
# Segment 79 / 129
# Segment 80 / 129
# Segment 81 / 129
# Segment 82 / 129
# Segment 83 / 129
# Segment 84 / 129
# Segment 85 / 129
# Segment 86 / 129
# Segment 87 / 129
# Segment 88 / 129
# Segment 89 / 129
# Segment 90 / 129
# Segment 91 / 129
# Segment 92 / 129
# Segment 93 / 129
# Segment 94 / 129
# Segment 95 / 129
# Segment 96 / 129
# Segment 97 / 129
# Segment 98 / 129
# Segment 99 / 129
# Segment 100 / 129
# Segment 101 / 129
# Segment 102 / 129
# Segment 103 / 129
# Segment 104 / 129
# Segment 105 / 129
# Segment 106 / 129
# Segment 107 / 129
# Segment 108 / 129
# Segment 109 / 129
# Segment 110 / 129
# Segment 111 / 129
# Segment 112 / 129
# Segment 113 / 129
# Segment 114 / 129
# Segment 115 / 129
# Segment 116 / 129
# Segment 117 / 129
# Segment 118 / 129
# Segment 119 / 129
# Segment 120 / 129
# Segment 121 / 129
# Segment 122 / 129
# Segment 123 / 129
# Segment 124 / 129
# Segment 125 / 129
# Segment 126 / 129
# Segment 127 / 129
# Segment 128 / 129
# Segment 129 / 129
# Write out to data/amt_cache/bytedance/2008_MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--1.mid
#   [18/50] 2008/MIDI-Unprocessed_08_R3_2008_01-05_ORIG_MID--AUDIO_08_R3_2008_wav--3.wav
# Segment 0 / 129
# Segment 1 / 129
# Segment 2 / 129
# Segment 3 / 129
# Segment 4 / 129
# Segment 5 / 129
# Segment 6 / 129
# Segment 7 / 129
# Segment 8 / 129
# Segment 9 / 129
# Segment 10 / 129
# Segment 11 / 129
# Segment 12 / 129
# Segment 13 / 129
# Segment 14 / 129
# Segment 15 / 129
# Segment 16 / 129
# Segment 17 / 129
# Segment 18 / 129
# Segment 19 / 129
# Segment 20 / 129
# Segment 21 / 129
# Segment 22 / 129
# Segment 23 / 129
# Segment 24 / 129
# Segment 25 / 129
# Segment 26 / 129
# Segment 27 / 129
# Segment 28 / 129
# Segment 29 / 129
# Segment 30 / 129
# Segment 31 / 129
# Segment 32 / 129
# Segment 33 / 129
# Segment 34 / 129
# Segment 35 / 129
# Segment 36 / 129
# Segment 37 / 129
# Segment 38 / 129
# Segment 39 / 129
# Segment 40 / 129
# Segment 41 / 129
# Segment 42 / 129
# Segment 43 / 129
# Segment 44 / 129
# Segment 45 / 129
# Segment 46 / 129
# Segment 47 / 129
# Segment 48 / 129
# Segment 49 / 129
# Segment 50 / 129
# Segment 51 / 129
# Segment 52 / 129
# Segment 53 / 129
# Segment 54 / 129
# Segment 55 / 129
# Segment 56 / 129
# Segment 57 / 129
# Segment 58 / 129
# Segment 59 / 129
# Segment 60 / 129
# Segment 61 / 129
# Segment 62 / 129
# Segment 63 / 129
# Segment 64 / 129
# Segment 65 / 129
# Segment 66 / 129
# Segment 67 / 129
# Segment 68 / 129
# Segment 69 / 129
# Segment 70 / 129
# Segment 71 / 129
# Segment 72 / 129
# Segment 73 / 129
# Segment 74 / 129
# Segment 75 / 129
# Segment 76 / 129
# Segment 77 / 129
# Segment 78 / 129
# Segment 79 / 129
# Segment 80 / 129
# Segment 81 / 129
# Segment 82 / 129
# Segment 83 / 129
# Segment 84 / 129
# Segment 85 / 129
# Segment 86 / 129
# Segment 87 / 129
# Segment 88 / 129
# Segment 89 / 129
# Segment 90 / 129
# Segment 91 / 129
# Segment 92 / 129
# Segment 93 / 129
# Segment 94 / 129
# Segment 95 / 129
# Segment 96 / 129
# Segment 97 / 129
# Segment 98 / 129
# Segment 99 / 129
# Segment 100 / 129
# Segment 101 / 129
# Segment 102 / 129
# Segment 103 / 129
# Segment 104 / 129
# Segment 105 / 129
# Segment 106 / 129
# Segment 107 / 129
# Segment 108 / 129
# Segment 109 / 129
# Segment 110 / 129
# Segment 111 / 129
# Segment 112 / 129
# Segment 113 / 129
# Segment 114 / 129
# Segment 115 / 129
# Segment 116 / 129
# Segment 117 / 129
# Segment 118 / 129
# Segment 119 / 129
# Segment 120 / 129
# Segment 121 / 129
# Segment 122 / 129
# Segment 123 / 129
# Segment 124 / 129
# Segment 125 / 129
# Segment 126 / 129
# Segment 127 / 129
# Segment 128 / 129
# Segment 129 / 129
# Write out to data/amt_cache/bytedance/2008_MIDI-Unprocessed_08_R3_2008_01-05_ORIG_MID--AUDIO_08_R3_2008_wav--3.mid
#   [19/50] 2008/MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--4.wav
# Segment 0 / 131
# Segment 1 / 131
# Segment 2 / 131
# Segment 3 / 131
# Segment 4 / 131
# Segment 5 / 131
# Segment 6 / 131
# Segment 7 / 131
# Segment 8 / 131
# Segment 9 / 131
# Segment 10 / 131
# Segment 11 / 131
# Segment 12 / 131
# Segment 13 / 131
# Segment 14 / 131
# Segment 15 / 131
# Segment 16 / 131
# Segment 17 / 131
# Segment 18 / 131
# Segment 19 / 131
# Segment 20 / 131
# Segment 21 / 131
# Segment 22 / 131
# Segment 23 / 131
# Segment 24 / 131
# Segment 25 / 131
# Segment 26 / 131
# Segment 27 / 131
# Segment 28 / 131
# Segment 29 / 131
# Segment 30 / 131
# Segment 31 / 131
# Segment 32 / 131
# Segment 33 / 131
# Segment 34 / 131
# Segment 35 / 131
# Segment 36 / 131
# Segment 37 / 131
# Segment 38 / 131
# Segment 39 / 131
# Segment 40 / 131
# Segment 41 / 131
# Segment 42 / 131
# Segment 43 / 131
# Segment 44 / 131
# Segment 45 / 131
# Segment 46 / 131
# Segment 47 / 131
# Segment 48 / 131
# Segment 49 / 131
# Segment 50 / 131
# Segment 51 / 131
# Segment 52 / 131
# Segment 53 / 131
# Segment 54 / 131
# Segment 55 / 131
# Segment 56 / 131
# Segment 57 / 131
# Segment 58 / 131
# Segment 59 / 131
# Segment 60 / 131
# Segment 61 / 131
# Segment 62 / 131
# Segment 63 / 131
# Segment 64 / 131
# Segment 65 / 131
# Segment 66 / 131
# Segment 67 / 131
# Segment 68 / 131
# Segment 69 / 131
# Segment 70 / 131
# Segment 71 / 131
# Segment 72 / 131
# Segment 73 / 131
# Segment 74 / 131
# Segment 75 / 131
# Segment 76 / 131
# Segment 77 / 131
# Segment 78 / 131
# Segment 79 / 131
# Segment 80 / 131
# Segment 81 / 131
# Segment 82 / 131
# Segment 83 / 131
# Segment 84 / 131
# Segment 85 / 131
# Segment 86 / 131
# Segment 87 / 131
# Segment 88 / 131
# Segment 89 / 131
# Segment 90 / 131
# Segment 91 / 131
# Segment 92 / 131
# Segment 93 / 131
# Segment 94 / 131
# Segment 95 / 131
# Segment 96 / 131
# Segment 97 / 131
# Segment 98 / 131
# Segment 99 / 131
# Segment 100 / 131
# Segment 101 / 131
# Segment 102 / 131
# Segment 103 / 131
# Segment 104 / 131
# Segment 105 / 131
# Segment 106 / 131
# Segment 107 / 131
# Segment 108 / 131
# Segment 109 / 131
# Segment 110 / 131
# Segment 111 / 131
# Segment 112 / 131
# Segment 113 / 131
# Segment 114 / 131
# Segment 115 / 131
# Segment 116 / 131
# Segment 117 / 131
# Segment 118 / 131
# Segment 119 / 131
# Segment 120 / 131
# Segment 121 / 131
# Segment 122 / 131
# Segment 123 / 131
# Segment 124 / 131
# Segment 125 / 131
# Segment 126 / 131
# Segment 127 / 131
# Segment 128 / 131
# Segment 129 / 131
# Segment 130 / 131
# Segment 131 / 131
# Write out to data/amt_cache/bytedance/2008_MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--4.mid
#   [20/50] 2008/MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--1.wav
# Segment 0 / 131
# Segment 1 / 131
# Segment 2 / 131
# Segment 3 / 131
# Segment 4 / 131
# Segment 5 / 131
# Segment 6 / 131
# Segment 7 / 131
# Segment 8 / 131
# Segment 9 / 131
# Segment 10 / 131
# Segment 11 / 131
# Segment 12 / 131
# Segment 13 / 131
# Segment 14 / 131
# Segment 15 / 131
# Segment 16 / 131
# Segment 17 / 131
# Segment 18 / 131
# Segment 19 / 131
# Segment 20 / 131
# Segment 21 / 131
# Segment 22 / 131
# Segment 23 / 131
# Segment 24 / 131
# Segment 25 / 131
# Segment 26 / 131
# Segment 27 / 131
# Segment 28 / 131
# Segment 29 / 131
# Segment 30 / 131
# Segment 31 / 131
# Segment 32 / 131
# Segment 33 / 131
# Segment 34 / 131
# Segment 35 / 131
# Segment 36 / 131
# Segment 37 / 131
# Segment 38 / 131
# Segment 39 / 131
# Segment 40 / 131
# Segment 41 / 131
# Segment 42 / 131
# Segment 43 / 131
# Segment 44 / 131
# Segment 45 / 131
# Segment 46 / 131
# Segment 47 / 131
# Segment 48 / 131
# Segment 49 / 131
# Segment 50 / 131
# Segment 51 / 131
# Segment 52 / 131
# Segment 53 / 131
# Segment 54 / 131
# Segment 55 / 131
# Segment 56 / 131
# Segment 57 / 131
# Segment 58 / 131
# Segment 59 / 131
# Segment 60 / 131
# Segment 61 / 131
# Segment 62 / 131
# Segment 63 / 131
# Segment 64 / 131
# Segment 65 / 131
# Segment 66 / 131
# Segment 67 / 131
# Segment 68 / 131
# Segment 69 / 131
# Segment 70 / 131
# Segment 71 / 131
# Segment 72 / 131
# Segment 73 / 131
# Segment 74 / 131
# Segment 75 / 131
# Segment 76 / 131
# Segment 77 / 131
# Segment 78 / 131
# Segment 79 / 131
# Segment 80 / 131
# Segment 81 / 131
# Segment 82 / 131
# Segment 83 / 131
# Segment 84 / 131
# Segment 85 / 131
# Segment 86 / 131
# Segment 87 / 131
# Segment 88 / 131
# Segment 89 / 131
# Segment 90 / 131
# Segment 91 / 131
# Segment 92 / 131
# Segment 93 / 131
# Segment 94 / 131
# Segment 95 / 131
# Segment 96 / 131
# Segment 97 / 131
# Segment 98 / 131
# Segment 99 / 131
# Segment 100 / 131
# Segment 101 / 131
# Segment 102 / 131
# Segment 103 / 131
# Segment 104 / 131
# Segment 105 / 131
# Segment 106 / 131
# Segment 107 / 131
# Segment 108 / 131
# Segment 109 / 131
# Segment 110 / 131
# Segment 111 / 131
# Segment 112 / 131
# Segment 113 / 131
# Segment 114 / 131
# Segment 115 / 131
# Segment 116 / 131
# Segment 117 / 131
# Segment 118 / 131
# Segment 119 / 131
# Segment 120 / 131
# Segment 121 / 131
# Segment 122 / 131
# Segment 123 / 131
# Segment 124 / 131
# Segment 125 / 131
# Segment 126 / 131
# Segment 127 / 131
# Segment 128 / 131
# Segment 129 / 131
# Segment 130 / 131
# Segment 131 / 131
# Write out to data/amt_cache/bytedance/2008_MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--1.mid
#   [21/50] 2008/MIDI-Unprocessed_11_R3_2008_01-04_ORIG_MID--AUDIO_11_R3_2008_wav--2.wav
# Segment 0 / 145
# Segment 1 / 145
# Segment 2 / 145
# Segment 3 / 145
# Segment 4 / 145
# Segment 5 / 145
# Segment 6 / 145
# Segment 7 / 145
# Segment 8 / 145
# Segment 9 / 145
# Segment 10 / 145
# Segment 11 / 145
# Segment 12 / 145
# Segment 13 / 145
# Segment 14 / 145
# Segment 15 / 145
# Segment 16 / 145
# Segment 17 / 145
# Segment 18 / 145
# Segment 19 / 145
# Segment 20 / 145
# Segment 21 / 145
# Segment 22 / 145
# Segment 23 / 145
# Segment 24 / 145
# Segment 25 / 145
# Segment 26 / 145
# Segment 27 / 145
# Segment 28 / 145
# Segment 29 / 145
# Segment 30 / 145
# Segment 31 / 145
# Segment 32 / 145
# Segment 33 / 145
# Segment 34 / 145
# Segment 35 / 145
# Segment 36 / 145
# Segment 37 / 145
# Segment 38 / 145
# Segment 39 / 145
# Segment 40 / 145
# Segment 41 / 145
# Segment 42 / 145
# Segment 43 / 145
# Segment 44 / 145
# Segment 45 / 145
# Segment 46 / 145
# Segment 47 / 145
# Segment 48 / 145
# Segment 49 / 145
# Segment 50 / 145
# Segment 51 / 145
# Segment 52 / 145
# Segment 53 / 145
# Segment 54 / 145
# Segment 55 / 145
# Segment 56 / 145
# Segment 57 / 145
# Segment 58 / 145
# Segment 59 / 145
# Segment 60 / 145
# Segment 61 / 145
# Segment 62 / 145
# Segment 63 / 145
# Segment 64 / 145
# Segment 65 / 145
# Segment 66 / 145
# Segment 67 / 145
# Segment 68 / 145
# Segment 69 / 145
# Segment 70 / 145
# Segment 71 / 145
# Segment 72 / 145
# Segment 73 / 145
# Segment 74 / 145
# Segment 75 / 145
# Segment 76 / 145
# Segment 77 / 145
# Segment 78 / 145
# Segment 79 / 145
# Segment 80 / 145
# Segment 81 / 145
# Segment 82 / 145
# Segment 83 / 145
# Segment 84 / 145
# Segment 85 / 145
# Segment 86 / 145
# Segment 87 / 145
# Segment 88 / 145
# Segment 89 / 145
# Segment 90 / 145
# Segment 91 / 145
# Segment 92 / 145
# Segment 93 / 145
# Segment 94 / 145
# Segment 95 / 145
# Segment 96 / 145
# Segment 97 / 145
# Segment 98 / 145
# Segment 99 / 145
# Segment 100 / 145
# Segment 101 / 145
# Segment 102 / 145
# Segment 103 / 145
# Segment 104 / 145
# Segment 105 / 145
# Segment 106 / 145
# Segment 107 / 145
# Segment 108 / 145
# Segment 109 / 145
# Segment 110 / 145
# Segment 111 / 145
# Segment 112 / 145
# Segment 113 / 145
# Segment 114 / 145
# Segment 115 / 145
# Segment 116 / 145
# Segment 117 / 145
# Segment 118 / 145
# Segment 119 / 145
# Segment 120 / 145
# Segment 121 / 145
# Segment 122 / 145
# Segment 123 / 145
# Segment 124 / 145
# Segment 125 / 145
# Segment 126 / 145
# Segment 127 / 145
# Segment 128 / 145
# Segment 129 / 145
# Segment 130 / 145
# Segment 131 / 145
# Segment 132 / 145
# Segment 133 / 145
# Segment 134 / 145
# Segment 135 / 145
# Segment 136 / 145
# Segment 137 / 145
# Segment 138 / 145
# Segment 139 / 145
# Segment 140 / 145
# Segment 141 / 145
# Segment 142 / 145
# Segment 143 / 145
# Segment 144 / 145
# Segment 145 / 145
# Write out to data/amt_cache/bytedance/2008_MIDI-Unprocessed_11_R3_2008_01-04_ORIG_MID--AUDIO_11_R3_2008_wav--2.mid
#   [22/50] 2008/MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--1.wav
# Segment 0 / 123
# Segment 1 / 123
# Segment 2 / 123
# Segment 3 / 123
# Segment 4 / 123
# Segment 5 / 123
# Segment 6 / 123
# Segment 7 / 123
# Segment 8 / 123
# Segment 9 / 123
# Segment 10 / 123
# Segment 11 / 123
# Segment 12 / 123
# Segment 13 / 123
# Segment 14 / 123
# Segment 15 / 123
# Segment 16 / 123
# Segment 17 / 123
# Segment 18 / 123
# Segment 19 / 123
# Segment 20 / 123
# Segment 21 / 123
# Segment 22 / 123
# Segment 23 / 123
# Segment 24 / 123
# Segment 25 / 123
# Segment 26 / 123
# Segment 27 / 123
# Segment 28 / 123
# Segment 29 / 123
# Segment 30 / 123
# Segment 31 / 123
# Segment 32 / 123
# Segment 33 / 123
# Segment 34 / 123
# Segment 35 / 123
# Segment 36 / 123
# Segment 37 / 123
# Segment 38 / 123
# Segment 39 / 123
# Segment 40 / 123
# Segment 41 / 123
# Segment 42 / 123
# Segment 43 / 123
# Segment 44 / 123
# Segment 45 / 123
# Segment 46 / 123
# Segment 47 / 123
# Segment 48 / 123
# Segment 49 / 123
# Segment 50 / 123
# Segment 51 / 123
# Segment 52 / 123
# Segment 53 / 123
# Segment 54 / 123
# Segment 55 / 123
# Segment 56 / 123
# Segment 57 / 123
# Segment 58 / 123
# Segment 59 / 123
# Segment 60 / 123
# Segment 61 / 123
# Segment 62 / 123
# Segment 63 / 123
# Segment 64 / 123
# Segment 65 / 123
# Segment 66 / 123
# Segment 67 / 123
# Segment 68 / 123
# Segment 69 / 123
# Segment 70 / 123
# Segment 71 / 123
# Segment 72 / 123
# Segment 73 / 123
# Segment 74 / 123
# Segment 75 / 123
# Segment 76 / 123
# Segment 77 / 123
# Segment 78 / 123
# Segment 79 / 123
# Segment 80 / 123
# Segment 81 / 123
# Segment 82 / 123
# Segment 83 / 123
# Segment 84 / 123
# Segment 85 / 123
# Segment 86 / 123
# Segment 87 / 123
# Segment 88 / 123
# Segment 89 / 123
# Segment 90 / 123
# Segment 91 / 123
# Segment 92 / 123
# Segment 93 / 123
# Segment 94 / 123
# Segment 95 / 123
# Segment 96 / 123
# Segment 97 / 123
# Segment 98 / 123
# Segment 99 / 123
# Segment 100 / 123
# Segment 101 / 123
# Segment 102 / 123
# Segment 103 / 123
# Segment 104 / 123
# Segment 105 / 123
# Segment 106 / 123
# Segment 107 / 123
# Segment 108 / 123
# Segment 109 / 123
# Segment 110 / 123
# Segment 111 / 123
# Segment 112 / 123
# Segment 113 / 123
# Segment 114 / 123
# Segment 115 / 123
# Segment 116 / 123
# Segment 117 / 123
# Segment 118 / 123
# Segment 119 / 123
# Segment 120 / 123
# Segment 121 / 123
# Segment 122 / 123
# Segment 123 / 123
# Write out to data/amt_cache/bytedance/2008_MIDI-Unprocessed_12_R3_2008_01-04_ORIG_MID--AUDIO_12_R3_2008_wav--1.mid
#   [23/50] 2011/MIDI-Unprocessed_03_R3_2011_MID--AUDIO_R3-D1_04_Track04_wav.wav
# Segment 0 / 131
# Segment 1 / 131
# Segment 2 / 131
# Segment 3 / 131
# Segment 4 / 131
# Segment 5 / 131
# Segment 6 / 131
# Segment 7 / 131
# Segment 8 / 131
# Segment 9 / 131
# Segment 10 / 131
# Segment 11 / 131
# Segment 12 / 131
# Segment 13 / 131
# Segment 14 / 131
# Segment 15 / 131
# Segment 16 / 131
# ...
# Segment 165 / 351
# Segment 166 / 351
# Segment 167 / 351
# Segment 168 / 351
# Segment 169 / 351
# Segment 170 / 351
# Segment 171 / 351
# Segment 172 / 351
# Segment 173 / 351
# Segment 174 / 351
# Segment 175 / 351
# Segment 176 / 351
# Segment 177 / 351
# Segment 178 / 351
# Segment 179 / 351
# Segment 180 / 351
# Segment 181 / 351
# Segment 182 / 351
# Segment 183 / 351
# Segment 184 / 351
# Segment 185 / 351
# Segment 186 / 351
# Segment 187 / 351
# Segment 188 / 351
# Segment 189 / 351
# Segment 190 / 351
# Segment 191 / 351
# Segment 192 / 351
# Segment 193 / 351
# Segment 194 / 351
# Segment 195 / 351
# Segment 196 / 351
# Segment 197 / 351
# Segment 198 / 351
# Segment 199 / 351
# Segment 200 / 351
# Segment 201 / 351
# Segment 202 / 351
# Segment 203 / 351
# Segment 204 / 351
# Segment 205 / 351
# Segment 206 / 351
# Segment 207 / 351
# Segment 208 / 351
# Segment 209 / 351
# Segment 210 / 351
# Segment 211 / 351
# Segment 212 / 351
# Segment 213 / 351
# Segment 214 / 351
# Segment 215 / 351
# Segment 216 / 351
# Segment 217 / 351
# Segment 218 / 351
# Segment 219 / 351
# Segment 220 / 351
# Segment 221 / 351
# Segment 222 / 351
# Segment 223 / 351
# Segment 224 / 351
# Segment 225 / 351
# Segment 226 / 351
# Segment 227 / 351
# Segment 228 / 351
# Segment 229 / 351
# Segment 230 / 351
# Segment 231 / 351
# Segment 232 / 351
# Segment 233 / 351
# Segment 234 / 351
# Segment 235 / 351
# Segment 236 / 351
# Segment 237 / 351
# Segment 238 / 351
# Segment 239 / 351
# Segment 240 / 351
# Segment 241 / 351
# Segment 242 / 351
# Segment 243 / 351
# Segment 244 / 351
# Segment 245 / 351
# Segment 246 / 351
# Segment 247 / 351
# Segment 248 / 351
# Segment 249 / 351
# Segment 250 / 351
# Segment 251 / 351
# Segment 252 / 351
# Segment 253 / 351
# Segment 254 / 351
# Segment 255 / 351
# Segment 256 / 351
# Segment 257 / 351
# Segment 258 / 351
# Segment 259 / 351
# Segment 260 / 351
# Segment 261 / 351
# Segment 262 / 351
# Segment 263 / 351
# Segment 264 / 351
# Segment 265 / 351
# Segment 266 / 351
# Segment 267 / 351
# Segment 268 / 351
# Segment 269 / 351
# Segment 270 / 351
# Segment 271 / 351
# Segment 272 / 351
# Segment 273 / 351
# Segment 274 / 351
# Segment 275 / 351
# Segment 276 / 351
# Segment 277 / 351
# Segment 278 / 351
# Segment 279 / 351
# Segment 280 / 351
# Segment 281 / 351
# Segment 282 / 351
# Segment 283 / 351
# Segment 284 / 351
# Segment 285 / 351
# Segment 286 / 351
# Segment 287 / 351
# Segment 288 / 351
# Segment 289 / 351
# Segment 290 / 351
# Segment 291 / 351
# Segment 292 / 351
# Segment 293 / 351
# Segment 294 / 351
# Segment 295 / 351
# Segment 296 / 351
# Segment 297 / 351
# Segment 298 / 351
# Segment 299 / 351
# Segment 300 / 351
# Segment 301 / 351
# Segment 302 / 351
# Segment 303 / 351
# Segment 304 / 351
# Segment 305 / 351
# Segment 306 / 351
# Segment 307 / 351
# Segment 308 / 351
# Segment 309 / 351
# Segment 310 / 351
# Segment 311 / 351
# Segment 312 / 351
# Segment 313 / 351
# Segment 314 / 351
# Segment 315 / 351
# Segment 316 / 351
# Segment 317 / 351
# Segment 318 / 351
# Segment 319 / 351
# Segment 320 / 351
# Segment 321 / 351
# Segment 322 / 351
# Segment 323 / 351
# Segment 324 / 351
# Segment 325 / 351
# Segment 326 / 351
# Segment 327 / 351
# Segment 328 / 351
# Segment 329 / 351
# Segment 330 / 351
# Segment 331 / 351
# Segment 332 / 351
# Segment 333 / 351
# Segment 334 / 351
# Segment 335 / 351
# Segment 336 / 351
# Segment 337 / 351
# Segment 338 / 351
# Segment 339 / 351
# Segment 340 / 351
# Segment 341 / 351
# Segment 342 / 351
# Segment 343 / 351
# Segment 344 / 351
# Segment 345 / 351
# Segment 346 / 351
# Segment 347 / 351
# Segment 348 / 351
# Segment 349 / 351
# Segment 350 / 351
# Segment 351 / 351
# Write out to data/amt_cache/bytedance/2018_MIDI-Unprocessed_Schubert4-6_MID--AUDIO_08_R2_2018_wav.mid
#   [49/50] 2018/MIDI-Unprocessed_Schubert7-9_MID--AUDIO_11_R2_2018_wav.wav
# Segment 0 / 327
# Segment 1 / 327
# Segment 2 / 327
# Segment 3 / 327
# Segment 4 / 327
# Segment 5 / 327
# Segment 6 / 327
# Segment 7 / 327
# Segment 8 / 327
# Segment 9 / 327
# Segment 10 / 327
# Segment 11 / 327
# Segment 12 / 327
# Segment 13 / 327
# Segment 14 / 327
# Segment 15 / 327
# Segment 16 / 327
# Segment 17 / 327
# Segment 18 / 327
# Segment 19 / 327
# Segment 20 / 327
# Segment 21 / 327
# Segment 22 / 327
# Segment 23 / 327
# Segment 24 / 327
# Segment 25 / 327
# Segment 26 / 327
# Segment 27 / 327
# Segment 28 / 327
# Segment 29 / 327
# Segment 30 / 327
# Segment 31 / 327
# Segment 32 / 327
# Segment 33 / 327
# Segment 34 / 327
# Segment 35 / 327
# Segment 36 / 327
# Segment 37 / 327
# Segment 38 / 327
# Segment 39 / 327
# Segment 40 / 327
# Segment 41 / 327
# Segment 42 / 327
# Segment 43 / 327
# Segment 44 / 327
# Segment 45 / 327
# Segment 46 / 327
# Segment 47 / 327
# Segment 48 / 327
# Segment 49 / 327
# Segment 50 / 327
# Segment 51 / 327
# Segment 52 / 327
# Segment 53 / 327
# Segment 54 / 327
# Segment 55 / 327
# Segment 56 / 327
# Segment 57 / 327
# Segment 58 / 327
# Segment 59 / 327
# Segment 60 / 327
# Segment 61 / 327
# Segment 62 / 327
# Segment 63 / 327
# Segment 64 / 327
# Segment 65 / 327
# Segment 66 / 327
# Segment 67 / 327
# Segment 68 / 327
# Segment 69 / 327
# Segment 70 / 327
# Segment 71 / 327
# Segment 72 / 327
# Segment 73 / 327
# Segment 74 / 327
# Segment 75 / 327
# Segment 76 / 327
# Segment 77 / 327
# Segment 78 / 327
# Segment 79 / 327
# Segment 80 / 327
# Segment 81 / 327
# Segment 82 / 327
# Segment 83 / 327
# Segment 84 / 327
# Segment 85 / 327
# Segment 86 / 327
# Segment 87 / 327
# Segment 88 / 327
# Segment 89 / 327
# Segment 90 / 327
# Segment 91 / 327
# Segment 92 / 327
# Segment 93 / 327
# Segment 94 / 327
# Segment 95 / 327
# Segment 96 / 327
# Segment 97 / 327
# Segment 98 / 327
# Segment 99 / 327
# Segment 100 / 327
# Segment 101 / 327
# Segment 102 / 327
# Segment 103 / 327
# Segment 104 / 327
# Segment 105 / 327
# Segment 106 / 327
# Segment 107 / 327
# Segment 108 / 327
# Segment 109 / 327
# Segment 110 / 327
# Segment 111 / 327
# Segment 112 / 327
# Segment 113 / 327
# Segment 114 / 327
# Segment 115 / 327
# Segment 116 / 327
# Segment 117 / 327
# Segment 118 / 327
# Segment 119 / 327
# Segment 120 / 327
# Segment 121 / 327
# Segment 122 / 327
# Segment 123 / 327
# Segment 124 / 327
# Segment 125 / 327
# Segment 126 / 327
# Segment 127 / 327
# Segment 128 / 327
# Segment 129 / 327
# Segment 130 / 327
# Segment 131 / 327
# Segment 132 / 327
# Segment 133 / 327
# Segment 134 / 327
# Segment 135 / 327
# Segment 136 / 327
# Segment 137 / 327
# Segment 138 / 327
# Segment 139 / 327
# Segment 140 / 327
# Segment 141 / 327
# Segment 142 / 327
# Segment 143 / 327
# Segment 144 / 327
# Segment 145 / 327
# Segment 146 / 327
# Segment 147 / 327
# Segment 148 / 327
# Segment 149 / 327
# Segment 150 / 327
# Segment 151 / 327
# Segment 152 / 327
# Segment 153 / 327
# Segment 154 / 327
# Segment 155 / 327
# Segment 156 / 327
# Segment 157 / 327
# Segment 158 / 327
# Segment 159 / 327
# Segment 160 / 327
# Segment 161 / 327
# Segment 162 / 327
# Segment 163 / 327
# Segment 164 / 327
# Segment 165 / 327
# Segment 166 / 327
# Segment 167 / 327
# Segment 168 / 327
# Segment 169 / 327
# Segment 170 / 327
# Segment 171 / 327
# Segment 172 / 327
# Segment 173 / 327
# Segment 174 / 327
# Segment 175 / 327
# Segment 176 / 327
# Segment 177 / 327
# Segment 178 / 327
# Segment 179 / 327
# Segment 180 / 327
# Segment 181 / 327
# Segment 182 / 327
# Segment 183 / 327
# Segment 184 / 327
# Segment 185 / 327
# Segment 186 / 327
# Segment 187 / 327
# Segment 188 / 327
# Segment 189 / 327
# Segment 190 / 327
# Segment 191 / 327
# Segment 192 / 327
# Segment 193 / 327
# Segment 194 / 327
# Segment 195 / 327
# Segment 196 / 327
# Segment 197 / 327
# Segment 198 / 327
# Segment 199 / 327
# Segment 200 / 327
# Segment 201 / 327
# Segment 202 / 327
# Segment 203 / 327
# Segment 204 / 327
# Segment 205 / 327
# Segment 206 / 327
# Segment 207 / 327
# Segment 208 / 327
# Segment 209 / 327
# Segment 210 / 327
# Segment 211 / 327
# Segment 212 / 327
# Segment 213 / 327
# Segment 214 / 327
# Segment 215 / 327
# Segment 216 / 327
# Segment 217 / 327
# Segment 218 / 327
# Segment 219 / 327
# Segment 220 / 327
# Segment 221 / 327
# Segment 222 / 327
# Segment 223 / 327
# Segment 224 / 327
# Segment 225 / 327
# Segment 226 / 327
# Segment 227 / 327
# Segment 228 / 327
# Segment 229 / 327
# Segment 230 / 327
# Segment 231 / 327
# Segment 232 / 327
# Segment 233 / 327
# Segment 234 / 327
# Segment 235 / 327
# Segment 236 / 327
# Segment 237 / 327
# Segment 238 / 327
# Segment 239 / 327
# Segment 240 / 327
# Segment 241 / 327
# Segment 242 / 327
# Segment 243 / 327
# Segment 244 / 327
# Segment 245 / 327
# Segment 246 / 327
# Segment 247 / 327
# Segment 248 / 327
# Segment 249 / 327
# Segment 250 / 327
# Segment 251 / 327
# Segment 252 / 327
# Segment 253 / 327
# Segment 254 / 327
# Segment 255 / 327
# Segment 256 / 327
# Segment 257 / 327
# Segment 258 / 327
# Segment 259 / 327
# Segment 260 / 327
# Segment 261 / 327
# Segment 262 / 327
# Segment 263 / 327
# Segment 264 / 327
# Segment 265 / 327
# Segment 266 / 327
# Segment 267 / 327
# Segment 268 / 327
# Segment 269 / 327
# Segment 270 / 327
# Segment 271 / 327
# Segment 272 / 327
# Segment 273 / 327
# Segment 274 / 327
# Segment 275 / 327
# Segment 276 / 327
# Segment 277 / 327
# Segment 278 / 327
# Segment 279 / 327
# Segment 280 / 327
# Segment 281 / 327
# Segment 282 / 327
# Segment 283 / 327
# Segment 284 / 327
# Segment 285 / 327
# Segment 286 / 327
# Segment 287 / 327
# Segment 288 / 327
# Segment 289 / 327
# Segment 290 / 327
# Segment 291 / 327
# Segment 292 / 327
# Segment 293 / 327
# Segment 294 / 327
# Segment 295 / 327
# Segment 296 / 327
# Segment 297 / 327
# Segment 298 / 327
# Segment 299 / 327
# Segment 300 / 327
# Segment 301 / 327
# Segment 302 / 327
# Segment 303 / 327
# Segment 304 / 327
# Segment 305 / 327
# Segment 306 / 327
# Segment 307 / 327
# Segment 308 / 327
# Segment 309 / 327
# Segment 310 / 327
# Segment 311 / 327
# Segment 312 / 327
# Segment 313 / 327
# Segment 314 / 327
# Segment 315 / 327
# Segment 316 / 327
# Segment 317 / 327
# Segment 318 / 327
# Segment 319 / 327
# Segment 320 / 327
# Segment 321 / 327
# Segment 322 / 327
# Segment 323 / 327
# Segment 324 / 327
# Segment 325 / 327
# Segment 326 / 327
# Segment 327 / 327
# Write out to data/amt_cache/bytedance/2018_MIDI-Unprocessed_Schubert7-9_MID--AUDIO_11_R2_2018_wav.mid
#   [50/50] 2018/MIDI-Unprocessed_Schubert7-9_MID--AUDIO_16_R2_2018_wav.wav
# Segment 0 / 351
# Segment 1 / 351
# Segment 2 / 351
# Segment 3 / 351
# Segment 4 / 351
# Segment 5 / 351
# Segment 6 / 351
# Segment 7 / 351
# Segment 8 / 351
# Segment 9 / 351
# Segment 10 / 351
# Segment 11 / 351
# Segment 12 / 351
# Segment 13 / 351
# Segment 14 / 351
# Segment 15 / 351
# Segment 16 / 351
# Segment 17 / 351
# Segment 18 / 351
# Segment 19 / 351
# Segment 20 / 351
# Segment 21 / 351
# Segment 22 / 351
# Segment 23 / 351
# Segment 24 / 351
# Segment 25 / 351
# Segment 26 / 351
# Segment 27 / 351
# Segment 28 / 351
# Segment 29 / 351
# Segment 30 / 351
# Segment 31 / 351
# Segment 32 / 351
# Segment 33 / 351
# Segment 34 / 351
# Segment 35 / 351
# Segment 36 / 351
# Segment 37 / 351
# Segment 38 / 351
# Segment 39 / 351
# Segment 40 / 351
# Segment 41 / 351
# Segment 42 / 351
# Segment 43 / 351
# Segment 44 / 351
# Segment 45 / 351
# Segment 46 / 351
# Segment 47 / 351
# Segment 48 / 351
# Segment 49 / 351
# Segment 50 / 351
# Segment 51 / 351
# Segment 52 / 351
# Segment 53 / 351
# Segment 54 / 351
# Segment 55 / 351
# Segment 56 / 351
# Segment 57 / 351
# Segment 58 / 351
# Segment 59 / 351
# Segment 60 / 351
# Segment 61 / 351
# Segment 62 / 351
# Segment 63 / 351
# Segment 64 / 351
# Segment 65 / 351
# Segment 66 / 351
# Segment 67 / 351
# Segment 68 / 351
# Segment 69 / 351
# Segment 70 / 351
# Segment 71 / 351
# Segment 72 / 351
# Segment 73 / 351
# Segment 74 / 351
# Segment 75 / 351
# Segment 76 / 351
# Segment 77 / 351
# Segment 78 / 351
# Segment 79 / 351
# Segment 80 / 351
# Segment 81 / 351
# Segment 82 / 351
# Segment 83 / 351
# Segment 84 / 351
# Segment 85 / 351
# Segment 86 / 351
# Segment 87 / 351
# Segment 88 / 351
# Segment 89 / 351
# Segment 90 / 351
# Segment 91 / 351
# Segment 92 / 351
# Segment 93 / 351
# Segment 94 / 351
# Segment 95 / 351
# Segment 96 / 351
# Segment 97 / 351
# Segment 98 / 351
# Segment 99 / 351
# Segment 100 / 351
# Segment 101 / 351
# Segment 102 / 351
# Segment 103 / 351
# Segment 104 / 351
# Segment 105 / 351
# Segment 106 / 351
# Segment 107 / 351
# Segment 108 / 351
# Segment 109 / 351
# Segment 110 / 351
# Segment 111 / 351
# Segment 112 / 351
# Segment 113 / 351
# Segment 114 / 351
# Segment 115 / 351
# Segment 116 / 351
# Segment 117 / 351
# Segment 118 / 351
# Segment 119 / 351
# Segment 120 / 351
# Segment 121 / 351
# Segment 122 / 351
# Segment 123 / 351
# Segment 124 / 351
# Segment 125 / 351
# Segment 126 / 351
# Segment 127 / 351
# Segment 128 / 351
# Segment 129 / 351
# Segment 130 / 351
# Segment 131 / 351
# Segment 132 / 351
# Segment 133 / 351
# Segment 134 / 351
# Segment 135 / 351
# Segment 136 / 351
# Segment 137 / 351
# Segment 138 / 351
# Segment 139 / 351
# Segment 140 / 351
# Segment 141 / 351
# Segment 142 / 351
# Segment 143 / 351
# Segment 144 / 351
# Segment 145 / 351
# Segment 146 / 351
# Segment 147 / 351
# Segment 148 / 351
# Segment 149 / 351
# Segment 150 / 351
# Segment 151 / 351
# Segment 152 / 351
# Segment 153 / 351
# Segment 154 / 351
# Segment 155 / 351
# Segment 156 / 351
# Segment 157 / 351
# Segment 158 / 351
# Segment 159 / 351
# Segment 160 / 351
# Segment 161 / 351
# Segment 162 / 351
# Segment 163 / 351
# Segment 164 / 351
# Segment 165 / 351
# Segment 166 / 351
# Segment 167 / 351
# Segment 168 / 351
# Segment 169 / 351
# Segment 170 / 351
# Segment 171 / 351
# Segment 172 / 351
# Segment 173 / 351
# Segment 174 / 351
# Segment 175 / 351
# Segment 176 / 351
# Segment 177 / 351
# Segment 178 / 351
# Segment 179 / 351
# Segment 180 / 351
# Segment 181 / 351
# Segment 182 / 351
# Segment 183 / 351
# Segment 184 / 351
# Segment 185 / 351
# Segment 186 / 351
# Segment 187 / 351
# Segment 188 / 351
# Segment 189 / 351
# Segment 190 / 351
# Segment 191 / 351
# Segment 192 / 351
# Segment 193 / 351
# Segment 194 / 351
# Segment 195 / 351
# Segment 196 / 351
# Segment 197 / 351
# Segment 198 / 351
# Segment 199 / 351
# Segment 200 / 351
# Segment 201 / 351
# Segment 202 / 351
# Segment 203 / 351
# Segment 204 / 351
# Segment 205 / 351
# Segment 206 / 351
# Segment 207 / 351
# Segment 208 / 351
# Segment 209 / 351
# Segment 210 / 351
# Segment 211 / 351
# Segment 212 / 351
# Segment 213 / 351
# Segment 214 / 351
# Segment 215 / 351
# Segment 216 / 351
# Segment 217 / 351
# Segment 218 / 351
# Segment 219 / 351
# Segment 220 / 351
# Segment 221 / 351
# Segment 222 / 351
# Segment 223 / 351
# Segment 224 / 351
# Segment 225 / 351
# Segment 226 / 351
# Segment 227 / 351
# Segment 228 / 351
# Segment 229 / 351
# Segment 230 / 351
# Segment 231 / 351
# Segment 232 / 351
# Segment 233 / 351
# Segment 234 / 351
# Segment 235 / 351
# Segment 236 / 351
# Segment 237 / 351
# Segment 238 / 351
# Segment 239 / 351
# Segment 240 / 351
# Segment 241 / 351
# Segment 242 / 351
# Segment 243 / 351
# Segment 244 / 351
# Segment 245 / 351
# Segment 246 / 351
# Segment 247 / 351
# Segment 248 / 351
# Segment 249 / 351
# Segment 250 / 351
# Segment 251 / 351
# Segment 252 / 351
# Segment 253 / 351
# Segment 254 / 351
# Segment 255 / 351
# Segment 256 / 351
# Segment 257 / 351
# Segment 258 / 351
# Segment 259 / 351
# Segment 260 / 351
# Segment 261 / 351
# Segment 262 / 351
# Segment 263 / 351
# Segment 264 / 351
# Segment 265 / 351
# Segment 266 / 351
# Segment 267 / 351
# Segment 268 / 351
# Segment 269 / 351
# Segment 270 / 351
# Segment 271 / 351
# Segment 272 / 351
# Segment 273 / 351
# Segment 274 / 351
# Segment 275 / 351
# Segment 276 / 351
# Segment 277 / 351
# Segment 278 / 351
# Segment 279 / 351
# Segment 280 / 351
# Segment 281 / 351
# Segment 282 / 351
# Segment 283 / 351
# Segment 284 / 351
# Segment 285 / 351
# Segment 286 / 351
# Segment 287 / 351
# Segment 288 / 351
# Segment 289 / 351
# Segment 290 / 351
# Segment 291 / 351
# Segment 292 / 351
# Segment 293 / 351
# Segment 294 / 351
# Segment 295 / 351
# Segment 296 / 351
# Segment 297 / 351
# Segment 298 / 351
# Segment 299 / 351
# Segment 300 / 351
# Segment 301 / 351
# Segment 302 / 351
# Segment 303 / 351
# Segment 304 / 351
# Segment 305 / 351
# Segment 306 / 351
# Segment 307 / 351
# Segment 308 / 351
# Segment 309 / 351
# Segment 310 / 351
# Segment 311 / 351
# Segment 312 / 351
# Segment 313 / 351
# Segment 314 / 351
# Segment 315 / 351
# Segment 316 / 351
# Segment 317 / 351
# Segment 318 / 351
# Segment 319 / 351
# Segment 320 / 351
# Segment 321 / 351
# Segment 322 / 351
# Segment 323 / 351
# Segment 324 / 351
# Segment 325 / 351
# Segment 326 / 351
# Segment 327 / 351
# Segment 328 / 351
# Segment 329 / 351
# Segment 330 / 351
# Segment 331 / 351
# Segment 332 / 351
# Segment 333 / 351
# Segment 334 / 351
# Segment 335 / 351
# Segment 336 / 351
# Segment 337 / 351
# Segment 338 / 351
# Segment 339 / 351
# Segment 340 / 351
# Segment 341 / 351
# Segment 342 / 351
# Segment 343 / 351
# Segment 344 / 351
# Segment 345 / 351
# Segment 346 / 351
# Segment 347 / 351
# Segment 348 / 351
# Segment 349 / 351
# Segment 350 / 351
# Segment 351 / 351
# Write out to data/amt_cache/bytedance/2018_MIDI-Unprocessed_Schubert7-9_MID--AUDIO_16_R2_2018_wav.mid
#   ByteDance done: 50 files
#
# YourMT3+ not installed. Install with:
#   uv pip install git+https://github.com/mimbres/YourMT3.git
# Continuing with ByteDance only.

# %%
# S2 pairwise assessment: ground-truth vs AMT-transcribed MIDI
from model_improvement.symbolic_encoders import GNNSymbolicEncoder
from model_improvement.graph import midi_to_graph
from model_improvement.layer1_validation import amt_degradation_comparison

s2_ckpt = sorted(CHECKPOINT_DIR.glob("S2/fold_3/*.ckpt"))[0]
print(f"Loading S2 from {s2_ckpt.name}")

s2_model = GNNSymbolicEncoder.load_from_checkpoint(str(s2_ckpt))
s2_model.eval()
s2_model.cpu()

def score_midi_files(model, midi_dir, recording_ids):
    """Score MIDI files with S2, returning {recording_id: scores [6]}."""
    results = {}
    with torch.no_grad():
        for rid in recording_ids:
            midi_path = midi_dir / f"{rid}.mid"
            if not midi_path.exists():
                midi_path = midi_dir / f"{rid}.midi"
            if not midi_path.exists():
                continue
            try:
                graph = midi_to_graph(midi_path)
            except (ValueError, Exception) as e:
                print(f"  Skipping {rid}: {e}")
                continue
            out = model(graph.x, graph.edge_index, torch.zeros(graph.x.size(0), dtype=torch.long))
            results[rid] = out["scores"].squeeze(0).numpy()
    return results

# Build recording IDs from selected audio files
recording_ids = [af.replace("/", "_").replace(".wav", "") for af in audio_files]

# Check what MIDI sources are available
sources = {}

# Ground truth: MAESTRO MIDI files
gt_scores = {}
with torch.no_grad():
    for af in audio_files:
        rec = selected_audio[af]
        midi_file = rec.get("midi_filename", "")
        midi_path = MAESTRO_DIR / midi_file
        rid = af.replace("/", "_").replace(".wav", "")
        if not midi_path.exists():
            continue
        try:
            graph = midi_to_graph(midi_path)
        except (ValueError, Exception) as e:
            print(f"  Skipping GT {rid}: {e}")
            continue
        out = s2_model(graph.x, graph.edge_index, torch.zeros(graph.x.size(0), dtype=torch.long))
        gt_scores[rid] = out["scores"].squeeze(0).numpy()

if gt_scores:
    sources["ground_truth"] = gt_scores
    print(f"Ground truth: scored {len(gt_scores)} recordings")

# ByteDance transcriptions
if list(BYTEDANCE_DIR.glob("*.mid")):
    bd_scores = score_midi_files(s2_model, BYTEDANCE_DIR, recording_ids)
    if bd_scores:
        sources["bytedance"] = bd_scores
        print(f"ByteDance: scored {len(bd_scores)} recordings")

# YourMT3+ transcriptions
if list(YOURMT3_DIR.glob("*.mid")):
    ym_scores = score_midi_files(s2_model, YOURMT3_DIR, recording_ids)
    if ym_scores:
        sources["yourmt3"] = ym_scores
        print(f"YourMT3+: scored {len(ym_scores)} recordings")

# Pairwise assessment
if len(sources) >= 2 and "ground_truth" in sources:
    # For each source, compute pairwise accuracy on contrastive pairs
    # Group recordings by piece for pairwise comparison
    piece_recordings = {}
    for af in audio_files:
        rec = selected_audio[af]
        title = rec["canonical_title"]
        rid = af.replace("/", "_").replace(".wav", "")
        if title not in piece_recordings:
            piece_recordings[title] = []
        piece_recordings[title].append(rid)

    # Only pieces with 2+ recordings
    contrastive_pieces = {p: rids for p, rids in piece_recordings.items() if len(rids) >= 2}
    print(f"\nContrastive pieces: {len(contrastive_pieces)}")

    pairwise_results = {}
    for source_name, scores_dict in sources.items():
        correct = np.zeros(6)
        total = np.zeros(6)
        overall_correct = 0
        overall_total = 0

        for piece, rids in contrastive_pieces.items():
            for i in range(len(rids)):
                for j in range(i + 1, len(rids)):
                    r_a, r_b = rids[i], rids[j]
                    if r_a not in scores_dict or r_b not in scores_dict:
                        continue
                    s_a = scores_dict[r_a]
                    s_b = scores_dict[r_b]
                    # Use ground truth ranking as reference
                    if r_a not in gt_scores or r_b not in gt_scores:
                        continue
                    gt_a = gt_scores[r_a].mean()
                    gt_b = gt_scores[r_b].mean()
                    if abs(gt_a - gt_b) < 0.01:
                        continue  # Skip ambiguous pairs

                    pred_diff = s_a - s_b
                    gt_sign = 1 if gt_a > gt_b else -1

                    for d in range(6):
                        total[d] += 1
                        if (pred_diff[d] > 0 and gt_sign > 0) or (pred_diff[d] < 0 and gt_sign < 0):
                            correct[d] += 1

                    overall_total += 1
                    pred_overall = s_a.mean() - s_b.mean()
                    if (pred_overall > 0 and gt_sign > 0) or (pred_overall < 0 and gt_sign < 0):
                        overall_correct += 1

        if overall_total > 0:
            pairwise_results[source_name] = {
                "overall": overall_correct / overall_total,
                "per_dimension": {d: (correct[d] / total[d] if total[d] > 0 else 0.0) for d in range(6)},
                "n_pairs": int(overall_total),
            }
            print(f"\n{source_name}: {overall_correct}/{overall_total} = {overall_correct/overall_total:.1%} pairwise accuracy")

    if len(pairwise_results) >= 2:
        degradation = amt_degradation_comparison(pairwise_results, baseline="ground_truth")
        print("\n=== AMT Degradation Results ===")
        for source, drops in degradation.items():
            gate = "PASS" if drops["viable"] else "FAIL"
            print(f"\n{source}: overall drop = {drops['overall_drop_pct']:+.1f}% [{gate}]")
            for dim_name, drop in drops["per_dimension_drop_pct"].items():
                print(f"  {dim_name:>14s}: {drop:+.1f}%")
    else:
        print("\nNeed at least ground_truth + one AMT source for degradation comparison.")
else:
    print("\nAMT assessment requires ground-truth + at least one transcription source.")
    if not sources:
        print("No MIDI scores computed. Download MAESTRO audio and run transcription first.")
# Out:
# Loading S2 from epoch=6-val_loss=0.4949.ckpt
# /Users/jdhiman/Documents/crescendai/model/.venv/lib/python3.12/site-packages/pytorch_lightning/utilities/migration/utils.py:56: The loaded checkpoint was produced with Lightning v2.6.1, which is newer than your current Lightning version: v2.5.5
# Ground truth: scored 50 recordings
# ByteDance: scored 50 recordings
#
# Contrastive pieces: 4
#
# ground_truth: 107/107 = 100.0% pairwise accuracy
#
# bytedance: 107/107 = 100.0% pairwise accuracy
#
# === AMT Degradation Results ===
#
# bytedance: overall drop = +0.0% [PASS]
#         dynamics: -0.9%
#           timing: +2.8%
#         pedaling: +0.0%
#     articulation: +0.9%
#         phrasing: +3.7%
#   interpretation: +1.9%
